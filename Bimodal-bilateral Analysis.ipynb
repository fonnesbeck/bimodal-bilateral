# %%
# Import modules and set options
import pandas as pd
import numpy as np
pd.set_option('display.notebook_repr_html', False)

pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 25)
rcParams['savefig.dpi'] = 120

# %% [markdown]
# Connect to database to import data for the three test domains and demographic information:

# %%
from redcap import Project
api_url = 'https://redcap.vanderbilt.edu/api/'
api_key = open("/Users/fonnescj/Dropbox/LSL-DR/api_token.txt").read()

lsl_dr_project = Project(api_url, api_key)

# %%
metadata = lsl_dr_project.export_metadata()

# %%
# metadata = lsl_dr_project.export_metadata(fields=['etiology'])

# %%
# for i,j in zip(lsl_dr_project.field_names, 
#                lsl_dr_project.field_labels):
#     print('{0}: \t{1}'.format(i,j))

# %% [markdown]
# Import each database from REDCap:

# %%
articulation_fields = ['study_id','redcap_event_name','age_test_aaps','aaps_ss','age_test_gf2','gf2_ss']
articulation = lsl_dr_project.export_records(fields=articulation_fields, format='df', df_kwargs={'index_col':None})

# %%
expressive_fields = ['study_id','redcap_event_name','age_test_eowpvt','eowpvt_ss','age_test_evt','evt_ss']
expressive = lsl_dr_project.export_records(fields=expressive_fields, format='df', df_kwargs={'index_col':None})

# %%
receptive_fields = ['study_id','redcap_event_name','age_test_ppvt','ppvt_ss','age_test_rowpvt','rowpvt_ss']
receptive = lsl_dr_project.export_records(fields=receptive_fields, format='df', df_kwargs={'index_col':None})

# %%
language_fields = ['study_id','redcap_event_name','pls_ac_ss','pls_ec_ss','pls_choice','age_test_pls',
                   'owls_lc_ss','owls_oe_ss','age_test_owls',
                   'celfp_rl_ss','celfp_el_ss','age_test_celp',
                   'celf_elss','celf_rlss','age_test_celf']
language_raw = lsl_dr_project.export_records(fields=language_fields, format='df', df_kwargs={'index_col':None})

# %%
language_raw
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8427 entries, 0 to 8426
# Data columns (total 16 columns):
# study_id             8427  non-null values
# redcap_event_name    8427  non-null values
# age_test_celp        1159  non-null values
# celfp_rl_ss          1081  non-null values
# celfp_el_ss          1080  non-null values
# age_test_celf        604  non-null values
# celf_rlss            461  non-null values
# celf_elss            483  non-null values
# age_test_owls        555  non-null values
# owls_lc_ss           586  non-null values
# owls_oe_ss           577  non-null values
# age_test_pls         2066  non-null values
# pls_choice___0       8427  non-null values
# pls_choice___1       8427  non-null values
# pls_ac_ss            2075  non-null values
# pls_ec_ss            2073  non-null values
# dtypes: float64(12), int64(2), object(2)

# %%
demographic_fields = ['study_id','redcap_event_name','redcap_data_access_group',
'hl','prim_lang','mother_ed','premature_age',
'onset_1','age_int','age','age_ci','degree_hl_ad','type_hl_ad','tech_ad','degree_hl_as',
'type_hl_as','tech_as','etiology','etiology_2', 'sib', 'gender', 'time', 'ad_250', 'as_250']
demographic = lsl_dr_project.export_records(fields=demographic_fields, format='df', 
                                            df_kwargs={'index_col':None, 
                                                       'na_values':{'premature_age':[999],
                                                                    'onset_1':[999],
                                                                    'age_amp':[999],
                                                                    'age_int':[999],
                                                                    'age':[999]}})

# %%
demographic.as_250.hist()

# %% [markdown]
# ## Cleaning languge dataset
#
# 5 language measures:
#
# - 3 versions of CELF
# - PLS
#     - pls_ac_rs: 	PLS: Auditory Comprehension Raw Score
#     - pls_ac_ss: 	PLS: Auditory Comprehension Standard Score
#     - pls_ec_rs: 	PLS: Expressive Communication Raw Score
#     - pls_ec_ss: 	PLS: Expressive Communication Standard Score
#     - pls_tl_rs: 	PLS: Total Language Score Standard Score Total
#     - pls_tl_ss: 	PLS: Total Language Score Standard Score
# - OWLS
#     - age_test_owls: 	Age at time of testing (OWLS)
#     - owls_lc_rs: 	OWLS: Listening Comprehension Raw Score
#     - owls_lc_ss: 	OWLS: Listening Comprehension Standard Score
#     - owls_oe_rs: 	OWLS: Oral Expression Raw Score
#     - owls_oe_ss: 	OWLS: Oral Expression Standard Score
#     - owls_oc_sss: 	OWLS: Oral Composite Sum of Listening Comprehension and Oral Expression Standard Scores
#     - owls_oc_ss: 	OWLS: Oral Composite Standard Score
#     - owls_wes_trs: 	OWLS: Written Expression Scale Total Raw Score
#     - owls_wes_as: 	OWLS: Written Expression Scale Ability Score
#     - owls_wes_ss: 	OWLS: Written Expression Scale Standard Score
#     - owsl_lc: 	OWLS: Written Expression Scale Language Composite (Sum of written expression age-based standard score, listening comprehension standard score and oral expression standard score)
#     - owls_lcss: 	OWLS: Language Composite Standard Score

# %%
# Test type
language_raw["test_name"] = None
language_raw["test_type"] = None
language_raw["score"] = None
CELP = language_raw.age_test_celp.notnull()
CELF = language_raw.age_test_celf.notnull()
PLS = language_raw.age_test_pls.notnull()
OWLS = language_raw.age_test_owls.notnull()

language_raw['age_test'] = None
language_raw['age_test'][CELP] = language_raw.age_test_celp
language_raw['age_test'][CELF] = language_raw.age_test_celf
language_raw['age_test'][PLS] = language_raw.age_test_pls
language_raw['age_test'][OWLS] = language_raw.age_test_owls

language1 = language_raw[CELP | CELF | PLS | OWLS]
language2 = language1.copy()

language1["test_type"] = "receptive"

language1["test_name"][CELP] = "CELF-P2"
language1["test_name"][CELF] = "CELF-4"
language1["test_name"][PLS] = "PLS"
language1["test_name"][OWLS] = "OWLS"

language1["score"][CELP] = language1.celfp_rl_ss
language1["score"][CELF] = language1.celf_rlss
language1["score"][PLS] = language1.pls_ac_ss
language1["score"][OWLS] = language1.owls_lc_ss


language2["test_type"] = "expressive"

language2["test_name"][CELP] = "CELF-P2"
language2["test_name"][CELF] = "CELF-4"
language2["test_name"][PLS] = "PLS"
language2["test_name"][OWLS] = "OWLS"

language2["score"][CELP] = language1.celfp_el_ss
language2["score"][CELF] = language1.celf_elss
language2["score"][PLS] = language1.pls_ec_ss
language2["score"][OWLS] = language1.owls_oe_ss

language = pd.concat([language1, language2])
language = language[language.score.notnull()]
print pd.crosstab(language.test_name, language.test_type)
print("There are {0} null values for score".format(sum(language["score"].isnull())))
# Out:
# test_type  expressive  receptive
# test_name
# CELF-4            355        331
# CELF-P2           824        825
# OWLS              528        537
# PLS              1977       1979
# There are 0 null values for score

# %% [markdown]
# A `school` variable was added, which is the first four columns of the `study_id`:

# %%
language["school"] = language.study_id.str.slice(0,4)

# %%
language = language[["study_id", "score", "test_type", "test_name", "school", "age_test"]]
language["domain"] = "Language"
language.head()
# Out:
#           study_id score  test_type test_name school age_test    domain
# 7   0101-2003-0101    61  receptive      OWLS   0101      113  Language
# 11  0101-2003-0102    55  receptive       PLS   0101       44  Language
# 12  0101-2003-0102    77  receptive       PLS   0101       54  Language
# 13  0101-2003-0102    93  receptive   CELF-P2   0101       68  Language
# 14  0101-2004-0101    50  receptive       PLS   0101       37  Language

# %% [markdown]
# ## Cleaning articulation dataset
#
# We converted the articulation dataset into a "long" format:

# %%
# Test type
articulation["test_type"] = None
ARIZ = articulation.aaps_ss.notnull()
GF = articulation.gf2_ss.notnull()
articulation = articulation[ARIZ | GF]
articulation["test_type"][ARIZ & GF] = "Arizonia and Goldman"
articulation["test_type"][ARIZ & GF-True] = "Arizonia"
articulation["test_type"][ARIZ-True & GF] = "Goldman"

print articulation.test_type.value_counts()
print("There are {0} null values for test_type".format(sum(articulation["test_type"].isnull())))

# Test score (Arizonia if both)
articulation["score"] = articulation.aaps_ss
articulation["score"][ARIZ-True & GF] = articulation.gf2_ss[ARIZ-True & GF]
# Out:
# Goldman                 2787
# Arizonia                 420
# Arizonia and Goldman      18
# dtype: int64
# There are 0 null values for test_type

# %% [markdown]
# A `school` variable was added, which is the first four columns of the `study_id`:

# %%
articulation["school"] = articulation.study_id.str.slice(0,4)

# %% [markdown]
# The age was taken to be the Arizonia age if there are both test types:

# %%
articulation["age_test"] = articulation.age_test_aaps
articulation.age_test[articulation.age_test.isnull()] = articulation.age_test_gf2[articulation.age_test.isnull()]
print articulation.age_test.describe()
# Out:
# count    3223.000000
# mean       66.991623
# std        29.165790
# min         0.000000
# 25%        47.000000
# 50%        59.000000
# 75%        78.000000
# max       243.000000
# dtype: float64

# %% [markdown]
# Finally, we dropped unwanted columns and added a domain identification column for merging:

# %%
articulation.columns
# Out:
# Index([u'study_id', u'redcap_event_name', u'age_test_aaps', u'aaps_ss', u'age_test_gf2', u'gf2_ss', u'test_type', u'score', u'school', u'age_test'], dtype=object)

# %%
articulation = articulation.drop(["redcap_event_name", "age_test_aaps", "age_test_gf2", "aaps_ss", "gf2_ss"], axis=1)
articulation["domain"] = "Articulation"
articulation.head()
# Out:
#           study_id test_type  score school  age_test        domain
# 3   0101-2003-0101   Goldman     78   0101        80  Articulation
# 11  0101-2003-0102   Goldman     72   0101        44  Articulation
# 12  0101-2003-0102   Goldman     97   0101        54  Articulation
# 16  0101-2004-0101   Goldman     75   0101        53  Articulation
# 17  0101-2004-0101   Goldman     80   0101        66  Articulation

# %% [markdown]
# ## Cleaning demographic dataset
#
# We excluded unwanted columns and rows for which age, gender or race were missing:

# %%
# Retain only subset of columns
demographic = demographic[demographic.gender.notnull()]
demographic = demographic.rename(columns={'gender':'male'})

# %% [markdown]
# Due to sample size considerations, we reduced the non-English primary language variable to English (0) and non-English (1):

# %%
demographic["non_english"] = None
demographic.non_english[demographic.prim_lang.notnull()] = demographic.prim_lang[demographic.prim_lang.notnull()]>0
print demographic.non_english.value_counts()
print("There are {0} null values for non_english".format(sum(demographic.non_english.isnull())))
# Out:
# False    2398
# True      493
# dtype: int64
# There are 452 null values for non_english

# %% [markdown]
# Mother's education (`mother_ed`) and father's education (`father_ed`) were both recoded to:
#
# * 0=no high school diploma
# * 1=high school
# * 2=undergraduate
# * 3=graduate
#
# Category 6 (unknown) was recoded as missing.

# %%
demographic = demographic.rename(columns={"mother_ed":"_mother_ed"})
demographic["mother_ed"] = demographic._mother_ed.copy()
demographic.mother_ed[demographic._mother_ed==1] = 0
demographic.mother_ed[(demographic._mother_ed==2) | (demographic.mother_ed==3)] = 1
demographic.mother_ed[demographic._mother_ed==4] = 2
demographic.mother_ed[demographic._mother_ed==5] = 3
demographic.mother_ed[demographic._mother_ed==6] = None
print("_mother_ed:")
print demographic._mother_ed.value_counts()
print("mother_ed:")
print demographic.mother_ed.value_counts()
print("\nThere are {0} null values for mother_ed".format(sum(demographic.mother_ed.isnull())))
# Out:
# _mother_ed:
# 6    873
# 4    589
# 3    394
# 5    326
# 2    250
# 1    111
# 0     48
# dtype: int64
# mother_ed:
# 1    644
# 2    589
# 3    326
# 0    159
# dtype: int64
#
# There are 1625 null values for mother_ed

# %% [markdown]
# Secondary diagnosis

# %%
demographic['secondary_diagnosis'] = demographic.etiology==0

# %%
demographic.secondary_diagnosis.value_counts()
# Out:
# False    2823
# True      520
# dtype: int64

# %%
demographic.secondary_diagnosis.mean()
# Out:
# 0.15554890816631767

# %% [markdown]
# Premature status was recoded to True (premature) and False (full-term). Here, premature indicates <36 weeks.

# %%
demographic['premature_weeks'] = demographic.premature_age.copy()
demographic.premature_weeks[demographic.premature_age==9] = None
demographic.premature_weeks = abs(demographic.premature_weeks-8)*2
print("There are {0} null values for premature_weeks".format(sum(demographic.premature_weeks.isnull())))
# Out:
# There are 1032 null values for premature_weeks

# %%
demographic.premature_weeks.value_counts()
# Out:
# 0     1975
# 2      114
# 4       73
# 12      44
# 6       36
# 10      33
# 8       25
# 14       9
# 16       2
# dtype: int64

# %% [markdown]
# `hearing_loss_birth` was added to indicate whether individuals had hearing loss within the first 3 months of life:

# %%
'''
demographic["hearing_loss_birth"] = pd.Series((demographic.onset==1) | (demographic.onset==3), dtype=object)
demographic.hearing_loss_birth[demographic.onset==2] = None
print("onset:")
print demographic.onset.value_counts()
print("\nhearing_loss_birth:")
print demographic.hearing_loss_birth.value_counts()
print("There are {0} null values for hearing_loss_birth".format(sum(demographic.hearing_loss_birth.isnull())))
'''
# Out:
# '\ndemographic["hearing_loss_birth"] = pd.Series((demographic.onset==1) | (demographic.onset==3), dtype=object)\ndemographic.hearing_loss_birth[demographic.onset==2] = None\nprint("onset:")\nprint demographic.onset.value_counts()\nprint("\nhearing_loss_birth:")\nprint demographic.hearing_loss_birth.value_counts()\nprint("There are {0} null values for hearing_loss_birth".format(sum(demographic.hearing_loss_birth.isnull())))\n'

# %% [markdown]
# Recode impant technology variables for each ear to one of four categories (None, Baha, Hearing aid, Cochlear implant):

# %%
tech_cats = ["None", "Baha", "Hearing aid", "Cochlear"]

demographic["tech_right"] = demographic.tech_ad.copy()
demographic.tech_right[demographic.tech_right==6] = 0
demographic.tech_right[demographic.tech_right==4] = 1
demographic.tech_right[demographic.tech_right==5] = 1
demographic.tech_right[demographic.tech_right==3] = 2
demographic.tech_right[demographic.tech_right==7] = 3
demographic.tech_right = np.abs(demographic.tech_right - 3)

demographic["tech_left"] = demographic.tech_as.copy()
demographic.tech_left[demographic.tech_left==6] = 0
demographic.tech_left[demographic.tech_left==4] = 1
demographic.tech_left[demographic.tech_left==5] = 1
demographic.tech_left[demographic.tech_left==3] = 2
demographic.tech_left[demographic.tech_left==7] = 3
demographic.tech_left = np.abs(demographic.tech_left - 3)

# %% [markdown]
# Substitute valid missing values for hearing loss:

# %%
demographic.type_hl_ad[demographic.type_hl_ad==5] = None
demographic.type_hl_as[demographic.type_hl_as==5] = None

# %% [markdown]
# Create `degree_hl`, which is the maximum level of hearing loss in either ear:

# %%
demographic["degree_hl"] = np.maximum(demographic.degree_hl_ad, demographic.degree_hl_as)

# %% [markdown]
# Create compound indicator variable for each technology (Baha, Hearing aid, Chochlear implant):
#
# * 0=none
# * 1=one ear
# * 2=both ears.

# %%
demographic["baha"] = 0
demographic.baha = demographic.baha.astype(object)
demographic.baha[(demographic.tech_right==1) | (demographic.tech_left==1)] = 1
demographic.baha[(demographic.tech_right==1) & (demographic.tech_left==1)] = 2
demographic.baha[(demographic.tech_right.isnull()) & (demographic.tech_left.isnull())] = None
print("baha:")
print demographic.baha.value_counts()
print("There are {0} null values for baha".format(sum(demographic.baha.isnull())))

demographic["hearing_aid"] = 0
demographic.hearing_aid = demographic.hearing_aid.astype(object)
demographic.hearing_aid[(demographic.tech_right==2) | (demographic.tech_left==2)] = 1
demographic.hearing_aid[(demographic.tech_right==2) & (demographic.tech_left==2)] = 2
demographic.hearing_aid[(demographic.tech_right.isnull()) & (demographic.tech_right.isnull())] = None
print("\nhearing_aid:")
print demographic.hearing_aid.value_counts()
print("There are {0} null values for hearing_aid".format(sum(demographic.hearing_aid.isnull())))

demographic["cochlear"] = 0
demographic.cochlear = demographic.cochlear.astype(object)
demographic.cochlear[(demographic.tech_right==3) | (demographic.tech_left==3)] = 1
demographic.cochlear[(demographic.tech_right==3) & (demographic.tech_left==3)] = 2
demographic.cochlear[(demographic.tech_right.isnull()) & (demographic.tech_left.isnull())] = None
print("\ncochlear:")
print demographic.cochlear.value_counts()
print("There are {0} null values for cochlear".format(sum(demographic.cochlear.isnull())))
print len(demographic)
# Out:
# baha:
# 0    2505
# 1      81
# 2      39
# dtype: int64
# There are 718 null values for baha
#
# hearing_aid:
# 0    1145
# 2    1087
# 1     384
# dtype: int64
# There are 727 null values for hearing_aid
#
# cochlear:
# 0    1528
# 2     637
# 1     460
# dtype: int64
# There are 718 null values for cochlear
# 3343

# %% [markdown]
# Identify bilateral and bimodal individuals:

# %%
demographic["bilateral"] = demographic.cochlear==2
demographic["bimodal"] = (demographic.cochlear==1) & (demographic.hearing_aid==1)

# %%
demographic.bilateral.sum(), demographic.bimodal.sum()
# Out:
# (637, 273)

# %% [markdown]
# Create variable that identifies bilateral (0), bilateral HA left (1), bilateral HA right (2)

# %%
demographic['tech'] = 0
demographic.tech[(demographic.bimodal) & (demographic.tech_left==2)] = 1
demographic.tech[(demographic.bimodal) & (demographic.tech_right==2)] = 2
print("There are {0} null values for tech".format(sum(demographic.tech.isnull())))
# Out:
# There are 0 null values for tech

# %% [markdown]
# Filter out non-bilateral/bimodal individuals:

# %%
demographic = demographic[demographic.bilateral | demographic.bimodal]

# %%
demographic['type'] = np.where(demographic.bilateral, 'bilateral', 'bimodal')

# %%
demographic
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 910 entries, 19 to 8416
# Data columns (total 37 columns):
# study_id               910  non-null values
# redcap_event_name      910  non-null values
# hl                     902  non-null values
# male                   910  non-null values
# prim_lang              796  non-null values
# sib                    792  non-null values
# _mother_ed             719  non-null values
# premature_age          764  non-null values
# onset_1                383  non-null values
# age_int                335  non-null values
# age                    900  non-null values
# etiology               899  non-null values
# etiology_2             420  non-null values
# ad_250                 231  non-null values
# degree_hl_ad           821  non-null values
# type_hl_ad             809  non-null values
# tech_ad                910  non-null values
# age_ci                 321  non-null values
# as_250                 230  non-null values
# degree_hl_as           818  non-null values
# type_hl_as             808  non-null values
# tech_as                910  non-null values
# time                   654  non-null values
# non_english            796  non-null values
# mother_ed              482  non-null values
# secondary_diagnosis    910  non-null values
# premature_weeks        589  non-null values
# tech_right             910  non-null values
# tech_left              910  non-null values
# degree_hl              815  non-null values
# baha                   910  non-null values
# hearing_aid            910  non-null values
# cochlear               910  non-null values
# bilateral              910  non-null values
# bimodal                910  non-null values
# tech                   910  non-null values
# type                   910  non-null values
# dtypes: bool(3), float64(25), int64(1), object(8)

# %%
demographic.sib.value_counts()
# Out:
# 1    316
# 0    196
# 2    145
# 3     95
# 4     40
# dtype: int64

# %% [markdown]
# ## Cleaning expressive vocabulary dataset
#
# We converted the expressive vocabulary dataset to "long" format:

# %%
# Test type
expressive["test_type"] = None
EOWPVT = expressive.eowpvt_ss.notnull()
EVT = expressive.evt_ss.notnull()
expressive = expressive[EOWPVT | EVT]
expressive["test_type"][EOWPVT & EVT] = "EOWPVT and EVT"
expressive["test_type"][EOWPVT & (EVT-True)] = "EOWPVT"
expressive["test_type"][(EOWPVT-True) & EVT] = "EVT"
print("There are {0} null values for test_type".format(sum(expressive["test_type"].isnull())))

expressive["score"] = expressive.eowpvt_ss
expressive["score"][EOWPVT-True & EVT] = expressive.evt_ss[(EOWPVT-True) & EVT]
# Out:
# There are 0 null values for test_type

# %%
expressive.test_type.value_counts()
# Out:
# EVT               2275
# EOWPVT            1564
# EOWPVT and EVT      78
# dtype: int64

# %% [markdown]
# A `school` variable was added, which is the first four columns of the `study_id`:

# %%
expressive["school"] = expressive.study_id.str.slice(0,4)

# %% [markdown]
# The age was taken to be the EOWPVT age if there are both test types:

# %%
expressive["age_test"] = expressive.age_test_eowpvt
expressive.age_test[expressive.age_test.isnull()] = expressive.age_test_evt[expressive.age_test.isnull()]

# %% [markdown]
# Finally, we dropped unwanted columns and added a domain identification column for merging:

# %%
expressive = expressive[["study_id", "score", "test_type", "school", "age_test"]]
expressive["domain"] = "Expressive Vocabulary"
expressive.head()
# Out:
#           study_id  score test_type school  age_test                 domain
# 2   0101-2003-0101     60    EOWPVT   0101        54  Expressive Vocabulary
# 4   0101-2003-0101     84    EOWPVT   0101        80  Expressive Vocabulary
# 7   0101-2003-0101     90    EOWPVT   0101       113  Expressive Vocabulary
# 16  0101-2004-0101     90    EOWPVT   0101        53  Expressive Vocabulary
# 17  0101-2004-0101     87    EOWPVT   0101       NaN  Expressive Vocabulary

# %%
expressive
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3917 entries, 2 to 8426
# Data columns (total 6 columns):
# study_id     3917  non-null values
# score        3917  non-null values
# test_type    3917  non-null values
# school       3917  non-null values
# age_test     3894  non-null values
# domain       3917  non-null values
# dtypes: float64(2), object(4)

# %% [markdown]
# ## Cleaning receptive vocabulary dataset

# %% [markdown]
# We converted the receptive vocabulary data table to "long" format:

# %%
receptive.columns
# Out:
# Index([u'study_id', u'redcap_event_name', u'age_test_ppvt', u'ppvt_ss', u'age_test_rowpvt', u'rowpvt_ss'], dtype=object)

# %%
# Test type
receptive["test_type"] = None
PPVT = receptive.ppvt_ss.notnull()
ROWPVT = receptive.rowpvt_ss.notnull()
receptive = receptive[PPVT | ROWPVT]
receptive["test_type"][PPVT & ROWPVT] = "PPVT and ROWPVT"
receptive["test_type"][PPVT & (ROWPVT-True)] = "PPVT"
receptive["test_type"][(PPVT-True) & ROWPVT] = "ROWPVT"
print("There are {0} null values for test_type".format(sum(receptive["test_type"].isnull())))

receptive["score"] = receptive.ppvt_ss
receptive["score"][(PPVT-True) & ROWPVT] = receptive.rowpvt_ss[(PPVT-True) & ROWPVT]
# Out:
# There are 0 null values for test_type

# %% [markdown]
# A `school` variable was added, which is the first four columns of the `study_id`:

# %%
receptive["school"] = receptive.study_id.str.slice(0,4)

# %% [markdown]
# The age was taken to be the PPVT age if there are both test types:

# %%
receptive["age_test"] = receptive.age_test_ppvt
receptive.age_test[receptive.age_test.isnull()] = receptive.age_test_rowpvt[receptive.age_test.isnull()]

# %%
print("There are {0} null values for age_test".format(sum(receptive.age_test.isnull())))
# Out:
# There are 44 null values for age_test

# %% [markdown]
# Finally, we dropped unwanted columns and added a domain identification column for merging:

# %%
receptive = receptive[["study_id", "score", "test_type", "school", "age_test"]]
receptive["domain"] = "Receptive Vocabulary"
receptive.head()
# Out:
#           study_id  score test_type school  age_test                domain
# 4   0101-2003-0101     90      PPVT   0101        80  Receptive Vocabulary
# 7   0101-2003-0101    101    ROWPVT   0101       113  Receptive Vocabulary
# 11  0101-2003-0102     55      PPVT   0101        44  Receptive Vocabulary
# 12  0101-2003-0102     80      PPVT   0101        54  Receptive Vocabulary
# 13  0101-2003-0102    101      PPVT   0101        68  Receptive Vocabulary

# %% [markdown]
# ## Merge datasets
#
# The four datasets were mereged into a single table. First, we concatenate the test scores data:

# %%
test_scores = pd.concat([articulation, expressive, receptive, language])

# %% [markdown]
# Then we perform a merge between the demographic data and the test scores data:

# %%
test_scores
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18543 entries, 3 to 8426
# Data columns (total 7 columns):
# age_test     18474  non-null values
# domain       18543  non-null values
# school       18543  non-null values
# score        18543  non-null values
# study_id     18543  non-null values
# test_name    7356  non-null values
# test_type    18543  non-null values
# dtypes: object(7)

# %%
lsl_dr = pd.merge(demographic, test_scores, on="study_id")
lsl_dr = lsl_dr[lsl_dr.score.notnull() & lsl_dr.age.notnull() & 
                lsl_dr.age_test.notnull() & lsl_dr.score.notnull()]

# %%
lsl_dr.score = lsl_dr.score.astype(float)

# %%
lsl_dr.shape
# Out:
# (5679, 43)

# %%
lsl_dr.hist(column='age', by=lsl_dr.type)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x10aea6990>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x10aec49d0>], dtype=object)

# %%
def score_summary(domain, bimodal=False):
    subset = lsl_dr[(lsl_dr.domain==domain) & (lsl_dr.bimodal==bimodal)]
    subset['age_test'] = (subset.age_test/12).dropna().astype(int)
    subset.age_test[subset.age_test > 11] = 11
    subset = subset[subset.age_test>1]
    byage = subset.groupby('age_test')
    n = byage.study_id.count()
    mean = byage.score.mean()
    sd = byage.score.std()
    min = byage.score.min()
    max = byage.score.max()
    summary = pd.DataFrame({'Sample Size':n, 'Mean':mean, 
    'SD':sd, 'Min':min, 'Max':max})
    return summary[['Sample Size','Mean','SD','Min','Max']]

# %%
receptive_summary = pd.concat([score_summary("Receptive Vocabulary", bimodal=True), 
                               score_summary("Receptive Vocabulary", bimodal=False)], keys=['bimodal','bilateral'])
receptive_summary
# Out:
#                     Sample Size       Mean         SD  Min  Max
#           age_test
# bimodal   2                  13  90.461538  21.270541   50  128
#           3                  63  81.428571  18.756259   40  140
#           4                  85  85.847059  16.315714   55  131
#           5                  76  82.592105  15.921623   40  114
#           6                  46  78.239130  14.103088   40  102
#           7                  34  74.000000  14.885421   41  103
#           8                  16  69.312500  19.925591   40   93
#           9                  12  67.750000  19.859163   40   98
#           10                 12  75.000000  15.045386   50   93
#           11                 16  65.062500  13.313996   45   92
# bilateral 2                  48  90.354167  18.499557   40  129
#           3                 168  86.636905  20.820426   36  141
#           4                 208  87.947115  19.026097   40  139
#           5                 147  84.986395  16.794074   40  123
#           6                  87  82.459770  14.466324   40  118
#           7                  67  80.597015  13.389344   42  110
#           8                  39  74.948718  13.502336   44  112
#           9                  27  71.851852  23.896739   25  160
#           10                 20  69.550000  12.193506   37   97
#           11                 30  68.866667  20.215619   20  123

# %%
def plot_summary(summary_data, var='Sample Size', color='seagreen'):
    fig, axes = plt.subplots(nrows=1, ncols=2)
    var = 'Sample Size'
    for m,mode in enumerate(['bimodal', 'bilateral']):
        summary_data.ix[mode][var].plot(ax=axes[m], kind='bar', grid=False, color=color)
        axes[m].set_title(mode)
        for i,x in enumerate(summary_data.ix[mode][var]):
            axes[m].annotate('%i' % x, (i+0.5, x+1), va="bottom", ha="center")

# %%
plot_summary(receptive_summary)

# %%
expressive_summary = pd.concat([score_summary("Expressive Vocabulary", bimodal=True), 
                               score_summary("Expressive Vocabulary", bimodal=False)], keys=['bimodal','bilateral'])
expressive_summary
# Out:
#                     Sample Size       Mean         SD  Min  Max
#           age_test
# bimodal   2                  18  88.000000  20.556951   55  123
#           3                  56  82.125000  21.902314   50  145
#           4                  83  86.927711  19.860970   54  140
#           5                  75  83.746667  18.445752   45  130
#           6                  45  77.155556  14.934639   47  106
#           7                  34  75.588235  16.487126   38  107
#           8                  15  74.600000  18.764709   40   99
#           9                  10  74.000000  18.666667   55  113
#           10                 12  79.166667  17.836802   52  100
#           11                 17  75.176471  10.932951   58  100
# bilateral 2                  48  90.979167  27.183764   23  141
#           3                 163  87.171779  23.884391   39  145
#           4                 205  88.136585  21.889224   28  140
#           5                 150  85.760000  18.194947   40  130
#           6                  89  84.595506  15.747813   45  112
#           7                  69  83.797101  15.028972   59  130
#           8                  36  78.555556  14.606152   55  113
#           9                  26  75.576923  22.022122   36  145
#           10                 21  74.238095  11.991267   55   94
#           11                 28  77.285714  20.899862   36  139

# %%
plot_summary(expressive_summary)

# %%
articulation_summary = pd.concat([score_summary("Articulation", bimodal=True), 
                               score_summary("Articulation", bimodal=False)], keys=['bimodal','bilateral'])
articulation_summary
# Out:
#                     Sample Size       Mean         SD  Min  Max
#           age_test
# bimodal   2                  10  88.100000  12.931014   63  103
#           3                  43  76.767442  14.994979   50  101
#           4                  70  76.600000  20.690543   39  119
#           5                  69  77.971014  18.753800   40  111
#           6                  40  76.075000  21.235417   39  109
#           7                  32  71.656250  21.261216   39  108
#           8                  14  68.642857  26.444738   40  106
#           9                  10  75.100000  20.195984   40  106
#           10                  9  75.333333  16.000000   40   94
#           11                 15  79.533333  14.196914   55  103
# bilateral 2                  36  81.222222  15.012587   53  110
#           3                 122  77.311475  18.968038   40  120
#           4                 170  79.570588  20.147629   40  118
#           5                 138  78.913043  21.145474   39  113
#           6                  83  76.313253  20.745218   39  110
#           7                  64  78.906250  20.905470   35  107
#           8                  25  71.160000  23.497659   40  103
#           9                  16  72.500000  24.413111   40  106
#           10                 15  72.933333  22.400468   40  100
#           11                 15  74.266667  16.649610   47  100

# %%
plot_summary(articulation_summary)

# %%
language_summary = pd.concat([score_summary("Language", bimodal=True), 
                               score_summary("Language", bimodal=False)], keys=['bimodal','bilateral'])
language_summary
# Out:
#                     Sample Size       Mean         SD  Min  Max
#           age_test
# bimodal   2                  62  79.548387  20.211730   52  150
#           3                 133  74.969925  16.520850   50  132
#           4                 140  76.571429  17.004503   45  124
#           5                 116  77.862069  17.420077   45  114
#           6                  58  70.655172  15.372055   47  115
#           7                  62  65.096774  16.405427   45   98
#           8                  24  62.875000  18.097111   45  115
#           9                   8  51.250000   7.611082   40   61
#           10                  2  90.000000   2.828427   88   92
#           11                 12  92.500000  14.945355   71  115
# bilateral 2                 199  80.663317  20.925124   50  146
#           3                 362  80.640884  21.436327   50  145
#           4                 362  80.030387  20.347444   48  141
#           5                 285  77.077193  17.954000   45  129
#           6                 150  72.166667  18.146835   44  115
#           7                 131  68.541985  18.541123   40  108
#           8                  57  66.298246  19.232566   40   99
#           9                  16  73.062500  21.889019   40  102
#           10                 14  64.285714  21.762454   40  110
#           11                  4  67.250000  26.272609   40   94

# %%
for t in language.test_type.value_counts().index:
    lsl_dr[lsl_dr.test_type==t].boxplot(column='score', by='bimodal')
    xlabel(t)

# %%
demographic.bimodal.sum()
# Out:
# 273

# %%
demographic.bilateral.sum()
# Out:
# 637

# %%
bim,bil = lsl_dr.groupby('bimodal')['score'].mean().values

# %%
lsl_dr.domain.unique()
# Out:
# array(['Articulation', 'Expressive Vocabulary', 'Receptive Vocabulary',
#        'Language'], dtype=object)

# %%
dataset = lsl_dr[(lsl_dr.domain=='Receptive Vocabulary') ]
fig, axes = subplots(10, 4, figsize=(14,20), sharey=True, sharex=True)
axes = axes.ravel()
for i,school in enumerate(dataset.school.unique()):
    subset = dataset[dataset.school==school]
    score = subset.score
    bimodal = subset.bimodal + np.random.randn(len(subset))*0.01
    axes[i].scatter(bimodal, score, alpha=0.4)
    means = subset.groupby('bimodal')['score'].mean().values
    if len(means)==2:
        axes[i].plot([0,1], means)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-161-8466486c9a77> in <module>()
#       6     score = subset.score
#       7     bimodal = subset.bimodal + np.random.randn(len(subset))*0.01
# ----> 8     axes[i].scatter(bimodal, score, alpha=0.4)
#       9     means = subset.groupby('bimodal')['score'].mean().values
#      10     if len(means)==2:
#
# IndexError: index out of bounds

# %%
for i,p in enumerate(paper_list):
    phe = observations[(observations['Paper ID']==p)].Phe
    phe[phe.isnull()] = observations[(observations['Paper ID']==p)][phe.isnull()]['Phe high']
    iq = observations[(observations['Paper ID']==p)].IQ
    m,b = np.polyfit(phe, iq, 1)
    axes[i].scatter(phe, iq)
    xvals = np.linspace(0,2000)
    axes[i].plot(xvals, m*xvals+b)
    xlim(0, 2000)

# %%
lsl_dr.to_csv("/Users/fonnescj/hierarchical_modeling/data/testscore.csv")

# %% [markdown]
# ## Test Score Model

# %% [markdown]
# ### PyMC 3 version

# %%
del test_score_model

# %%
from pymc import Model, Bernoulli, Normal, Uniform, DiscreteUniform, Gamma, Lognormal
import theano.tensor as T
from theano import function, shared

dataset = lsl_dr[lsl_dr.domain=='Language']

with Model() as test_score_model:
    
    # Extract data to local variables
    age = dataset.age.values/12.
    school = dataset.school.values
    study_id = dataset.study_id.values
    score = dataset.score.values
    bimodal = dataset.bimodal.values
    male = dataset.male.values
    
    # Transform some data
    age_std = age - age.mean()
    
    test_mean_score = Normal("test_mean_score", 0, 0.001, shape=2)
    
    E = (dataset.test_type=='expressive').values.astype(int)
    mean_score = test_mean_score[E]
    
    # Indices to school random effects
    unique_schools = np.unique(school)
    school_index = [list(unique_schools).index(s) for s in school]
    
    # School random effect
    sigma_school = Uniform("sigma_school", 0, 1000)
    tau_school = sigma_school**-2
    alpha_school = Normal("alpha_school", mu=0, tau=tau_school, shape=len(unique_schools))
    
    # Indices to child random effects
    unique_child = np.unique(study_id)
    child_index = [list(unique_child).index(s) for s in study_id]
    
    # Individual random effect
    sigma_child = Uniform("sigma_child", 0, 1000)
    tau_child = sigma_child**-2    
    alpha_child = Normal("alpha_child", mu=50, tau=tau_child, shape=len(unique_child))
    
    # Random intercepts
    intercept = mean_score + alpha_child[child_index] + alpha_school[school_index]
    
    # Male effect
    beta_male = Normal("beta_male", mu=0, tau=0.001)
    
    # Bimodal effect (relative to bilateral)
    beta_bimodal = Normal("beta_bimodal", mu=0, tau=0.001)
    
    # Bimodal-male interaction
    beta_bxm = Normal("beta_bxm", mu=0, tau=0.001)
    
    # Age effect
    beta_age = Normal("beta_age", mu=0, tau=0.001)
    
    # Age-male interaction
    beta_axm = Normal("beta_axm", mu=0, tau=0.001)
    
    betas = [beta_male, beta_bimodal, beta_bxm, beta_age, beta_axm]
    
    theta = intercept + beta_male*male + beta_bimodal*bimodal + beta_age*age_std
    theta += beta_bxm*bimodal*male + beta_axm*age_std*male
    
    sigma = Uniform("sigma", 0, 1000)
    tau = sigma**-2
    
    # Data likelihood
    score_like = Lognormal("score_like", mu=theta, tau=tau, observed=score)

# %%
from pymc import find_MAP, NUTS, sample, Metropolis, psample

with test_score_model:
    step = NUTS()

    trace = psample(2000, step, trace=test_score_model.named_vars, threads=2)

# %%
burn = 1000
foo = MultiTrace([t[1000:] for t in trace.traces])

# %%
foo['sigma_child'][0].shape
# Out:
# (1000,)

# %%
from pymc import NpTrace
NpTrace(trace['sigma_child'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-110-ed21e730edc0> in <module>()
#       1 from pymc import NpTrace
# ----> 2 NpTrace(trace['sigma_child'])
#
# /Users/fonnescj/Code/pymc3/pymc/trace.pyc in __init__(self, vars)
#      12     """
#      13     def __init__(self, vars):
# ---> 14         self.f = compilef(vars)
#      15         self.vars = vars
#      16         self.varnames =map(str, vars)
#
# /Users/fonnescj/Code/pymc3/pymc/memoize.pyc in memoizer(*args, **kwargs)
#      12
#      13         if key not in cache:
# ---> 14             cache[key] = obj(*args, **kwargs)
#      15
#      16         return cache[key]
#
# /Users/fonnescj/Code/pymc3/pymc/model.pyc in compilef(outs, mode)
#     174     """
#     175     return PointFunc(
# --> 176         function(inputvars(outs), outs,
#     177                  allow_input_downcast=True,
#     178                  on_unused_input='ignore',
#
# /Users/fonnescj/Code/pymc3/pymc/theanof.pyc in inputvars(a)
#      18         r : list of tensor variables that are inputs
#      19     """
# ---> 20     return [v for v in inputs(makeiter(a)) if isinstance(v, t.TensorVariable)]
#      21
#      22 def cont_inputs(f):
#
# /Library/Python/2.7/site-packages/theano/gof/graph.pyc in inputs(variable_list, blockers)
#     569
#     570     """
# --> 571     vlist = ancestors(variable_list, blockers)
#     572     rval = [r for r in vlist if r.owner is None]
#     573     return rval
#
# /Library/Python/2.7/site-packages/theano/gof/graph.pyc in ancestors(variable_list, blockers)
#     553             l.reverse()
#     554             return l
# --> 555     dfs_variables = stack_search(deque(variable_list), expand, 'dfs')
#     556     return dfs_variables
#     557
#
# /Library/Python/2.7/site-packages/theano/gof/graph.pyc in stack_search(start, expand, mode, build_inv)
#     524             rval_list.append(l)
#     525             rval_set.add(id(l))
# --> 526             expand_l = expand(l)
#     527             if expand_l:
#     528                 if build_inv:
#
# /Library/Python/2.7/site-packages/theano/gof/graph.pyc in expand(r)
#     549     """
#     550     def expand(r):
# --> 551         if r.owner and (not blockers or r not in blockers):
#     552             l = list(r.owner.inputs)
#     553             l.reverse()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'owner'

# %%
from pymc import traceplot
traceplot(MultiTrace([t[1000:] for t in trace.traces]), vars=['sigma_child', 'sigma_school'])

# %%
traceplot(MultiTrace([t[1000:] for t in trace.traces]), vars=['beta_male', 'beta_bimodal', 'beta_bxm', 'beta_age', 'beta_axm'])

# %%
forestplot(MultiTrace(trace[1000:]), 
        vars=['beta_male', 'beta_bimodal', 'beta_bxm', 'beta_age', 'beta_axm'])

# %%
from pymc import forestplot

forestplot(trace, vars=['beta_male', 'beta_bimodal', 'beta_bxm', 'beta_age', 'beta_axm'])

# %%
forestplot(trace, vars=['sigma_child', 'sigma_school'])

# %% [markdown]
# ### PyMC 2 version

# %%
from pymc import Bernoulli, Normal, Uniform, invlogit, logit, deterministic, MCMC, Matplot
from pymc import Lambda, Dirichlet, Categorical, DiscreteUniform, Exponential, Gamma, Lognormal

def generate_model(dataset):
    
    # Extract data to local variables
    school = np.array(dataset.school)
    study_id = np.array(dataset.study_id)
    score = np.array(dataset.score)
    bimodal = np.array(dataset.bimodal)
    male = np.array(dataset.male)
    time = np.array(dataset.time)
    age = np.array(dataset.age)/12.
    
    # Center age variable and change to year
    age_centered = age - age.mean()
    
    # Dummy variables for test name: [CELF-4, CELF-P2, OWLS]
    # (PLS is baseline)
    test_name = np.array(pd.get_dummies(dataset.test_name).drop('PLS', axis=1))
    
    # Imputation of time
    alpha_time = Gamma('alpha_time', 1, 0.1, value=1)
    mu_time = Gamma('mu_time', 1, 0.1, value=1)
    time_masked = np.ma.masked_array(dataset.time.values, dataset.time.isnull(), 
                                         fill_value=10)
    time = NegativeBinomial('time', mu_time, alpha_time, value=time_masked, observed=True)
    
    # Imputation of sibling count
    sib_masked = np.ma.masked_array(dataset.sib.values, dataset.sib.isnull(),
                                     fill_value=6)
    sib = DiscreteUniform('sib', 0, 6, value=sib_masked, observed=True)
    
    # Test type mean: 0=receptive, 1=expressive
    test_mean_score = Normal("test_mean_score", 0, 0.001, value=[100]*2)
#     test_type_rec = Normal('test_type_rec', 0, 0.001, value=[0]*3)
#     test_type_exp = Normal('test_type_exp', 0, 0.001, value=[0]*3)
    
#     @deterministic
#     def mean_score(b0=test_mean_score, br=test_type_rec, be=test_type_exp):
#         E = (dataset.test_type=='expressive').values.astype(int)
#         R = (dataset.test_type=='receptive').values.astype(int)
#         return b0[E] + R*(test_name.dot(br)) + E*(test_name.dot(be))
    @deterministic
    def mean_score(b0=test_mean_score):
        E = (dataset.test_type=='expressive').values.astype(int)
        return b0[E]
    
    # Indices to school random effects
    unique_schools = np.unique(school)
    school_index = [list(unique_schools).index(s) for s in school]

    # School random effect
    sigma_school = Uniform("sigma_school", 0, 1000, value=1)
    tau_school = sigma_school**-2
    alpha_school = Normal("alpha_school", mu=0, tau=tau_school, value=np.zeros(len(unique_schools)))
    
    # Indices to child random effects
    unique_child = np.unique(study_id)
    child_index = [list(unique_child).index(s) for s in study_id]
    
    # Individual random effect
    sigma_child = Uniform("sigma_child", 0, 1000, value=1)
    tau_child = sigma_child**-2    
    alpha_child = Normal("alpha_child", mu=50, tau=tau_child, value=np.zeros(len(unique_child)))
    
    @deterministic
    def intercept(a0=mean_score, a1=alpha_child):
        """Random intercepts"""
        return a0 + a1[child_index]
    
    # Male effect
    beta_male = Normal("beta_male", mu=0, tau=0.001, value=0)
    
    # Bimodal effect (relative to bilateral)
    beta_bimodal = Normal("beta_bimodal", mu=0, tau=0.001, value=0)
    
    # Bimodal-male interaction
    beta_bm = Normal("beta_bm", mu=0, tau=0.001, value=0)
    
    # Age effect
    beta_age = Normal("beta_age", mu=0, tau=0.001, value=0)
    
    # Age-male interaction
    beta_am = Normal("beta_am", mu=0, tau=0.001, value=0)
    
    betas = [beta_male, beta_bimodal, beta_age, beta_bm, beta_am]
    
    @deterministic
    def theta(b0=intercept, b=betas, xt=time, xs=sib):

        return b0 + b[0]*male + b[1]*bimodal + b[2]*age + b[3]*bimodal*male + b[4]*age*male
            
    sigma = Uniform("sigma", 0, 1000, value=10)
    tau = sigma**-2
    
    # Data likelihood
    score_like = Lognormal("score_like", mu=theta, tau=tau, value=score, observed=True)
    #score_like_pred = Normal("score_like_pred", mu=theta, tau=tau, value=score)
    
    return MCMC(locals())

# %%
data_lang.bimodal.sum(),data_lang.shape[0]
# Out:
# (475, 1812)

# %%
from pymc import AdaptiveMetropolis
data_lang = lsl_dr[(lsl_dr.domain=='Language') & (lsl_dr.non_english==False)]
Mlang = generate_model(data_lang)
#Mlang.use_step_method(AdaptiveMetropolis, Mlang.betas)

# %%
Mlang.sample(20000, 10000)
# Out:
#  [                  0%                  ] 86 of 20000 complete in 0.5 sec
#  [                  0%                  ] 195 of 20000 complete in 1.0 sec
#  [                  1%                  ] 288 of 20000 complete in 1.5 sec
#  [                  2%                  ] 400 of 20000 complete in 2.0 sec
#  [                  2%                  ] 518 of 20000 complete in 2.5 sec
#  [-                 3%                  ] 636 of 20000 complete in 3.0 sec
#  [-                 3%                  ] 754 of 20000 complete in 3.5 sec
#  [-                 4%                  ] 871 of 20000 complete in 4.0 sec
#  [-                 4%                  ] 985 of 20000 complete in 4.5 sec
#  [--                5%                  ] 1102 of 20000 complete in 5.0 sec
#  [--                6%                  ] 1212 of 20000 complete in 5.5 sec
#  [--                6%                  ] 1326 of 20000 complete in 6.0 sec
#  [--                7%                  ] 1443 of 20000 complete in 6.5 sec
#  [--                7%                  ] 1561 of 20000 complete in 7.0 sec
#  [---               8%                  ] 1678 of 20000 complete in 7.5 sec
#  [---               8%                  ] 1795 of 20000 complete in 8.0 sec
#  [---               9%                  ] 1913 of 20000 complete in 8.5 sec
#  [---              10%                  ] 2031 of 20000 complete in 9.0 sec
#  [----             10%                  ] 2145 of 20000 complete in 9.5 sec
#  [----             11%                  ] 2256 of 20000 complete in 10.0 sec
#  [----             11%                  ] 2369 of 20000 complete in 10.5 sec
#  [----             12%                  ] 2484 of 20000 complete in 11.0 sec
#  [----             13%                  ] 2601 of 20000 complete in 11.6 sec
#  [-----            13%                  ] 2712 of 20000 complete in 12.1 sec
#  [-----            14%                  ] 2826 of 20000 complete in 12.6 sec
#  [-----            14%                  ] 2940 of 20000 complete in 13.1 sec
#  [-----            15%                  ] 3052 of 20000 complete in 13.6 sec
#  [------           15%                  ] 3162 of 20000 complete in 14.1 sec
#  [------           16%                  ] 3273 of 20000 complete in 14.6 sec
#  [------           16%                  ] 3385 of 20000 complete in 15.1 sec
#  [------           17%                  ] 3487 of 20000 complete in 15.6 sec
#  [------           17%                  ] 3584 of 20000 complete in 16.1 sec
#  [-------          18%                  ] 3692 of 20000 complete in 16.6 sec
#  [-------          19%                  ] 3805 of 20000 complete in 17.1 sec
#  [-------          19%                  ] 3896 of 20000 complete in 17.6 sec
