# %%
# Import modules and set options
import pandas as pd
import numpy as np
pd.set_option('display.notebook_repr_html', False)
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 25)
rcParams['savefig.dpi'] = 120

# %% [markdown]
# Connect to database to import data for the three test domains and demographic information:

# %%
from redcap import Project
api_url = 'https://redcap.vanderbilt.edu/api/'
api_key = open("/Users/fonnescj/Dropbox/LSL-DR/api_token.txt").read()

lsl_dr_project = Project(api_url, api_key)

# %%
metadata = lsl_dr_project.export_metadata(fields=['etiology'])

# %%
metadata
# Out:
# [{u'branching_logic': u'',
#   u'custom_alignment': u'',
#   u'field_label': u'Study ID',
#   u'field_name': u'study_id',
#   u'field_note': u'{Geographic-School ID (0000)]-[Enrolled Year (YYYY)]-[Student ID (0000)] ex 0109-2010-0001',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'',
#   u'custom_alignment': u'',
#   u'field_label': u'Enter academic year',
#   u'field_name': u'academic_year',
#   u'field_note': u'0000-0000 (i.e., 2010-2011)',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'Y',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'',
#   u'custom_alignment': u'',
#   u'field_label': u'Does the child have a hearing loss?',
#   u'field_name': u'hl',
#   u'field_note': u'',
#   u'field_type': u'radio',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'Y',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Yes \\n 1, No \\n 2, Suspected but not diagnosed \\n 3, Unknown',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'',
#   u'custom_alignment': u'',
#   u'field_label': u'Select from the following choices:',
#   u'field_name': u'demo_sel',
#   u'field_note': u'',
#   u'field_type': u'checkbox',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u"0, Initial assessment/enrollment data entry \\n 1, No changes from the previous year \\n 3, Change in primary language spoken in the home \\n 4, Change in number of children in the home \\n 5, Change in mother's educational level \\n 6, Change in father's educational level \\n 7, Changes in diagnosis \\n8, Change in impact of the other combined conditions that contribute to the child's overall learning abilities",
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[demo_sel(0)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Gender',
#   u'field_name': u'gender',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'Demographics/Medical History',
#   u'select_choices_or_calculations': u'0, Female \\n 1, Male',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[demo_sel(0)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Race',
#   u'field_name': u'race',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Caucasian \\n 1, Black or African American \\n 2, Hispanic or Latino \\n 3, Asian \\n 4, Native Hawaiians/Pacific Islanders \\n 5, American Indian/Alaska Natives \\n 6, Multiracial \\n 7, Unknown \\n 8, Other',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[race]="8"',
#   u'custom_alignment': u'',
#   u'field_label': u'If other, please enter here',
#   u'field_name': u'race_other',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[demo_sel(0)]="1" or [demo_sel(3)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Primary language spoken at home',
#   u'field_name': u'prim_lang',
#   u'field_note': u'Select only one',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, English \\n 1, Spanish \\n 2, Chinese \\n 3, French \\n 4, German \\n 5, Tagalong \\n 6, Other',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[prim_lang]="6"',
#   u'custom_alignment': u'',
#   u'field_label': u'If other, please enter here',
#   u'field_name': u'prim_lang_other',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[demo_sel(0)]="1" or [demo_sel(4)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Total number of children in the home ',
#   u'field_name': u'sib',
#   u'field_note': u'Include study child in this number',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, 1 child (study child) \\n 1, 2 children \\n 2, 3 children \\n 3, 4 or more children \\n 4, Unknown',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[demo_sel(0)]="1" or [demo_sel(5)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u"Mother's educational level",
#   u'field_name': u'mother_ed',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u"0, 8th grade or less \\n 1, Some high school \\n 2, High school diploma/GED \\n 3, Some college \\n 4, Bachelor's degree \\n 5, Post graduate degree \\n 6, Unknown",
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[demo_sel(0)]="1" or [demo_sel(6)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u"Father's educational level",
#   u'field_name': u'father_ed',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u"0, 8th grade or less \\n 1, Some high school \\n 2, High school diploma/GED \\n 3, Some college \\n 4, Bachelor's degree \\n 5, Post graduate degree \\n 6, Unknown",
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[demo_sel(0)] = "1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Parental hearing status since childhood',
#   u'field_name': u'parent_hl',
#   u'field_note': u'Congenital/early childhood hearing loss onset',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Both parents do not have a hearing loss \\n 1, Both parents have hearing loss \\n 2, Mother has hearing loss \\n 3, Father has hearing loss \\n 4, Unknown',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[demo_sel(0)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Age of gestation',
#   u'field_name': u'premature_age',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'Medical History',
#   u'select_choices_or_calculations': u'8, Full term (36 weeks or greater) \\n 7, 34 weeks to 35 weeks, 6 days \\n 6, 32 weeks to 33 weeks, 6 days \\n 5, 30 weeks to 31 weeks, 6 days \\n 4, 28 weeks to 29 weeks, 6 days \\n 3, 26 weeks to 27 weeks, 6 days \\n 2, 24 weeks to 25 weeks, 6 days \\n 1, 22 weeks to 23 weeks, 6 days \\n 0, Less than 22 weeks \\n 9, Unknown',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hl]="0" and [demo_sel(0)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Age when hearing loss diagnosed',
#   u'field_name': u'onset_1',
#   u'field_note': u'Enter the age in months',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'300',
#   u'text_validation_min': u'0',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hl]="0" and [demo_sel(0)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Age when first amplified (i.e., hearing aids, cochlear implant, etc.)',
#   u'field_name': u'age_amp',
#   u'field_note': u'Enter the age in months',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'300',
#   u'text_validation_min': u'0',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hl]="0" and [demo_sel(0)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Age when any intervention began (e.g., speech-language services, deaf education services, early intervention, etc.)',
#   u'field_name': u'age_int',
#   u'field_note': u'Enter the age in months',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'300',
#   u'text_validation_min': u'0',
#   u'text_validation_type_or_show_slider_number': u'integer'},
#  {u'branching_logic': u'[demo_sel(0)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Age when child entered your program ',
#   u'field_name': u'age',
#   u'field_note': u'Enter the age in months',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'300',
#   u'text_validation_min': u'0',
#   u'text_validation_type_or_show_slider_number': u'integer'},
#  {u'branching_logic': u'[demo_sel(7)]="1" or [demo_sel(0)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Child has a known medical diagnosis',
#   u'field_name': u'med_cause',
#   u'field_note': u'',
#   u'field_type': u'radio',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Yes, diagnosis made by a physician \\n 1, No \\n 2, Suspected but not diagnosed \\n 3, Unknown',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[med_cause]="0" ',
#   u'custom_alignment': u'',
#   u'field_label': u'Select the known medical diagnoses made by the physician',
#   u'field_name': u'etiology_4',
#   u'field_note': u'',
#   u'field_type': u'checkbox',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Connexin \\n 1, Cytomegalovirus (CMV) \\n 2, ECHMO \\n 3, Enlarged Vestibular Aqueducts \\n 4, Genetic other than Connexin \\n 5, Meningitis \\n 12, Microtia/Atresia \\n 6, Mondini Malformation \\n 7, Ototoxic Medication \\n 8, Persistent Pulmonary Hypertension of the Newborn (PPHN) \\n 9, Rubella \\n 10, Syphilis \\n 11, Other',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[etiology_4(11)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'If other, please enter known medical cause of hearing loss',
#   u'field_name': u'etiology_4_oth',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[demo_sel(7)]="1" or [demo_sel(0)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Child has a known syndrome',
#   u'field_name': u'synd_cause',
#   u'field_note': u'',
#   u'field_type': u'radio',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Yes, diagnosis made by a physician \\n 1, No \\n 2, Suspected but not diagnosed \\n 3, Unknown',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[synd_cause]="0"',
#   u'custom_alignment': u'',
#   u'field_label': u'Select known syndrome diagnosed by physician',
#   u'field_name': u'etiology_3',
#   u'field_note': u'',
#   u'field_type': u'checkbox',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Alport \\n 1, CHARGE \\n 2, Cornelia deLange \\n 3, Crouzon \\n 4, DeGeorges \\n 5, Down \\n 6, Fetal Alcohol \\n 7, Fragile X \\n 8, Friedreich Ataxia \\n 9, Hunter/Hurler \\n 10, Pendred \\n 11, Pierre Robin Sequence \\n 12, Treacher Collins \\n 13, Usher \\n 14, Waardenburg \\n 15, Other',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[etiology_3(15)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'If other, please enter known syndrome',
#   u'field_name': u'etiology_3_oth',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[demo_sel(7)]="1" or [demo_sel(0)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Child has another diagnosed disability(s)',
#   u'field_name': u'etiology',
#   u'field_note': u'',
#   u'field_type': u'radio',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Yes, diagnosis made by a physician \\n 1, No \\n 2, Suspected but not diagnosed \\n 3, Unknown',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[etiology]="0" ',
#   u'custom_alignment': u'',
#   u'field_label': u'Select other diagnosed disabilities',
#   u'field_name': u'etiology_oth',
#   u'field_note': u'',
#   u'field_type': u'checkbox',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Apraxia \\n 1, Autism \\n 12, Attention Deficit Disorder (ADD)/Attention Deficit Hyperactivity Disorder (ADHD) \\n 2, Blind/Cortical Vision Impairment \\n 3, Developmental Delay/Disorder \\n 4, Emotional Disturb/Mental Health \\n 5, Oral Motor \\n 6, Orthopedic Impairment \\n 7, Sensory Integration \\n 8, Specific Learning Disability \\n 9, Traumatic Brain Injury (TBI) \\n 10, Vision Impairment (corrected with glasses) \\n 11, Other Health Impairment (OHI)',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[etiology_oth(11)]="1" ',
#   u'custom_alignment': u'',
#   u'field_label': u'If other, please enter here',
#   u'field_name': u'etiology_oth_ohi',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[demo_sel(0)]="1" or [demo_sel(8)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u"Rate the impact of the other combined condition(s), if applicable, that contribute to the child's overall learning abilities",
#   u'field_name': u'etiology_2',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, None \\n 1, Mild \\n 2, Moderate \\n 3, Severe \\n 4, N/A (no additional disability suspected or identified)',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hl]="0" ',
#   u'custom_alignment': u'',
#   u'field_label': u'Please select from the following choices:',
#   u'field_name': u'hearing_changes',
#   u'field_note': u'',
#   u'field_type': u'radio',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'Audiology',
#   u'select_choices_or_calculations': u'0, Initial assessment/enrollment year or changes in both ears in subsequent years \\n 1, Changes in audiological information in the right ear only \\n 2, Changes in the audiological information in the left ear only \\n 3, No changes from the previous year',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u"[hearing_changes] = '0' or [hearing_changes] = '1'",
#   u'custom_alignment': u'',
#   u'field_label': u'Age at time of testing ',
#   u'field_name': u'ae',
#   u'field_note': u'Enter the age in months',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'300',
#   u'text_validation_min': u'0',
#   u'text_validation_type_or_show_slider_number': u'integer'},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Right Ear: 250 Hz',
#   u'field_name': u'ad_250',
#   u'field_note': u'dB Unaided Behavioral Thresholds',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'Audiology: Right Ear',
#   u'select_choices_or_calculations': u'0, 0 \\n 5, 5 \\n 10, 10 \\n 15, 15 \\n 20, 20 \\n 25, 25 \\n 30, 30 \\n 35, 35 \\n 40, 40 \\n 45, 45 \\n 50, 50 \\n 55, 55 \\n 60, 60 \\n 65, 65 \\n 70, 70 \\n 75, 75 \\n 80, 80 \\n 85, 85 \\n 90, 90 \\n 95, 95 \\n 100, 100 \\n 105, 105 \\n 110, 110 \\n 115, 115 \\n 120, 120+',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Right Ear: 500 Hz',
#   u'field_name': u'ad_500',
#   u'field_note': u'dB Unaided Behavioral Thresholds',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, 0 \\n 5, 5 \\n 10, 10 \\n 15, 15 \\n 20, 20 \\n 25, 25 \\n 30, 30 \\n 35, 35 \\n 40, 40 \\n 45, 45 \\n 50, 50 \\n 55, 55 \\n 60, 60 \\n 65, 65 \\n 70, 70 \\n 75, 75 \\n 80, 80 \\n 85, 85 \\n 90, 90 \\n 95, 95 \\n 100, 100 \\n 105, 105 \\n 110, 110 \\n 115, 115 \\n 120, 120+',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Right Ear: 1000 Hz',
#   u'field_name': u'ad_1000',
#   u'field_note': u'dB Unaided Behavioral Thresholds',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, 0 \\n 5, 5 \\n 10, 10 \\n 15, 15 \\n 20, 20 \\n 25, 25 \\n 30, 30 \\n 35, 35 \\n 40, 40 \\n 45, 45 \\n 50, 50 \\n 55, 55 \\n 60, 60 \\n 65, 65 \\n 70, 70 \\n 75, 75 \\n 80, 80 \\n 85, 85 \\n 90, 90 \\n 95, 95 \\n 100, 100 \\n 105, 105 \\n 110, 110 \\n 115, 115 \\n 120, 120+',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Right Ear: 2000 Hz',
#   u'field_name': u'ad_2000',
#   u'field_note': u'dB Unaided Behavioral Thresholds',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, 0 \\n 5, 5 \\n 10, 10 \\n 15, 15 \\n 20, 20 \\n 25, 25 \\n 30, 30 \\n 35, 35 \\n 40, 40 \\n 45, 45 \\n 50, 50 \\n 55, 55 \\n 60, 60 \\n 65, 65 \\n 70, 70 \\n 75, 75 \\n 80, 80 \\n 85, 85 \\n 90, 90 \\n 95, 95 \\n 100, 100 \\n 105, 105 \\n 110, 110 \\n 115, 115 \\n 120, 120+',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Right Ear: 4000 Hz',
#   u'field_name': u'ad_4000',
#   u'field_note': u'dB Unaided Behavioral Thresholds',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, 0 \\n 5, 5 \\n 10, 10 \\n 15, 15 \\n 20, 20 \\n 25, 25 \\n 30, 30 \\n 35, 35 \\n 40, 40 \\n 45, 45 \\n 50, 50 \\n 55, 55 \\n 60, 60 \\n 65, 65 \\n 70, 70 \\n 75, 75 \\n 80, 80 \\n 85, 85 \\n 90, 90 \\n 95, 95 \\n 100, 100 \\n 105, 105 \\n 110, 110 \\n 115, 115 \\n 120, 120+',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Right Ear: 8000 Hz',
#   u'field_name': u'ad_8000',
#   u'field_note': u'dB Unaided Behavioral Thresholds',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, 0 \\n 5, 5 \\n 10, 10 \\n 15, 15 \\n 20, 20 \\n 25, 25 \\n 30, 30 \\n 35, 35 \\n 40, 40 \\n 45, 45 \\n 50, 50 \\n 55, 55 \\n 60, 60 \\n 65, 65 \\n 70, 70 \\n 75, 75 \\n 80, 80 \\n 85, 85 \\n 90, 90 \\n 95, 95 \\n 100, 100 \\n 105, 105 \\n 110, 110 \\n 115, 115 \\n 120, 120+',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Pure Tone Average (PTA) for the Right Ear ',
#   u'field_name': u'pta_ad',
#   u'field_note': u'dB Unaided Behavioral Thresholds',
#   u'field_type': u'calc',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'round((([ad_500]+[ad_1000]+[ad_2000])/3), 1)',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Degree of hearing loss in the right ear',
#   u'field_name': u'degree_hl_ad',
#   u'field_note': u'Based on PTA or ABR results',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Normal (0-14) \\n 1, Slight (15-25) \\n 2, Mild (26-40) \\n 3, Moderate (41-55) \\n 4, Moderately Severe (56-70) \\n 5, Severe (71-90) \\n 6, Profound (90+)',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Type of hearing loss in the right ear',
#   u'field_name': u'type_hl_ad',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Sensorineural Hearing Loss \\n 1, Conductive Hearing Loss \\n 2, Mixed Hearing Loss (Sensory and Conductive) \\n 3, Neural Hearing Loss (Includes Auditory Neuropathy Spectrum Disorder) \\n 4, Normal \\n 5, Unknown',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Identify the technology used in the right ear',
#   u'field_name': u'tech_ad',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Cochlear Implant \\n 8, Cochlear Implant Revision \\n 1, Hearing Aid \\n 2, Softband Baha \\n 3, Baha (Implanted) \\n 4, FM System Only \\n 5, Hearing Aid with Personal FM system \\n 6, Cochlear Implant with Personal FM System \\n 7, None \\n 9, Other',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[tech_ad]="0" or [tech_ad]="3" or [tech_ad]="6" or [tech_ad]="8"',
#   u'custom_alignment': u'',
#   u'field_label': u'Age when cochlear implant received or revised',
#   u'field_name': u'age_ci',
#   u'field_note': u'Enter the age in months',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[tech_ad]="0" or [tech_ad]="6" or [tech_ad]="8"',
#   u'custom_alignment': u'',
#   u'field_label': u'Identify number of electrodes used in current cochlear implant',
#   u'field_name': u'ci_tech_ad',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Full insertion with all electrodes being used \\n 1, Partial insertion with some electrodes turned off \\n 2, Full insertion but some electrodes are turned off \\n 3, Unknown',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[tech_ad]="0" or [tech_ad]="6" or [tech_ad]="8"',
#   u'custom_alignment': u'',
#   u'field_label': u'Current manufacturer',
#   u'field_name': u'ci_man_ad',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Advanced Bionics Corporation \\n 1, Cochlear Corporation \\n 3, Med El Corporation \\n 4, Other',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[ci_man_ad]="4"',
#   u'custom_alignment': u'',
#   u'field_label': u'If other, please enter here',
#   u'field_name': u'ci_man_ad_oth',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[tech_ad]="0" or [tech_ad]="3" or [tech_ad]="6" or [tech_ad]="8"',
#   u'custom_alignment': u'',
#   u'field_label': u'Sound Processor Name',
#   u'field_name': u'ci_sp_ad',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[tech_ad]="0" or [tech_ad]="6" or [tech_ad]="8"',
#   u'custom_alignment': u'',
#   u'field_label': u'Electrode Array Name',
#   u'field_name': u'ci_array_ad',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[tech_ad]="0" or [tech_ad]="6" or [tech_ad]="8"',
#   u'custom_alignment': u'',
#   u'field_label': u'Sound Processing Strategy Used',
#   u'field_name': u'ci_strat_ad',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[tech_ad]="9"',
#   u'custom_alignment': u'',
#   u'field_label': u'Enter the other technology',
#   u'field_name': u'oth_tech_ad',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="2"',
#   u'custom_alignment': u'',
#   u'field_label': u'Left Ear: 250 Hz',
#   u'field_name': u'as_250',
#   u'field_note': u'dB Unaided Behavioral Thresholds',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'Audiology: Left Ear',
#   u'select_choices_or_calculations': u'0, 0 \\n 5, 5 \\n 10, 10 \\n 15, 15 \\n 20, 20 \\n 25, 25 \\n 30, 30 \\n 35, 35 \\n 40, 40 \\n 45, 45 \\n 50, 50 \\n 55, 55 \\n 60, 60 \\n 65, 65 \\n 70, 70 \\n 75, 75 \\n 80, 80 \\n 85, 85 \\n 90, 90 \\n 95, 95 \\n 100, 100 \\n 105, 105 \\n 110, 110 \\n 115, 115 \\n 120, 120+',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="2"',
#   u'custom_alignment': u'',
#   u'field_label': u'Left Ear: 500 Hz',
#   u'field_name': u'as_500',
#   u'field_note': u'dB Unaided Behavioral Thresholds',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, 0 \\n 5, 5 \\n 10, 10 \\n 15, 15 \\n 20, 20 \\n 25, 25 \\n 30, 30 \\n 35, 35 \\n 40, 40 \\n 45, 45 \\n 50, 50 \\n 55, 55 \\n 60, 60 \\n 65, 65 \\n 70, 70 \\n 75, 75 \\n 80, 80 \\n 85, 85 \\n 90, 90 \\n 95, 95 \\n 100, 100 \\n 105, 105 \\n 110, 110 \\n 115, 115 \\n 120, 120+',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="2"',
#   u'custom_alignment': u'',
#   u'field_label': u'Left Ear: 1000 Hz',
#   u'field_name': u'as_1000',
#   u'field_note': u'dB Unaided Behavioral Thresholds',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, 0 \\n 5, 5 \\n 10, 10 \\n 15, 15 \\n 20, 20 \\n 25, 25 \\n 30, 30 \\n 35, 35 \\n 40, 40 \\n 45, 45 \\n 50, 50 \\n 55, 55 \\n 60, 60 \\n 65, 65 \\n 70, 70 \\n 75, 75 \\n 80, 80 \\n 85, 85 \\n 90, 90 \\n 95, 95 \\n 100, 100 \\n 105, 105 \\n 110, 110 \\n 115, 115 \\n 120, 120+',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="2"',
#   u'custom_alignment': u'',
#   u'field_label': u'Left Ear: 2000 Hz',
#   u'field_name': u'as_2000',
#   u'field_note': u'dB Unaided Behavioral Thresholds',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, 0 \\n 5, 5 \\n 10, 10 \\n 15, 15 \\n 20, 20 \\n 25, 25 \\n 30, 30 \\n 35, 35 \\n 40, 40 \\n 45, 45 \\n 50, 50 \\n 55, 55 \\n 60, 60 \\n 65, 65 \\n 70, 70 \\n 75, 75 \\n 80, 80 \\n 85, 85 \\n 90, 90 \\n 95, 95 \\n 100, 100 \\n 105, 105 \\n 110, 110 \\n 115, 115 \\n 120, 120+',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="2"',
#   u'custom_alignment': u'',
#   u'field_label': u'Left Ear: 4000 Hz',
#   u'field_name': u'as_4000',
#   u'field_note': u'dB Unaided Behavioral Thresholds',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, 0 \\n 5, 5 \\n 10, 10 \\n 15, 15 \\n 20, 20 \\n 25, 25 \\n 30, 30 \\n 35, 35 \\n 40, 40 \\n 45, 45 \\n 50, 50 \\n 55, 55 \\n 60, 60 \\n 65, 65 \\n 70, 70 \\n 75, 75 \\n 80, 80 \\n 85, 85 \\n 90, 90 \\n 95, 95 \\n 100, 100 \\n 105, 105 \\n 110, 110 \\n 115, 115 \\n 120, 120+',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="2"',
#   u'custom_alignment': u'',
#   u'field_label': u'Left Ear: 8000 Hz',
#   u'field_name': u'as_8000',
#   u'field_note': u'dB Unaided Behavioral Thresholds',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, 0 \\n 5, 5 \\n 10, 10 \\n 15, 15 \\n 20, 20 \\n 25, 25 \\n 30, 30 \\n 35, 35 \\n 40, 40 \\n 45, 45 \\n 50, 50 \\n 55, 55 \\n 60, 60 \\n 65, 65 \\n 70, 70 \\n 75, 75 \\n 80, 80 \\n 85, 85 \\n 90, 90 \\n 95, 95 \\n 100, 100 \\n 105, 105 \\n 110, 110 \\n 115, 115 \\n 120, 120+',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="2"',
#   u'custom_alignment': u'',
#   u'field_label': u'Pure Tone Average (PTA) for the Left Ear ',
#   u'field_name': u'pta_as',
#   u'field_note': u'dB Unaided Behavioral Thresholds',
#   u'field_type': u'calc',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'round((([as_500]+[as_1000]+[as_2000])/3), 1)',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="2"',
#   u'custom_alignment': u'',
#   u'field_label': u'Degree of hearing loss in the left ear',
#   u'field_name': u'degree_hl_as',
#   u'field_note': u'Based on PTA or ABR results',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Normal (0-14) \\n 1, Slight (15-25) \\n 2, Mild (26-40) \\n 3, Moderate (41-55) \\n 4, Moderately Severe (56-70) \\n 5, Severe (71-90) \\n 6, Profound (90+)',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="2"',
#   u'custom_alignment': u'',
#   u'field_label': u'Type of hearing loss in the left ear',
#   u'field_name': u'type_hl_as',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Sensorineural Hearing Loss \\n 1, Conductive Hearing Loss \\n 2, Mixed Hearing Loss (Sensory and Conductive) \\n 3, Neural Hearing Loss (Includes Auditory Neuropathy Spectrum Disorder) \\n 4, Normal \\n 5, Unknown',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[hearing_changes]="0" or [hearing_changes]="2"',
#   u'custom_alignment': u'',
#   u'field_label': u'Identify the technology used in the left ear',
#   u'field_name': u'tech_as',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Cochlear Implant \\n 8, Cochlear Implant Revision \\n 1, Hearing Aid \\n 2, Softband Baha \\n 3, Baha (Implanted) \\n 4, FM System Only \\n 5, Hearing Aid with Personal FM system \\n 6, Cochlear Implant with Personal FM System \\n 7, None \\n 9, Other',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[tech_as]="0" or [tech_as]="3" or [tech_as]="6" or [tech_as]="8"',
#   u'custom_alignment': u'',
#   u'field_label': u'Age when cochlear implant received or revised',
#   u'field_name': u'age_ci_2',
#   u'field_note': u'Enter the age in months',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[tech_as]="0" or [tech_as]="6" or [tech_as]="8"',
#   u'custom_alignment': u'',
#   u'field_label': u'Identify number of electrodes used in current cochlear implant',
#   u'field_name': u'ci_tech_as',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Full insertion with all electrodes being used \\n 1, Partial insertion with some electrodes turned off \\n 2, Full insertion but some electrodes are turned off \\n 3, Unknown',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[tech_as]="0" or [tech_as]="6" or [tech_as]="8"',
#   u'custom_alignment': u'',
#   u'field_label': u'Current manufacturer',
#   u'field_name': u'ci_man_as',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Advanced Bionics Corporation \\n 1, Cochlear Corporation \\n 3, Med El Corporation \\n 4, Other',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[ci_man_as]="4"',
#   u'custom_alignment': u'',
#   u'field_label': u'If other, please enter here',
#   u'field_name': u'ci_man_as_oth',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[tech_as]="0" or [tech_as]="3" or [tech_as]="6" or [tech_as]="8"',
#   u'custom_alignment': u'',
#   u'field_label': u'Sound Processor Name',
#   u'field_name': u'ci_sp_as',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[tech_as]="0" or [tech_as]="6" or [tech_as]="8"',
#   u'custom_alignment': u'',
#   u'field_label': u'Electrode Array Name',
#   u'field_name': u'ci_array_as',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[tech_as]="0" or [tech_as]="6" or [tech_as]="8"',
#   u'custom_alignment': u'',
#   u'field_label': u'Sound Processing Strategy Used',
#   u'field_name': u'ci_strat_as',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[tech_as]="9"',
#   u'custom_alignment': u'',
#   u'field_label': u'Enter the other technology',
#   u'field_name': u'oth_tech_as',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'',
#   u'custom_alignment': u'',
#   u'field_label': u'Length of time child has received services in a LSL Program (OPTION School)',
#   u'field_name': u'time',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'Service Provision',
#   u'select_choices_or_calculations': u'0, 0 to 1 year \\n 1, 1 year to 1 year, 11 months \\n 2, 2 years to 2 years, 11 months \\n 3, 3 years to 3 years, 11 months \\n 4, 4 years to 4 years, 11 months \\n 5, 5 years to 5 years, 11 months \\n 6, 6 years to 6 years, 11 months \\n 7, 7 years to 7 years, 11 months \\n 8, 8 years to 8 years, 11 months \\n 9, 9 or more years',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'',
#   u'custom_alignment': u'',
#   u'field_label': u'Select school grade',
#   u'field_name': u'school_grade',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Early Intervention \\n 1, 3 year old preschool \\n 2, 4 or 5 year old preschool \\n 3, Kindergarten (5 years of age on or before September 30)  \\n 4, First grade (1) \\n 5, Second grade (2) \\n 6, Third grade (3) \\n 7, Fourth grade (4) \\n 8, Fifth grade (5) \\n 9, Sixth grade (6) \\n 10, Seventh grade (7) \\n 11, Eighth grade (8) \\n 12, Ninth grade (9) \\n 13, Tenth grade (10) \\n 14, Eleventh grade (11) \\n 15, Twelfth grade (12)',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'',
#   u'custom_alignment': u'',
#   u'field_label': u'Select service provision. (For the "Initial Assessment/Enrollment" year, please select all of service provision categories up to and including the child\'s age to capture past history.)',
#   u'field_name': u'ser_prov_sel',
#   u'field_note': u'',
#   u'field_type': u'checkbox',
#   u'form_name': u'mandatory',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
# ...
#   u'custom_alignment': u'',
#   u'field_label': u'What was the presentation level (dB HL) for the Test de Ling?',
#   u'field_name': u'ling_db',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, 30-34 \\n 1, 35-39 \\n 2, 40-44 \\n 3, 45-49 \\n 4, 50-51 \\n 5, 55-59 \\n 6, 60-64 \\n 7, 65-69 \\n 8, 70-74 \\n 9, 75-79 \\n 10, 80-84 \\n 11, 85-89 \\n 12, 90+ \\n 13, Unknown \\n 14, Other',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(14)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Test de Ling:  Enter the raw score correct in both ears',
#   u'field_name': u'ling_rs_au',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'18',
#   u'text_validation_min': u'0',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(14)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Test de Ling:  Enter the word % correct in both ears',
#   u'field_name': u'ling_per_au',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'100',
#   u'text_validation_min': u'0',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(15)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Age at time of testing (ESP-Spanish)',
#   u'field_name': u'esp_sp_age',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'300',
#   u'text_validation_min': u'0',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(15)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'How was the ESP-Spanish administered?',
#   u'field_name': u'esp_sp_way',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Monitored Live Voice (MLV) \\n 1, Recorded \\n 2, Unknown',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(15)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'What was the presentation level (dB HL) for the ESP-Spanish?',
#   u'field_name': u'esp_sp_db',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, 30-34 \\n 1, 35-39 \\n 2, 40-44 \\n 3, 45-49 \\n 4, 50-51 \\n 5, 55-59 \\n 6, 60-64 \\n 7, 65-69 \\n 8, 70-74 \\n 9, 75-79 \\n 10, 80-84 \\n 11, 85-89 \\n 12, 90+ \\n 13, Unknown \\n 14, Other',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(15)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Select version of the ESP-Spanish administered',
#   u'field_name': u'esp_sp_ver',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, ESP Verbal Bajo \\n 1,ESP Percepci??e formas \\n 2, ESP Identificaci??e bis?bos \\n 3, ESP Identificaci??e monos?bos',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(15)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'ESP-Spanish:  Enter the raw score correct in both ears',
#   u'field_name': u'esp_sp_rs_au',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'24',
#   u'text_validation_min': u'0',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(15)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'ESP-Spanish:  Enter the word % correct in both ears',
#   u'field_name': u'esp_sp_per_au',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'100',
#   u'text_validation_min': u'0',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(16)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Age at time of testing (PIP-S)',
#   u'field_name': u'pips_age',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'300',
#   u'text_validation_min': u'36',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(16)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'How was the PIP-S administered?',
#   u'field_name': u'pips_way',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Monitored Live Voice (MLV) \\n 1, Recorded \\n 2, Unknown',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(16)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'What was the presentation level (dB HL) for the PIP-S?',
#   u'field_name': u'pips_db',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, 30-34 \\n 1, 35-39 \\n 2, 40-44 \\n 3, 45-49 \\n 4, 50-51 \\n 5, 55-59 \\n 6, 60-64 \\n 7, 65-69 \\n 8, 70-74 \\n 9, 75-79 \\n 10, 80-84 \\n 11, 85-89 \\n 12, 90+ \\n 13, Unknown \\n 14, Other',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(16)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'PIP-S:  Enter the raw score correct in both ears',
#   u'field_name': u'pips_rs_au',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'24',
#   u'text_validation_min': u'0',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(16)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'PIP-S:  Enter the word % correct in both ears',
#   u'field_name': u'pips_per_au',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'100',
#   u'text_validation_min': u'0',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(17)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Age at time of testing (PIPV)',
#   u'field_name': u'pipv_age',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'300',
#   u'text_validation_min': u'0',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(17)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'How was the PIPV administered?',
#   u'field_name': u'pipv_way',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Monitored Live Voice (MLV) \\n 1, Recorded \\n 2, Unknown',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(17)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'What was the presentation level (dB HL) for the PIPV?',
#   u'field_name': u'pipv_db',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, 30-34 \\n 1, 35-39 \\n 2, 40-44 \\n 3, 45-49 \\n 4, 50-51 \\n 5, 55-59 \\n 6, 60-64 \\n 7, 65-69 \\n 8, 70-74 \\n 9, 75-79 \\n 10, 80-84 \\n 11, 85-89 \\n 12, 90+ \\n 13, Unknown \\n 14, Other',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(17)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Select version of the PIPV administered',
#   u'field_name': u'pipv_ver',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, PIPV-30 Pruebas de Identificaci??e palabras a trav?de vocales\\n 1, PIPV-40 Pruebas de Identificaci??e palabras a trav?de vocales',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(17)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'PIPV:  Enter the raw score correct in both ears',
#   u'field_name': u'pipv_rs_au',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'40',
#   u'text_validation_min': u'0',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(17)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'PIPV:  Enter the word % correct in both ears',
#   u'field_name': u'pipv_per_au',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'100',
#   u'text_validation_min': u'0',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(18)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Age at time of testing (PIPC)',
#   u'field_name': u'pipc_age',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'300',
#   u'text_validation_min': u'24',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(18)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'How was the PIPC administered?',
#   u'field_name': u'pipc_way',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, Monitored Live Voice (MLV) \\n 1, Recorded \\n 2, Unknown',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(18)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'What was the presentation level (dB HL) for the PIPC?',
#   u'field_name': u'pipc_db',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, 30-34 \\n 1, 35-39 \\n 2, 40-44 \\n 3, 45-49 \\n 4, 50-51 \\n 5, 55-59 \\n 6, 60-64 \\n 7, 65-69 \\n 8, 70-74 \\n 9, 75-79 \\n 10, 80-84 \\n 11, 85-89 \\n 12, 90+ \\n 13, Unknown \\n 14, Other',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(18)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'Select version of the PIPC administered',
#   u'field_name': u'pipc_ver',
#   u'field_note': u'',
#   u'field_type': u'dropdown',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'0, PIPC-10 Pruebas de Identificaci??e palabras a trav?de consonantes \\n 1, PIPC-20 Pruebas de Identificaci??e palabras a trav?de consonantes \\n 2, PIPC-25 Pruebas de Identificaci??e palabras a trav?de consonantes \\n 3, PIPC-50 Pruebas de Identificaci??e palabras a trav?de consonantes',
#   u'text_validation_max': u'',
#   u'text_validation_min': u'',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(18)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'PIPC:  Enter the raw score correct in both ears',
#   u'field_name': u'pipc_rs_au',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'50',
#   u'text_validation_min': u'0',
#   u'text_validation_type_or_show_slider_number': u''},
#  {u'branching_logic': u'[test_sel11(18)]="1"',
#   u'custom_alignment': u'',
#   u'field_label': u'PIPC:  Enter the word % correct in both ears',
#   u'field_name': u'pipc_per_au',
#   u'field_note': u'',
#   u'field_type': u'text',
#   u'form_name': u'international',
#   u'identifier': u'',
#   u'matrix_group_name': u'',
#   u'question_number': u'',
#   u'required_field': u'',
#   u'section_header': u'',
#   u'select_choices_or_calculations': u'',
#   u'text_validation_max': u'100',
#   u'text_validation_min': u'0',
#   u'text_validation_type_or_show_slider_number': u''}]

# %%
for i,j in zip(lsl_dr_project.field_names, 
               lsl_dr_project.field_labels):
    print('{0}: \t{1}'.format(i,j))
# Out:
# study_id: 	Study ID
# academic_year: 	Enter academic year
# hl: 	Does the child have a hearing loss?
# demo_sel: 	Select from the following choices:
# gender: 	Gender
# race: 	Race
# race_other: 	If other, please enter here
# prim_lang: 	Primary language spoken at home
# prim_lang_other: 	If other, please enter here
# sib: 	Total number of children in the home
# mother_ed: 	Mother's educational level
# father_ed: 	Father's educational level
# parent_hl: 	Parental hearing status since childhood
# premature_age: 	Age of gestation
# onset_1: 	Age when hearing loss diagnosed
# age_amp: 	Age when first amplified (i.e., hearing aids, cochlear implant, etc.)
# age_int: 	Age when any intervention began (e.g., speech-language services, deaf education services, early intervention, etc.)
# age: 	Age when child entered your program
# med_cause: 	Child has a known medical diagnosis
# etiology_4: 	Select the known medical diagnoses made by the physician
# etiology_4_oth: 	If other, please enter known medical cause of hearing loss
# synd_cause: 	Child has a known syndrome
# etiology_3: 	Select known syndrome diagnosed by physician
# etiology_3_oth: 	If other, please enter known syndrome
# etiology: 	Child has another diagnosed disability(s)
# etiology_oth: 	Select other diagnosed disabilities
# etiology_oth_ohi: 	If other, please enter here
# etiology_2: 	Rate the impact of the other combined condition(s), if applicable, that contribute to the child's overall learning abilities
# hearing_changes: 	Please select from the following choices:
# ae: 	Age at time of testing
# ad_250: 	Right Ear: 250 Hz
# ad_500: 	Right Ear: 500 Hz
# ad_1000: 	Right Ear: 1000 Hz
# ad_2000: 	Right Ear: 2000 Hz
# ad_4000: 	Right Ear: 4000 Hz
# ad_8000: 	Right Ear: 8000 Hz
# pta_ad: 	Pure Tone Average (PTA) for the Right Ear
# degree_hl_ad: 	Degree of hearing loss in the right ear
# type_hl_ad: 	Type of hearing loss in the right ear
# tech_ad: 	Identify the technology used in the right ear
# age_ci: 	Age when cochlear implant received or revised
# ci_tech_ad: 	Identify number of electrodes used in current cochlear implant
# ci_man_ad: 	Current manufacturer
# ci_man_ad_oth: 	If other, please enter here
# ci_sp_ad: 	Sound Processor Name
# ci_array_ad: 	Electrode Array Name
# ci_strat_ad: 	Sound Processing Strategy Used
# oth_tech_ad: 	Enter the other technology
# as_250: 	Left Ear: 250 Hz
# as_500: 	Left Ear: 500 Hz
# as_1000: 	Left Ear: 1000 Hz
# as_2000: 	Left Ear: 2000 Hz
# as_4000: 	Left Ear: 4000 Hz
# as_8000: 	Left Ear: 8000 Hz
# pta_as: 	Pure Tone Average (PTA) for the Left Ear
# degree_hl_as: 	Degree of hearing loss in the left ear
# type_hl_as: 	Type of hearing loss in the left ear
# tech_as: 	Identify the technology used in the left ear
# age_ci_2: 	Age when cochlear implant received or revised
# ci_tech_as: 	Identify number of electrodes used in current cochlear implant
# ci_man_as: 	Current manufacturer
# ci_man_as_oth: 	If other, please enter here
# ci_sp_as: 	Sound Processor Name
# ci_array_as: 	Electrode Array Name
# ci_strat_as: 	Sound Processing Strategy Used
# oth_tech_as: 	Enter the other technology
# time: 	Length of time child has received services in a LSL Program (OPTION School)
# school_grade: 	Select school grade
# ser_prov_sel: 	Select service provision. (For the "Initial Assessment/Enrollment" year, please select all of service provision categories up to and including the child's age to capture past history.)
# ei_place_b: 	Identify early intervention services/history (birth-1 year)
# ei_place_b_oth: 	If other, please enter here
# ei_place_1: 	Identify early intervention services/history (1 year to 1year, 11 months)
# ei_place_1_oth: 	If other, please enter here
# ei_place_2: 	Identify early intervention services/history (2 years to 2 years, 11 months)
# ei_place_2_oth: 	If other, please enter here
# ed_place2_3yr: 	Select service placement for 3 year olds
# ed_place2_3yr_other: 	If other, please enter here
# ed_place2_4yr: 	Select service placement for 4 year olds
# ed_place2_4yr_other: 	If other, please enter here
# ed_place: 	Select service placement for 5 years and older
# ed_place_oth: 	If other, please enter here
# age_disenrolled: 	Enter student's age (in months) when disenrolled/graduated from the LSL program (otherwise leave blank)
# funct_out_age: 	Age at time of rating
# slc_fo: 	Spoken Language - Comprehension (Receptiveness): Select the stage the child is currently performing
# sle_fo: 	Spoken Language - Expression (Expressiveness): Select the stage the child is currently performing
# a_fo: 	Audition: Select the stage the child is currently performing
# fam_age: 	Age at time of rating
# family_inv: 	Rate the family involvement (1-5)
# test_sel1: 	From the following list of tests, select the articulation assessment(s) that were completed.
# age_test_aaps: 	Age at time of testing (Arizona)
# aaps_ts: 	Arizona-3: Total Score
# aaps_ss: 	Arizona-3: Standard Score
# aaps_ir: 	Arizona-3 Impairment Rating
# aaps_inr: 	Arizonia-3 Speech Intelligibility Interpretation Values
# age_test_gf2: 	Age at time of testing (Goldman-Fristoe)
# gf2_rs: 	Goldman-Fristoe: Raw Score
# gf2_ss: 	Goldman-Fristoe: Standard Score
# test_sel2: 	From the following list of tests, select at least one expressive vocabulary assessment and at least one receptive vocabulary assessment that were completed.
# age_test_eowpvt: 	Age at time of testing (EOWPVT)
# eowpvt_rs: 	EOWPVT: Raw Score
# eowpvt_ss: 	EOWPVT: Standard Score
# age_test_evt: 	Age at time of testing (EVT2)
# evt_rs: 	EVT2: Total Raw Score
# evt_ss: 	EVT2: Standard Score
# age_test_ppvt: 	Age at time of testing (PPVT)
# ppvt_f: 	PPVT: Select which Form and Version Administered
# ppvt_rs: 	PPVT: Raw Score
# ppvt_ss: 	PPVT: Standard Score
# age_test_rowpvt: 	Age at time of testing (ROWPVT)
# rowpvt_rs: 	ROWPVT: Raw Score
# rowpvt_ss: 	ROWPVT: Standard Score
# test_sel3: 	From the following list of tests, select all the language assessment(s) that were completed.
# age_test_celp: 	Age at time of testing (CELF-P2)
# celfp_ss_rs: 	CELF-P2: Sentence Structure Raw Score
# celfp_ss_ss: 	CELF-P2: Sentence Structure Scaled Score
# celfp_ws_rs: 	CELF-P2: Word Structure Raw Score
# celfp_ws_ss: 	CELF-P2: Word Structure Scaled Score
# celfp_ev_rs: 	CELF-P2: Expressive Vocabulary Raw Score
# celfp_ev_ss: 	CELF-P2: Expressive Vocabulary Scaled Score
# celfp_fd_rs: 	CELF-P2: Concepts & Following Directions Raw Score
# celfp_fd_ss: 	CELF-P2: Concepts & Following Directions Scaled Score
# celfp_rs_rs: 	CELF-P2: Recalling Sentences Raw Score
# celfp_rs_ss: 	CELF-P2: Recalling Sentences Scaled Score
# celfp_bc_rs: 	CELF-P2: Basic Concepts (Ages 3-4) Raw Score
# celfp_bc_ss: 	CELF-P2: Basic Concepts (Ages 3-4) Scaled Score
# celfp_wcr_rs: 	CELF-P2: Word Classes-Receptive Raw Score
# celfp_wcr_ss: 	CELF-P2: Word Classes-Receptive Scaled Score
# celfp_wce_rs: 	CELF-P2: Word Classes-Expressive Raw Score
# celfp_wce_ss: 	CELF-P2: Word Classes-Expressive Scaled Score
# celfp_wc_sss: 	CELF-P2: Word Classes - Sum of Word Classes - Expressive and Word Classes - Receptive Scaled Score
# celfp_wct_ss: 	CELF-P2: Word Classes - Total Scaled Score
# celfp_cl_sss: 	CELF-P2: Core Language Sum of Subtest Scaled Scores
# celfp_cl_ssss: 	CELF-P2: Core Language Standard Score
# celfp_rl_ssss: 	CELF-P2: Receptive Language Sum of Subtest Scaled Scores
# celfp_rl_ss: 	CELF-P2: Receptive Language Standard Score
# celfp_el_ssss: 	CELF-P2: Expressive Language Sum of Subtest Scaled Scores
# celfp_el_ss: 	CELF-P2: Expressive Language Standard Score
# celfp_lc_ssss: 	CELF-P2: Language Content Sum of Subtest Scaled Scores
# celfp_lc_ss_: 	CELF-P2: Language Content Standard Score
# celfp_ls_ssss: 	CELF-P2: Language Structure Sum of Subtest Scaled Scores
# celfp_ls_ss_: 	CELF-P2: Language Structure Standard Score
# age_test_celf: 	Age at time of testing (CELF-4)
# celf_cfd_rs: 	CELF-4, 5-8: Concepts & Following Directions Raw Score
# celf_cfd_ss: 	CELF-4, 5-8: Concepts & Following Directions Scaled Score
# celf_ws_rs: 	CELF-4, 5-8: Word Structure Raw Score
# celf_ws_ss: 	CELF-4, 5-8: Word Structure Scaled Score
# celf_rs_rs: 	CELF-4, 5-8: Recalling Sentences Raw Score
# celf_rs_ss: 	CELF-4, 5-8: Recalling Sentences Scaled Score
# celf_fs_rs: 	CELF-4, 5-8: Formulated Sentences Raw Score
# celf_fs_ss: 	CELF-4, 5-8: Formulated Sentences Scaled Score
# celf_wcr_rs: 	CELF-4, 5-8: Word Classes-Receptive Raw Score
# celf_wcr_ss: 	CELF-4, 5-8: Word Classes-Receptive Scaled Score
# celf_wce_rs: 	CELF-4, 5-8: Word Classes-Expressive Raw Score
# celf_wce_ss: 	CELF-4, 5-8: Word Classes-Expressive Scaled Score
# celf_wct_sss: 	CELF-4, 5-8: Word Classes Sum of WC-R + WC-E Scaled Score
# celf_wct_ss: 	CELF-4, 5-8: Word Classes - Total Scaled Score
# celf_ss_rs: 	CELF-4, 5-8: Sentence Structure Raw Score
# celf_ss_ss: 	CELF-4, 5-8: Sentence Structure Scaled Score
# celf_ev_rs: 	CELF-4, 5-8: Expressive Vocabulary Raw Score
# celf_ev_ss: 	CELF-4, 5-8: Expressive Vocabulary Scaled Score
# celf_usp_rs: 	CELF-4, 5-8: Understanding Spoken Paragraphs Raw Score
# celf_usp_ss: 	CELF-4, 5-8: Understanding Spoken Paragraphs Scaled Score
# celf_nrf_rs: 	CELF-4, 5-8: Number Repetition-Forward Raw Score
# celf_nrf_ss: 	CELF-4, 5-8: Number Repetition-Forward Scaled Score
# celf_nrb_rs: 	CELF-4, 5-8: Number Repetition-Backward Raw Score
# celf_nrb_ss: 	CELF-4, 5-8: Number Repetition-Backward Scaled Score
# celf_nrt_rs: 	CELF-4, 5-8: Number Repetition-Total Raw Score
# celf_nrt_ss: 	CELF-4, 5-8: Number Repetition-Total Scaled Score
# celf_fsq_rs: 	CELF-4, 5-8: Familiar Sequences Raw Score
# celf_fsq_ss: 	CELF-4, 5-8: Familiar Sequences Scaled Score
# celf_clsi: 	CELF-4, 5-8: Core Language Sum of Subtest Scaled Scores
# celf_cl: 	CELF-4, 5-8: Core Language Standard Score
# celf_rl: 	CELF-4, 5-8: Receptive Language Sum of Subtest Scaled Scores
# celf_rlss: 	CELF-4, 5-8: Receptive Language Standard Score
# celf_el: 	CELF-4, 5-8: Expressive Language Sum of Subtest Scaled Scores
# celf_elss: 	CELF-4, 5-8, Expressive Language Standard Score
# celf_lc: 	CELF-4, 5-8: Language Content Sum of Subtest Scaled Scores
# celf_lcss: 	CELF-4, 5-8: Language Content Standard Score
# celf_ls: 	CELF-4, 5-8: Language Structure Sum of Subtest Scaled Scores
# celf_lsss: 	CELF-4, 5-8: Language Structure Standard Score
# celf_wm: 	CELF-4, 5-8: Working Memory Sum of Subtest Scaled Scores
# celf_wmss: 	CELF-4, 5-8: Working Memory Standard Score
# age_test_celf4: 	Age at time of testing (CELF-4, 9-21)
# celf4_cfd_rs: 	CELF-4, 9-21: Concepts & Following Directions Raw Score
# celf4_cfd_ss: 	CELF-4, 9-21: Concepts & Following Directions Scaled Score
# celf4_rs_rs: 	CELF-4, 9-21: Recalling Sentences Raw Score
# celf4_rs_ss: 	CELF-4, 9-21: Recalling Sentences Scaled Score
# celf4_fs_rs: 	CELF-4, 9-21: Formulated Sentences Raw Score
# celf4_fs_ss: 	CELF-4, 9-21: Formulated Sentences Scaled Score
# celf4_wcr_rs: 	CELF-4, 9-21: Word Classes-Receptive Raw Score
# celf4_wcr_ss: 	CELF-4, 9-21: Word Classes-Receptive Scaled Score
# celf4_wce_rs: 	CELF-4, 9-21: Word Classes-Expressive Raw Score
# celf4_wce_ss: 	CELF-4, 9-21: Word Classes-Expressive Scaled Score
# celf4_wct_rs: 	CELF-4, 9-21: Word Classes - Sum of WC-R + WC-E Scaled Scores
# celf4_wct_ss: 	CELF-4, 9-21: Word Classes - Total Scaled Score
# celf4_wd_rs: 	CELF-4, 9-21: Word Definitions Raw Score
# celf4_wd_ss: 	CELF-4, 9-21: Word Definitions Scaled Score
# celf4_ev_rs: 	CELF-4, 9-21: Expressive Vocabulary Raw Score
# celf4_ev_ss: 	CELF-4, 9-21: Expressive Vocabulary Scaled Score
# celf4_sars: 	CELF-4, 9-21: Sentence Assembly Raw Score
# celf4_sass: 	CELF-4, 9-21: Sentence Assembly Scaled Score
# celf4_sr_rs: 	CELF-4, 9-21: Semantic Relationships Raw Score
# celf4_sr_ss: 	CELF-4, 9-21: Semantic Relationships Scaled Score
# celf4_usp_rs: 	CELF-4, 9-21: Understanding Spoken Paragraphs Raw Score
# celf4_usp_ss: 	CELF-4, 9-21: Understanding Spoken Paragraphs Scaled Score
# celf4_nrf_rs: 	CELF-4, 9-21: Number Repetition-Forward Raw Score
# celf4_nrf_ss: 	CELF-4, 9-21: Number Repetition-Forward Scaled Score
# celf4_nrb_rs: 	CELF-4, 9-21: Number Repetition-Backward Raw Score
# celf4_nrb_ss: 	CELF-4, 9-21: Number Repetition-Backward Scaled Score
# celf4_nrt_rs: 	CELF-4, 9-21: Number Repetition-Total Raw Score
# celf4_nrt_ss: 	CELF-4, 9-21: Number Repetition-Total Scaled Score
# celf4_fsq_rs: 	CELF-4, 9-21: Familiar Sequences 1/2 Raw Score
# celf4_fsq_ss: 	CELF-4, 9-21: Familiar Sequences 1/2 Scaled Score
# celf4_cl_ss_ss: 	CELF-4, 9-21: Core Language Sum of Subtest Scaled Score
# celf4_cl_ss: 	CELF-4, 9-21: Core Language Standard Score
# celf4_rl_ss_ss: 	CELF-4, 9-21: Receptive Language Sum of Subtest Scaled Score
# celf4_rl_ss: 	CELF-4, 9-21: Receptive Language Standard Score
# celf4_el_ss_ss: 	CELF-4, 9-21: Expressive Language Sum of Subtest Scaled Scores
# celf4_el_ss: 	CELF-4, 9-21: Expressive Language Standard Score
# celf4_lc_ss_ss: 	CELF-4, 9-21: Language Content Sum of Subtest Scaled Scores
# celf4_lc_ss_: 	CELF-4, 9-21: Language Content Standard Score
# celf4_lm_ss_ss: 	CELF-4, 9-21: Language Memory Sum of Subtest Scaled Scores
# celf4_lm_ss: 	CELF-4, 9-21: Language Memory Standard Score
# celf4_wm_ss_ss: 	CELF-4, 9-21: Working Memory Sum of Subtest Scaled Scores
# celf4_wm_ss_: 	CELF-4, 9-21: Working Memory Standard Score
# age_test_owls: 	Age at time of testing (OWLS)
# owls_lc_rs: 	OWLS: Listening Comprehension Raw Score
# owls_lc_ss: 	OWLS: Listening Comprehension Standard Score
# owls_oe_rs: 	OWLS: Oral Expression Raw Score
# owls_oe_ss: 	OWLS: Oral Expression Standard Score
# owls_oc_sss: 	OWLS: Oral Composite Sum of Listening Comprehension and Oral Expression Standard Scores
# owls_oc_ss: 	OWLS: Oral Composite Standard Score
# owls_wes_trs: 	OWLS: Written Expression Scale Total Raw Score
# owls_wes_as: 	OWLS: Written Expression Scale Ability Score
# owls_wes_ss: 	OWLS: Written Expression Scale Standard Score
# owsl_lc: 	OWLS: Written Expression Scale Language Composite (Sum of written expression age-based standard score, listening comprehension standard score and oral expression standard score)
# owls_lcss: 	OWLS: Language Composite Standard Score
# age_test_pls: 	Age at time of testing (PLS)
# pls_choice: 	Select the PLS version administered
# pls_ac_rs: 	PLS: Auditory Comprehension Raw Score
# pls_ac_ss: 	PLS: Auditory Comprehension Standard Score
# pls_ec_rs: 	PLS: Expressive Communication Raw Score
# pls_ec_ss: 	PLS: Expressive Communication Standard Score
# pls_tl_rs: 	PLS: Total Language Score Standard Score Total
# pls_tl_ss: 	PLS: Total Language Score Standard Score
# comment: 	Comment
# att_type: 	Select area of attendance for intervention
# att_days_sch: 	Enter the number of required attendance days for this academic year
# att_days_st2_417: 	Enter the number of days the student attended for this academic year
# att_days_hr: 	Select the number of hours, on average, the child participates in the school day
# att_days_slp: 	Enter the number of scheduled speech-language therapy sessions
# att_days_slp_st: 	Enter the number of sessions the student attended speech-language therapy
# freq_slp: 	Select frequency of speech-language therapy
# freq_slp_other: 	If other, enter the frequency of speech-language therapy
# int_slp: 	Select intensity of speech-language therapy
# int_slp_other: 	If other, enter the intensity of speech-language therapy
# fam_part: 	Select on average family participation in speech-language therapy sessions
# att_days_de: 	Enter the number of scheduled sessions with a teacher of the deaf and hard of hearing
# att_days_de_st: 	Enter the number of sessions the student attended with a teacher of the deaf and hard of hearing
# freq_deafed: 	Select frequency of sessions with a teacher of the deaf and hard of hearing
# freq_deafed_other: 	If other, enter the frequency of sessions with a teacher of the deaf and hard of hearing
# int_deafed: 	Select intensity of sessions with a teacher of the deaf and hard of hearing
# int_deafed_other: 	If other, enter the intensity of sessions with a teacher of the deaf and hard of hearing
# fam_deafed: 	Select on average family participation during the session with a teacher of the deaf and hard of hearing
# att_days_des_other: 	Other type of session
# att_days_rnum_other: 	Enter the number of possible sessions
# att_days_anum_other: 	Enter the number of attended sessions
# demo_ses: 	Enter Family Income
# school_lunch: 	Does the child qualify for a free lunch?
# medicaid: 	Does the child qualify for the state Medicaid program and/or SSI?
# test_sel4: 	From the following list of tests, select the assessment(s) that were completed.
# age_test_battelle: 	Age at time of testing (Battelle)
# bdi_a_sc_rs: 	Battelle: Adaptive-Self Care Raw Score Total
# bdi_a_sc_ss: 	Battelle: Adaptive-Self Care Scaled Score
# bdi_a_pr_rs: 	Battelle: Adaptive-Personal Responsibility Raw Score Total
# bdi_a_pr_ss: 	Battelle: Adaptive-Personal Responsibility Scaled Score
# bdi_ps_ai_rs: 	Battelle: Personal Social-Adult Interaction Raw Score Total
# bdi_ps_ai_ss: 	Battelle: Personal Social-Adult Interaction Scaled Score
# bdi_ps_pr_rs: 	Battelle: Personal Social-Peer Interaction Raw Score Total
# bdi_ps_pr_ss: 	Battelle: Personal Social-Peer Interaction Scaled Score
# bdi_ps_sr_rs: 	Battelle: Personal Social-Self Concept and Social Role Raw Score Total
# bdi_ps_sr_ss: 	Battelle: Personal Social-Self Concept and Social Role Scaled Score
# bdi_c_rc_rs: 	Battelle: Communication - Receptive Communication Raw Score Total
# bdi_c_rc_ss: 	Battelle: Communication - Receptive Communication Scaled Score
# bdi_c_ec_rs: 	Battelle: Communication - Expressive Communication Raw Score Total
# bdi_c_ec_ss: 	Battelle: Communication - Expressive Communication Scaled Score
# bdi_m_gm_rs: 	Battelle: Motor-Gross Motor Raw Score Total
# bdi_m_gm_ss: 	Battelle: Motor-Gross Motor Scaled Score
# bdi_m_fm_rs: 	Battelle: Motor-Fine Motor Raw Score Total
# bdi_m_fm_ss: 	Battelle: Motor-Fine Motor Scaled Score
# bdi_m_pm_rs: 	Battelle: Motor-Perceptual Motor Raw Score Total
# bdi_m_pm_ss: 	Battelle: Motor-Perceptual Motor Scaled Score
# bdi_c_am_rs: 	Battelle: Cognitive-Attention and Memory Raw Score Total
# bdi_c_am_ss: 	Battelle: Cognitive-Attention and Memory Scaled Score
# bdi_c_ra_rs: 	Battelle: Cognitive-Reasoning and Academic Skills Raw Score Total
# bdi_c_ra_ss: 	Battelle: Cognitive-Reasoning and Academic Skills Scaled Score
# bdi_c_pc_rs: 	Battelle: Cognitive-Perceptions and Concepts Raw Score Total
# bdi_c_pc_ss: 	Battelle: Cognitive-Perception and Concepts Scaled Score
# bdi_total_ssss: 	Battelle: BDI-2 Total Sum of Subdomain Scaled Scores
# bdi_a_sss: 	Battelle: Adaptive Sum of Scaled Scores
# bdi_a_dq: 	Battelle: Adaptive Developmental Quotient
# bdi_ps_sss: 	Battelle: Personal Social Sum of Scaled Scores
# bdi_ps_dq: 	Battelle: Personal Social Developmental Quotient
# bdi_cm_sss: 	Battelle: Communication Sum of Scaled Scores
# bdi_cm_dq: 	Battelle: Communication Developmental Quotient
# bdi_m_sss: 	Battelle: Motor Sum of Scaled Scores
# bdi_m_dq: 	Battelle: Motor  Developmental Quotient
# bdi_cg_sss: 	Battelle: Cognitive Sum of Scaled Scores
# bdi_cg_dq: 	Battelle: Cognitive Developmental Quotient
# bdi_t_sss: 	Battelle: Total Sum of Scaled Scores Developmental Quotient
# bdi_t_dq: 	Battelle: BDI-2 Total Developmental Quotient
# age_test_dayc: 	Age at time of testing (DAYC)
# dayc_c_rs: 	DAYC: Cognitive Raw Score
# dayc_c_ss: 	DAYC: Cognitive Standard Score
# dayc_com_rs: 	DAYC: Communication Raw Score
# dayc_com_ss: 	DAYC: Communication Standard Score
# dayc_se_rs: 	DAYC: Social-Emotional Raw Score
# dayc_se_ss: 	DAYC: Social-Emotional Standard Score
# dayc_pd_rs: 	DAYC: Physical Development Raw Score
# dayc_pd_ss: 	DAYC: Physical Development Standard Score
# dayc_ab_rs: 	DAYC: Adaptive Behavior Raw Score
# dayc_ab_ss: 	DAYC: Adaptive Behavior Standard Score
# dayc_sss: 	DAYC: Sum of Standard Scores
# dayc_quo: 	DAYC: General Development Quotient
# age_spsc: 	Age at time of testing (Sensory Profile-School Campanion)
# spsc_a_rs: 	Auditory Raw Score
# spsc_a_i: 	Auditory Interpretation
# spsc_v_rs: 	Visual Raw Score
# spsc_v_i: 	Visual Interpretation
# spsc_m_rs: 	Movement Raw Score
# spsc_m_i: 	Movement Interpretation
# spsc_t_rs: 	Touch Raw Score
# spsc_t_i: 	Touch Interpretation
# spsc_b_rs: 	Behavior Raw Score
# spsc_b_i: 	Behavior Interpretation
# age_sps: 	Age at time of testing (Sensory Profile-Supplement)
# sps_ap_rs: 	Auditory Processing Raw Score
# sps_sp_i: 	Auditory Processing Interpretation
# sps_vp_rs: 	Visual Processing Raw Score
# sps_vp_i: 	Visual Processing Interpretation
# sps_bal_rs: 	Vestibular Processing Raw Score
# sps_bal_i: 	Vestibular Processing Interpretation
# sps_tp_rs: 	Touch Processing Raw Score
# sps_tp_i: 	Touch Processing Interpretation
# sps_mp_rs: 	Multisensory Processing Raw Score
# sps_mp_i: 	Multisensory Processing Interpretation
# sps_osp_rs: 	Oral Sensory Processing Raw Score
# sps_osp_i: 	Oral Sensory Processing  Interpretation
# sps_soet_rs: 	Sensory Processing Related to Endurance/Tone Raw Score
# sps_soet_i: 	Sensory Processing Related to Endurance/Tone Interpretation
# sps_mbpm_rs: 	Modulation Related to Body Position and Movement Raw Score
# sps_mbpm_i: 	Modulation Related to Body Position and Movement Interpretation
# sps_mmaal_rs: 	Modulation of Movement Affecting Activity Level Raw Score
# sps_mmaal_i: 	Modulation of Movement Affecting Activity Level Interpretation
# sps_msier_rs: 	Modulation of Sensory Input Affecting Activity Level Raw Score
# sps_msier_i: 	Modulation of Sensory Input Affecting Activity Level Interpretation
# sps_mvier_rs: 	Modulation of Visual Input Affecting Emotional Responses Raw Score
# sps_mvier_i: 	Modulation of Visual Input Affecting Emotional Responses Interpretation
# sps_esr_rs: 	Emotional/Social Responses Raw Score
# sps_esr_i: 	Emotional/Social Responses Interpretation
# sps_bosp_rs: 	Behavioral Outcomes of Sensory Processing Raw Score
# sps_bosp_i: 	Behavioral Outcomes of Sensory Processing Interpretation
# sps_iitr_rs: 	Items Indicating Thresholds for Responses Raw Score
# sps_iitr_i: 	Items Indicating Thresholds for Responses Interpretation
# age_spsit: 	Age at time of testing (Sensory Profile-Infant & Toddlers)
# spsit_ap_rs: 	Auditory Processing Raw Score
# spsit_ap_i: 	Auditory Processing Intrepretation
# spsit_vp_rs: 	Visual Processing Raw Score
# spsit_vp_i: 	Visual Processing Interpretation
# spsit_tp_rs: 	Tactile Processing Raw Score
# spsit_tp_i: 	Tactile Processing Interpretation
# spsit_bal_rs: 	Vestibular Processing Raw Score
# spsit_bal_i: 	Vestibular Processing Interpretation
# spsit_os_rs: 	Oral Sensory Processing Raw Score
# spsit_os_i: 	Oral Sensory Processing  Interpretation
# age_test_vin: 	Age at time of testing (Vineland)
# vine_rrs: 	Vineland-II: Communication Domain Receptive Raw Score
# vine_rss: 	Vineland-II: Communication Domain Receptive V-Scale Score
# vine_ers: 	Vineland-II: Communication Domain Expressive Raw Score
# vine_ess: 	Vineland-II: Communication Domain Expressive V-Scale Score
# vine_wrs: 	Vineland-II: Communication Domain Written Raw Score
# vine_wss: 	Vineland-II: Communication Domain Written V-Scale Score
# vine_cd_rs: 	Vineland-II: Communication Domain Sum Score
# vine_cd_ss: 	Vineland-II: Communication Domain Standard Score
# vine_prs: 	Vineland-II: Daily Living Skills Domain Personal Raw Score
# vine_pss: 	Vineland-II: Daily Living Skills Domain Personal V-Scale Score
# vine_drs: 	Vineland-II: Daily Living Skills Domain Domestic Raw Score
# vine_dss: 	Vineland-II: Daily Living Skills Domain Domestic V-Scale Score
# vine_crs: 	Vineland-II: Daily Living Skills Domain Community Raw Score
# vine_css: 	Vineland-II: Daily Living Skills Domain Community V-Scale Score
# vine_dlsd_rs: 	Vineland-II: Daily Living Skills Domain Sum Score
# vine_dls_dss: 	Vineland-II: Daily Living Skills Domain Standard Score
# vine_ir_rs: 	Vineland-II: Socialization Interpersonal Relationships Raw Score
# vine_ir_ss: 	Vineland-II: Socialization Interpersonal Relationships V-Scale Score
# vine_plt_rs: 	Vineland-II: Socialization Play and Leisure Time Raw Score
# vine_plt_ss: 	Vineland-II: Socialization Play and Leisure Time V-Scale Score
# vine_cs_rs: 	Vineland-II: Socialization Coping Skills Raw Score
# vine_cs_ss: 	Vineland-II: Socialization Coping Skills V-Scale Score
# vine_sd_rs: 	Vineland-II: Socialization Domain Sum Score
# v_sd_ss: 	Vineland-II: Socialization Domain Standard Score
# vine_g_rs: 	Vineland-II: Motor Skills Gross Raw Score
# vine_g_ss: 	Vineland-II: Motor Skills Gross V-Scale Score
# vine_f_rs: 	Vineland-II: Motor Skills Fine Raw Score
# vine_f_ss: 	Vineland-II: Motor Skills Fine V-Scale Score
# vine_msd_rs: 	Vineland-II: Motor Skills Domain Sum Score
# vine_msd_ss: 	Vineland-II: Motor Skills Domain Standard Score
# vine_sdss: 	Vineland-II: Sum of Domain Standard Scores
# vine_abc_ss: 	Vineland-II: Adaptive Behavior Composite Standard Score
# test_sel10: 	From the following list of tests, select the assessment(s) that were completed.
# age_test_iepn: 	Age at time of testing (IEPN)
# iepn_man_s_rs: 	IEPN:  Manner - Stop Raw Score
# iepn_man_n_rs: 	IEPN: Manner - Nasal Raw Score
# iepn_man_f_rs: 	IEPN: Manner - Fricative Raw Score
# iepn_man_l_rs: 	IEPN: Manner - Liquid Raw Score
# iepn_man_tp: 	IEPN: Manner  Total %
# iepn_place_l_rs: 	IEPN: Place - Labial Raw Score
# iepn_place_a_rs: 	IEPN: Place - Alveolar Raw Score
# iepn_place_v_rs: 	IEPN: Place - Velar Raw Score
# iepn_place_tp: 	IEPN: Place Total %
# iepn_vc_vl_rs: 	IEPN: Voicing Contrasts - Voiceless Raw Score
# iepn_vc_v_rs: 	IEPN: Voicing Contrasts - Voiced Raw Score
# iepn_vc_tp: 	IEPN: Voicing Contrasts Total %
# iepn_wp_s_rs: 	IEPN: Word Patterns - Syllables Raw Score
# iepn_wp_st_rs: 	IEPN: Word Patterns - Stress  Raw Score
# iepn_wp_i_rs: 	IEPN: Word Patterns - Intonation Raw Score
# iepn_wp_ic_rs: 	IEPN: Word Patterns - Initial Consonant Raw Score
# iepn_wp_fcrs: 	IEPN: Word Patterns - Final Consonant Raw Score
# iepn_wp_tp: 	IEPN: Word Patterns Total %
# iepn_bv_hf_rs: 	IEPN: Basic Vowel Areas - High Front Raw Score
# iepn_bv_mlf_rs: 	IEPN: Basic Vowel Areas - Mid-Low Front Raw Score
# iepn_bv_lb_rs: 	IEPN: Basic Vowel Areas - Low Back Raw Score
# iepn_bv_bb_rs: 	IEPN: Basic Vowel Areas - Back Back Raw Score
# iepn_bv_d_rs: 	IEPN: Basic Vowel Areas - Diphthongs Raw Score
# iepn_bv_tp: 	IEPN: Basic Vowels Total %
# iepn_d_tp: 	IEPN: Diphthongs Total %
# iepn_vdtotal_per: 	IEPN: Vowel and Diphthongs Total %
# test_sel5: 	From the following list of tests, select the assessment(s) that were completed.
# age_asc: 	Age at time of testing (Auditory Skills Checklist)
# asc_d_rs: 	ASC: Detection Raw Score
# asc_ds_rs: 	ASC: Discrimination Raw Score
# asc_id_rs: 	ASC: Identification Raw Score
# asc_c_rs: 	ASC: Comprehension Raw Score
# asc_ts: 	ASC: Total Score
# age_test_apthi: 	Age at time of testing (APT-HI R)
# apthi_a_rs: 	APT-HI-R Auditory-Only Profile Raw Score
# apthi_a_per: 	APT-HI-R Auditory-Only Profile Overall Percentage
# apthi_a_dev: 	APT-HI-R Auditory-Only Profile % Developed
# apthi_a_emer: 	APT-HI-R Auditory-Only Profile % Emerging
# apthi_a_mis: 	APT-HI-R Auditory-Only Profile % Missing
# apthi_av_rs: 	APT-HI-R Auditory-Visual Profile Raw Score
# apthi_av_per: 	APT-HI-R Auditory-Visual Profile Overall Percentage
# apthi_av_dev: 	APT-HI-R Auditory-Visual Profile % Developed
# apthi_av_emer: 	APT-HI-R Auditory-Visual Profile % Emerging
# apthi_av_mis: 	APT-HI-R Auditory-Visual Profile % Missing
# childp_age: 	Age at time of testing (CHILD-Parent)
# childp_tr: 	CHILD-Parent:  Total Responses
# childp_ave: 	CHILD-Parent: Average Responses
# childc_age: 	Age at time of testing (CHILD-Child)
# childc_tr: 	CHILD-Child: Total Responses
# childc_ave: 	CHILD-Child: Average Responses
# fapi_age: 	Age at time of testing (FAPI)
# fapi_ams_rs: 	FAPI: Awareness and Meaning of Sound Raw Score
# fapi_ams_s: 	FAPI: Awareness and Meaning of Sound  Score
# fapi_afi_rs: 	FAPI: Auditory Feedback and Integration Raw Score
# fapi_afi_s: 	FAPI: Auditory Feedback and Integration Score
# fapi_lss_rs: 	FAPI: Localization Sound Source Raw Score
# fapi_lss_s: 	FAPI: Localization Sound Source Score
# fapi_ad_rs: 	FAPI: Auditory Discrimination Raw Score
# fapi_ad_s: 	FAPI: Auditory Discrimination Score
# fapi_ac_rs: 	FAPI: Auditory Comprehension Raw Score
# fapi_ac_s: 	FAPI: Auditory Comprehension Score
# fapi_stam_rs: 	FAPI: Short-Term Auditory Memory Raw Score
# fapi_stam_s: 	FAPI: Short-Term Auditory Memory Score
# fapi_lap_rs: 	FAPI: Linguistic Auditory Processing Raw Score
# fapi_lap_s: 	FAPI: Linguistic Auditory Processing Score
# itmais_age: 	Age at time of testing (IT-MAIS)
# itmais_lang: 	Select language version
# itmais: 	IT-MAIS Overall Score
# itmais_du: 	IT-MAIS Device Usage Raw Score
# itmais_as: 	IT-MAIS Alerting to Sound Raw Score
# itmais_dm: 	IT-MAIS Deriving Meaning Raw Score
# le_age: 	Age at time of testing (LittlEars)
# le_lang: 	Select language version
# le_rs: 	LittlEars Raw Score
# mais_age: 	Age at time of testing (MAIS)
# mais_lang: 	Select language version
# mais: 	MAIS Overall Score
# mais_du: 	MAIS Device Usage Raw Score
# mais_as: 	MAIS Alerting to Sound Raw Score
# mais_dm: 	MAIS Deriving Meaning Raw Score
# peach_age: 	Age at time of testing (PEACH)
# peach_q_rs: 	PEACH: Quiet Raw Score
# peach_n_rs: 	PEACH: Noise Raw Score
# peach_o_rs: 	PEACH: Overall Raw Score
# peach_q_ps: 	PEACH: Quiet % Score
# peach_n_ps: 	PEACH: Noise %Score
# peach_o_ps: 	PEACH: Overall %Score
# peach_q_r: 	PEACH: Quiet
# peach_n_r: 	PEACH: Noise
# peach_o_r: 	PEACH: Overall
# sifter_age: 	Age at time of testing (SIFTER)
# sifter_aca: 	SIFTER: Academics Total Score
# sifter_att: 	SIFTER: Attention Total Score
# sifter_com: 	SIFTER: Communication Total Score
# sifter_part: 	SIFTER: Class Participation Total Score
# sifter_soc: 	SIFTER: Social Behavior Total Score
# test_sel7: 	From the following list of tests, select the assessment(s) that were completed.
# age_test_casl: 	Age at time of testing (CASL-Form 1)
# casl_bc_rs: 	CASL - Form 1: Basic Concepts Raw Score
# casl_bc_ss: 	CASL - Form 1: Basic Concepts Standard Score
# casl_a_rs: 	CASL - Form 1: Antonyms Raw Score
# casl_a_ss: 	CASL - Form 1: Antonyms Standard Score
# casl_scpl_rs: 	CASL - Form 1: Sentence Completion Raw Score
# casl_scpl_ss: 	CASL - Form 1: Sentence Completion Standard Score
# casl_synconpl_rs: 	CASL - Form 1: Syntax Construction Raw Score
# casl_synconpl_ss: 	CASL - Form 1: Syntax Construction Standard Score
# casl_pc_rs: 	CASL - Form 1: Paragraph Comprehension Raw Score
# casl_pc_ss: 	CASL - Form 1: Paragraph Comprehension Standard Score
# casl_pj_rs: 	CASL - Form 1: Pragmatic Judgment Raw Score
# casl_pj_ss: 	CASL - Form 1: Pragmatic Judgment Standard Score
# casl_scss: 	CASL - Form 1: Sum of Core Standard Scores
# casl_cc_ss: 	CASL - Form 1: Core Composite Standard Score
# casl2_age: 	Age at time of testing (CASL - Form 2)
# casl2_a_rs: 	CASL - Form 2: Antonyms Raw Score
# casl2_a_ss: 	CASL - Form 2: Antonyms Standard Score
# casl2_s_rs: 	CASL - Form 2: Synonyms Raw Score
# casl2_s_ss: 	CASL - Form 2: Synonyms Standard Score
# casl2_sc_rs: 	CASL - Form 2: Sentence Completion Raw Score
# casl2_sc_ss: 	CASL - Form 2: Sentence Completion Standard Score
# casl2_il_rs: 	CASL - Form 2: Idiomatic Language Raw Score
# casl2_il_ss: 	CASL - Form 2: Idiomatic Language Standard Score
# casl2_syc_rs: 	CASL - Form 2: Syntax Construction Raw Score
# casl2_syc_ss: 	CASL - Form 2: Syntax Construction Standard Score
# casl2_pc_rs: 	CASL - Form 2: Paragraph Comprehension Raw Score
# casl2_pc_ss: 	CASL - Form 2: Paragraph Comprehension Standard Score
# casl2_gm_rs: 	CASL - Form 2: Grammatical Morphemes Raw Score
# casl2_gm_ss: 	CASL - Form 2: Grammatical Morphemes Standard Score
# casl2_scom_rs: 	CASL - Form 2: Sentence Comprehension Raw Score
# casl2_scom_ss: 	CASL - Form 2: Sentence Comprehension Standard Score
# casl2_gj_rs: 	CASL - Form 2: Grammaticality Judgment Raw Score
# casl2_gj_ss: 	CASL - Form 2: Grammaticality Judgment Standard Score
# casl2_nl_rs: 	CASL - Form 2: Nonliteral Language Raw Score
# casl2_nl_ss: 	CASL - Form 2: Nonliteral Language Standard Score
# casl2_mc_rs: 	CASL - Form 2: Meaning from Context Raw Score
# casl2_mc_ss: 	CASL - Form 2: Meaning from Context Standard Score
# casl2_i_rs: 	CASL - Form 2: Inference Raw Score
# casl2_i_ss: 	CASL - Form 2: Inference Standard Score
# casl2_as_rs: 	CASL - Form 2: Ambiguous Sentences Raw Score
# casl2_as_ss: 	CASL - Form 2: Ambiguous Sentences Standard Score
# casl2_pj_rs: 	CASL - Form 2: Pragmatic Judgment Raw Score
# casl2_pg_ss: 	CASL - Form 2: Pragmatic Judgment Standard Score
# casl2_cc_scss: 	CASL - Form 2: Core Composite Sum of Core Standard Scores
# casl2_cc_ss: 	CASL - Form 2: Core Composite Standard Score
# casl2_ls_sss: 	CASL - Form 2: Linguistic/Semantic Sum of Standard Score
# casl2_ls_ss: 	CASL - Form 2: Linguistic/Semantic Standard Score
# casl2_syn_sss: 	CASL - Form 2: Syntactic Sum of Standard Scores
# casl2_syn_ss: 	CASL - Form 2: Syntactic Standard Scores
# casl2_sl_sss: 	CASL - Form 2: Supralinguistic Sum of Standard Scores
# casl2_sl_ss: 	CASL-  Form 2: Supralinguistic Standard Scores
# casl2_r_sss: 	CASL - Form 2: Receptive Sum of Standard Scores
# casl2_r_ss: 	CASL - Form 2: Receptive Standard Scores
# casl2_e_sss: 	CASL - Form 2: Expressive Sum of Standard Scores
# casl2_e_ss: 	CASL - Form 2: Expressive Standard Scores
# age_test_itpa: 	Age at time of testing (ITPA-3)
# itpa_sa_rs: 	ITPA-3: Spoken Analogies Raw Score
# itpa_sa_ss: 	ITPA-3: Spoken Analogies Standard Score
# itpa_sv_rs: 	ITPA-3: Spoken Vocabulary Raw Score
# itpa_sv_ss: 	ITPA-3: Spoken Vocabulary Standard Score
# itpa_mc_rs: 	ITPA-3: Morphological Closure Raw Score
# itpa_mc_rss: 	ITPA-3: Morphological Closure Standard Score
# itpa_sys_rs: 	ITPA-3: Syntactic Sentences Raw Score
# itpa_sys_ss: 	ITPA-3: Syntactic Sentences Standard Score
# itpa_sd_rs: 	ITPA-3: Sound Deletion Raw Score
# itpa_sd_ss: 	ITPA-3: Sound Deletion Standard Score
# itpa_rs_rs: 	ITPA-3: Rhyming Sequences Raw Score
# itpa_rs_ss: 	ITPA-3: Rhyming Sequences Standard Score
# itpa_ss_rs: 	ITPA-3: Sentence Sequencing Raw Score
# itpa_wsss_ss: 	ITPA-3: Sentence Sequencing Standard Score
# itpa_wsv_rs: 	ITPA-3: Written Vocabulary Raw Score
# itpa_wsv_ss: 	ITPA-3: Written Vocabulary Standard Score
# itpa_wssd_rs: 	ITPA-3: Sight Decoding Raw Score
# itpa_wssd_ss: 	ITPA-3: Sight Decoding Standard Score
# itpa_wssdec_rs: 	ITPA-3: Sound Decoding Raw Score
# itpa_wssdec_ss: 	ITPA-3: Sound Decoding Standard Score
# itpa_wsssp_rs: 	ITPA-3: Sight Spelling Raw Score
# itpa_wsssp_ss: 	ITPA-3: Sight Spelling Standard Score
# itpa_wssdsp_rs: 	ITPA-3: Sound Spelling Raw Score
# itpa_wssdsp_ss: 	ITPA-3: Sound Spelling Standard Score
# itpa_g_gl_sss: 	ITPA-3: Global-General Language Subtest Standard Score Sum
# itpa_g_gl_q: 	ITPA-3: Global-General Language Quotient
# itpa_g_sl_sss: 	ITPA-3: Global-Spoken Language Subtest Standard Score Sum
# itpa_g_sl_q: 	ITPA-3: Global-Spoken Language Quotient
# itpa_g_wl_sss: 	ITPA-3: Global-Written Language Subtest Standard Score Sum
# itpa_g_wl_q: 	ITPA-3: Global-Written Language Quotient
# itpa_s_s_sss: 	ITPA-3: Specific-Semantics Subtest Standard Score Sum
# itpa_s_s_q: 	ITPA-3: Specific-Semantics Quotient
# itpa_s_g_sss: 	ITPA-3: Specific-Grammar Subtest Standard Score Sum
# itpa_s_g_q: 	ITPA-3: Specific-Grammar Quotient
# itpa_s_p_sss: 	ITPA-3: Specific-Phonology Subtest Standard Score Sum
# itpa_s_p_q: 	ITPA-3: Specific-Phonology Quotient
# itpa_s_c_sss: 	ITPA-3: Specific-Comprehension Subtest Standard Score Sum
# itpa_s_c_q: 	ITPA-3: Specific-Comprehension Quotient
# itpa_s_wi_sss: 	ITPA-3: Specific-Word Identification Subtest Standard Score Sum
# itpa_s_wi_p: 	ITPA-3: Specific-Word Identification Quotient
# itpa_s_sp_sss: 	ITPA-3: Specific-Spelling Subtest Standard Score Sum
# itpa_s_sp_q: 	ITPA-3: Specific-Spelling Quotient
# itpa_s_sss_sss: 	ITPA-3: Specific-Sight Symbol Subtest Standard Score Sum
# itpa_s_sss_q: 	ITPA-3: Specific-Sight Symbol Processing Quotient
# itpa_s_sosp_sss: 	ITPA-3: Specific-Sound Symbol Subtest Standard Score Sum
# itpa_s_sosp_q: 	ITPA-3: Specific-Sound Symbol Quotient
# age_test_mbcdi: 	Age at time of testing (MacArthur-Bates-Words and Gestures)
# mbcdi_ew_pu_rs: 	MacArthur - Bates-Words and Gestures: Part 1: Early Words - Phrases understood Raw Score
# mbcdi_ew_wu_rs: 	MacArthur - Bates-Words and Gestures: Part 1: Early Words - Words Understood Raw Score
# mbcdi_ew_wp_rs: 	MacArthur - Bates-Words and Gestures: Part 1: Early Words - Words Produced Raw Score
# mbcdi_ag_eg_rs: 	MacArthur - Bates-Words and Gestures: Part 2: Actions and Gestures - Early Gestures Raw Score
# mbcdi_ag_lg_rs: 	MacArthur - Bates-Words and Gestures: Part 2: Actions and Gestures - Later Gestures Raw Score
# mbcdi_ag_tg_rs: 	MacArthur - Bates-Words and Gestures: Part 2: Actions and Gestures - Total Gestures Raw Score
# age_test_mbcdi2: 	Age at time of testing (MacArthur-Bates - Words and Sentences)
# mbcdi_v_wp_rs: 	MacArthur - Bates - Words and Sentences: Part 1: Vocabulary - Words Produced Raw Score
# mbcdi_wf_rs: 	MacArthur - Bates - Words and Sentences: Part 2: Word Forms Raw Score
# mbcdi_we_rs: 	MacArthur - Bates - Words and Sentences: Part 2: Word Endings Raw Score
# mbcdi_m3l_rw: 	MacArthur - Bates - Words and Sentences: Part 2: M3L (mean) Raw Score
# mbcdi_c_rs: 	MacArthur - Bates - Words and Sentences: Part 2: Complexity Raw Score
# age_test_plai: 	Age at time of testing (PLAI - 3 Years)
# plai_m_rs: 	PLAI - 3 Years: Matching Raw Score
# plai_m_ss: 	PLAI - 3 Years: Matching Scaled Score
# plai_sa_rs: 	PLAI - 3 Years: Selective Analysis Raw Score
# plai_sa_ss: 	PLAI - 3 Years: Selective Analysis Scaled Score
# plai_rr_rs: 	PLAI - 3 Years: Reordering and Reasoning Raw Score
# plai_rr_ss: 	PLAI - 3 Years: Reordering and Reasoning Scaled Score
# plai_rec_rs: 	PLAI - 3 Years: Receptive Raw Score
# plai_rec_ss: 	PLAI - 3 Years: Receptive Scaled Score
# plai_exp_rs: 	PLAI - 3 Years: Expressive Raw Score
# plai_exp_ss: 	PLAI - 3 Years: Expressive Scaled Score
# plai_com: 	PLAI - 3 Years: Composite Sum of Receptive and Expressive Scaled Scores
# plai_dab: 	PLAI - 3 Years: Discourse Ability Score
# age_test_plai2: 	Age at time of testing (PLAI - 4-5 Years)
# plai4_m_rs: 	PLAI - 4-5 Years: Matching Raw Score
# plai4_m_ss: 	PLAI - 4-5 Years: Matching Scaled Score
# plai4_sa_rs: 	PLAI - 4-5 Years: Selective Analysis Raw Score
# plai4_sa_ss: 	PLAI - 4-5 Years: Selective Analysis Scaled Score
# plai4_r_rs: 	PLAI - 4-5 Years: Reordering Raw Score
# plai4_r_ss: 	PLAI - 4-5 Years: Reordering Scaled Score
# plai4_rea_rs: 	PLAI - 4-5 Years: Reasoning Raw Score
# plai4_rea_ss: 	PLAI - 4-5 Years: Reasoning Scaled Score
# plai4_rec_rs: 	PLAI - 4-5 Years: Receptive Raw Score
# plai4_rec_ss: 	PLAI - 4-5 Years: Receptive Scaled Score
# plai4_exp_rs: 	PLAI - 4-5 Years: Expressive Raw Score
# plai4_exp_ss: 	PLAI - 4-5 Years: Expressive Scaled Score
# plai4_sum: 	PLAI - 4-5 Years: Sum of Receptive and Expressive Scaled Scores
# plai4_dab: 	PLAI - 4-5 Years: Discourse Ability Score
# age_test_reel: 	Age at time of testing (REEL-3)
# reel_rl_rs: 	REEL-3: Receptive Language Raw Score
# reel_rl_as: 	REEL-3: Receptive Language Ability Score
# reel_el_rs: 	REEL-3: Expressive Language Raw Score
# reel_el_as: 	REEL-3: Expressive Language Ability Score
# reel_sreas: 	REEL-3: Sum of Receptive and Expressive Ability Score
# reel_labs: 	REEL-3: Language Ability Score
# age_test_rey: 	Age at time of testing (Reynell)
# reynell_vcf: 	Reynell: Verbal Comprehension Form
# reynell_vc_tc: 	Reynell: Verbal Comprehension Total Correct
# reynell_vc_ss: 	Reynell: Verbal Comprehension Standard Score
# reynell_vci: 	Reynell: Verbal Comprehension Interpretation
# reynell_el_tc: 	Reynell: Expressive Language Total Correct
# reynell_el_ss: 	Reynell: Expressive Language Standard Score
# reynell_eli: 	Reynell: Expressive Language Interpretation
# age_test_ros: 	Age at time of testing (Rossetti)
# rosetti_iapp: 	Rossetti: Interaction-Attachment
# rosetti_prapp: 	Rossetti: Pragmatics
# rosetti_gapp: 	Rossetti: Gesture
# rosetti_papp: 	Rossetti: Play Age Performance Profile
# rossetti_lcapp: 	Rossetti Language Comprehension Age Performance Profile
# rossetti_leapp: 	Rossetti: Language Expression Age Performance Profile
# age_test_tasl: 	Age at time of testing (TASL)
# tasl: 	TASL: Test Level
# age_test_toldp: 	Age at time of testing (TOLD-P:4)
# toldp_pv_rs: 	TOLD-P:4: Picture Vocabulary Raw Score
# toldp_pv_ss: 	TOLD-P:4: Picture Vocabulary Standard Score
# toldp_rv_rs: 	TOLD-P:4: Relational Vocabulary Raw Score
# toldp_rv_ss: 	TOLD-P:4: Relational Vocabulary Standard Score
# toldp_ov_rs: 	TOLD-P:4: Oral Vocabulary Raw Score
# toldp_ov_ss: 	TOLD-P:4: Oral Vocabulary Standard Score
# toldp_gu_rs: 	TOLD-P:4: Syntactic Understanding Raw Score
# toldp_gu_ss: 	TOLD-P:4: Syntactic Understanding Standard Score
# toldp_si_rs: 	TOLD-P:4: Sentence Imitation Raw Score
# tolpd_si_ss: 	TOLD-P:4: Sentence Imitation Standard Score
# toldp_gc_rs: 	TOLD-P:4: Morphological Completion Raw Score
# toldp_gc_ss: 	TOLD-P:4: Morphological Completion Standard Score
# toldp_wd_rs: 	TOLD-P:4: Word Discrimination Raw Score
# toldp_wd_ss: 	TOLD-P:4: Word Discrimination Standard Score
# toldp_pa_rs: 	TOLD-P:4: Phonemic Analysis Raw Score
# toldp_pa_ss: 	TOLD-P:4: Phonemic Analysis Standard Score
# toldp_wa_rs: 	TOLD-P:4: Word Articulation Raw Score
# toldp_wa_ss: 	TOLD-P:4: Word Articulation Standard Score
# toldp_liq_sss: 	TOLD-P:4: Listening Sum of Standard Scores
# toldp_liq: 	TOLD-P:4: Listening Quotients
# toldp_orq_sss: 	TOLD-P:4: Organizing Sum of Standard Scores
# toldp_orq: 	TOLD-P:4: Organizing Quotients
# toldp_spq_sss: 	TOLD-P:4: Speaking Sum of Standard Scores
# toldp_spq: 	TOLD-P:4: Speaking Quotients
# toldp_gr_sss: 	TOLD-P:4: Grammar Sum of Standard Scores
# toldp_gr_q: 	TOLD-P:4: Grammar Quotients
# toldp_seq_sss: 	TOLD-P:4: Semantics Sum of Standard Scores
# toldp_seq: 	TOLD-P:4: Semantics Quotients
# toldp_sl_sss: 	TOLD-P:4: Spoken Language Sum of Standard Scores
# toldp_sl_q: 	TOLD-P:4: Spoken Language Quotients
# age_test_toldi4: 	Age at time of testing (TOLD-I:4)
# toldi4_sc_rs: 	TOLD-I:4: Sentence Combining Raw Score
# toldi4_sc_ss: 	TOLD-I:4: Sentence Combining Scaled Score
# toldi4_pv_rs: 	TOLD-I:4: Picture Vocabulary Raw Score
# toldi4_pv_ss: 	TOLD-I:4: Picture Vocabulary Scaled Score
# toldi4_wo_rs: 	TOLD-I:4: Word Ordering Raw Score
# toldi4_wo_ss: 	TOLD-I:4: Word Ordering Scaled Score
# toldi4_rv_rs: 	TOLD-I:4: Relational Vocabulary Raw Score
# toldi4_rv_ss: 	TOLD-I:4: Relational Vocabulary Scaled Score
# toldi4_mc_rs: 	TOLD-I:4: Morphological Comprehension Raw Score
# tolpi4_mc_ss: 	TOLD-I:4: Morphological Comprehension Scaled Score
# toldi4_mm_rs: 	TOLD-I:4: Multiple Meanings Raw Score
# toldi4_mm_ss: 	TOLD-I:4: Multiple Meanings Scaled Score
# tolpi4_l_sss: 	TOLD-I:4: Listening Sum of Scaled Scores
# toldi4_l_is: 	TOLD-I:4: Listening Index Score
# toldi4_o_sss: 	TOLD-I:4:Organizing Sum of Scaled Scores
# toldi4_o_is: 	TOLD-I:4: Organizing Index Score
# toldi4_s_sss: 	TOLD-I:4: Speaking Sum of Scaled Scores
# toldi4_s_is: 	TOLD-I:4: Speaking Index Score
# toldi4_g_sss: 	TOLD-I:4: Grammar Sum of Scaled Scores
# toldi4_g_is: 	TOLD-I:4: Grammar Index Score
# toldi4_sm_sss: 	TOLD-I:4: Semantics Sum of Scaled Scores
# toldi4_sm_is: 	TOLD-I:4: Semantics Index Score
# toldi4_sl_sss: 	TOLD-I:4: Spoken Language Sum of Scaled Scores
# toldi4_sl_is: 	TOLD-I:4: Spoken Language Index Score
# test_sel8: 	From the following list of tests, select the assessment(s) that were completed.
# age_test_ctopp5: 	Age at time of testing (CTOPP (ages 5-6))
# ctopp5_el_rs: 	CTOPP (5-6): Ellsion Raw Score
# ctopp5_el_ss: 	CTOPP (5-6): Ellsion Standard Score
# ctopp5_rc_rs: 	CTOPP (5-6): Rapid Color Naming Raw Score
# ctopp5_rc_ss: 	CTOPP (5-6): Rapid Color Naming Standard Score
# ctopp5_bw_rs: 	CTOPP (5-6): Blending Words Raw Score
# ctopp5_bw_ss: 	CTOPP (5-6): Blending Words Standard Score
# ctopp5_sm_rs: 	CTOPP (5-6): Sound Matching Raw Score
# ctopp5_sm_ss: 	CTOPP (5-6): Sound Matching Standard Score
# ctopp5_ro_rs: 	CTOPP (5-6): Rapid Object Naming Raw Score
# ctopp5_ro_ss: 	CTOPP (5-6): Rapid Object Naming Standard  Score
# ctopp5_md_rs: 	CTOPP (5-6): Memory for Digits Raw Score
# ctopp5_md_ss: 	CTOPP (5-6): Memory for Digits Standard Score
# ctopp5_nr_rs: 	CTOPP (5-6): Nonword Repetition Raw Score
# ctopp5_nr_ss: 	CTOPP (5-6): Nonword Repetition Standard Score
# ctopp5_bn_rs: 	CTOPP (5-6): Blending Nonwords Raw Score
# ctopp5_bn_ss: 	CTOPP (5-6): Blending Nonwords Standard Score
# ctopp5_cpa_sss: 	CTOPP (5-6): Phonological Awareness Sums of Standard Scores
# ctopp5_cpa_cs: 	CTOPP (5-6): Phonological Awareness Composite Score
# ctopp5_cpm_sss: 	CTOPP (5-6): Phonological Memory Sums of Standard Scores
# ctopp5_cpm_cs: 	CTOPP (5-6): Phonological Memory Composite Score
# ctopp5_rn_sss: 	CTOPP (5-6): Rapid Naming Sums of Standard Scores
# ctopp5_rn_cs: 	CTOPP (5-6): Rapid Naming Composite Score
# age_test_ctopp7: 	Age at time of testing (CTOPP (ages 7-24))
# ctopp7_el_rs: 	CTOPP (7-24): Ellsion Raw Score
# ctopp7_el_ss: 	CTOPP (7-24): Ellsion Standard Score
# ctopp7_bw_rs: 	CTOPP (7-24): Blending Words Raw Score
# ctopp7_bw_ss: 	CTOPP (7-24): Blending Words Standard Score
# ctopp7_md_rs: 	CTOPP (7-24): Memory for Digits Raw Score
# ctopp7_md_ss: 	CTOPP (7-24): Memory for Digits Standard Score
# ctopp7_rd_rs: 	CTOPP (7-24): Rapid Digit Naming Raw Score
# ctopp7_rd_ss: 	CTOPP (7-24): Rapid Digit Naming Standard Score
# ctopp7_nr_rs: 	CTOPP (7-24): Nonword Repetition Raw Score
# ctopp7_nr_ss: 	CTOPP (7-24): Nonword Repetition Standard Score
# ctopp7_rl_rs: 	CTOPP (7-24): Rapid letter Naming Raw Score
# ctopp7_rl_ss: 	CTOPP (7-24): Rapid letter Naming Standard Score
# ctopp7_rc_rs: 	CTOPP (7-24): Rapid Color Naming Raw Score
# ctopp7_rc_ss: 	CTOPP (7-24): Rapid Color Naming Standard Score
# ctopp7_pr_rs: 	CTOPP (7-24): Phoneme Reversal Raw Score
# ctopp7_pr_ss: 	CTOPP (7-24): Phoneme Reversal Standard Score
# ctopp7_ro_rs: 	CTOPP (7-24): Rapid Object Naming Raw Score
# ctopp7_ro_ss: 	CTOPP (7-24): Rapid Object Naming Standard  Score
# ctopp7_bn_rs: 	CTOPP (7-24): Blending Nonwords Raw Score
# ctopp7_bn_ss: 	CTOPP (7-24): Blending Nonwords Standard Score
# ctopp7_sw_rs: 	CTOPP (7-24): Segmenting Words Raw Score
# ctopp7_sw_ss: 	CTOPP (7-24): Segmenting Words Standard Score
# ctopp7_sn_rs: 	CTOPP (7-24): Segmenting Nonwords Raw Score
# ctopp7_sn_ss: 	CTOPP (7-24): Segmenting Nonwords Standard Score
# ctopp7_cpa_sss: 	CTOPP (7-24): Phonological Awareness Sums of Standard Scores
# ctopp7_cpa_cs: 	CTOPP (7-24): Phonological Awareness Composite Score
# ctopp7_cpm_sss: 	CTOPP (7-24): Phonological Memory Sums of Standard Scores
# ctopp7_cpm_cs: 	CTOPP (7-24): Phonological Memory Composite Score
# ctopp7_rn_sss: 	CTOPP (7-24): Rapid Naming Sums of Standard Scores
# ctopp7_rn_cs: 	CTOPP (7-24): Rapid Naming Composite Score
# ctopp7_apa_sss: 	CTOPP (7-24): Alternate Phonological Awareness Sums of Standard Scores
# ctopp7_apa_cs: 	CTOPP (7-24): Alternate Phonological Awareness Composite Score
# ctopp7_arn_sss: 	CTOPP (7-24): Alternate Rapid Naming Sums of Standard Scores
# ctopp7_arn_cs: 	CTOPP (7-24): Alternate Rapid Naming Composite Score
# gradep_age: 	Age at time of testing (GRADE Level P)
# gradep_when: 	GRADE Level P: Score Based on:
# gradep_sm_rs: 	GRADE Level P: Sound Matching Raw Score
# gradep_r_rs: 	GRADE Level P: Rhyming Raw Score
# gradep_pa_sum: 	GRADE Level P: Phonological Awareness Sum
# gradep_pa_s: 	GRADE Level P: Phonological Awareness Stanine
# gradep_pm_rs: 	GRADE Level P: Picture Matching Raw Score
# gradep_pd_rs: 	GRADE Level P: Picture Differences Raw Score
# gradep_vs_sum: 	GRADE Level P: Visual Skills Sum
# gradep_vs_s: 	GRADE Level P: Visual Skills Stanine
# gradep_vc_rs: 	GRADE Level P: Verbal Concepts Raw Score
# gradep_pc_rs: 	GRADE Level P: Picture Categories Raw Score
# gradep_c_sum: 	GRADE Level P: Concepts Sum
# gradep_c_s: 	GRADE Level P: Concepts Stanine
# gradep_lc_sum: 	GRADE Level P: Listening Comprehension Sum
# gradep_lc_s: 	GRADE Level P: Listening Comprehension Stanine
# gradep_tt_sum: 	GRADE Level P: Total Test Sum
# gradep_tt_s: 	GRADE Level P: Total Test Stanine
# gradep_tt_ss: 	GRADE Level P: Total Test Standard Score
# gradek_age: 	Age at time of testing (GRADE Level K)
# gradek_when: 	GRADE Level K: Score Based on:
# gradek_sm_rs: 	GRADE Level K: Sound Matching Raw Score
# gradek_r_rs: 	GRADE Level K: Rhyming Raw Score
# gradek_pa_sum: 	GRADE Level K: Phonological Awareness Sum
# gradek_pa_s: 	GRADE Level K: Phonological Awareness Stanine
# gradek_pa_rs: 	GRADE Level K: Print Awareness Raw Score
# gradek_lr_rs: 	GRADE Level K: Letter Recognition Raw Score
# gradek_sdw_rs: 	GRADE Level K: Same & Difference Words Raw Score
# gradek_els_sum: 	GRADE Level K: Early Literacy Skills Sum
# gradek_els_s: 	GRADE Level K: Early Literacy Skills Stanine
# gradek_pgc_sum: 	GRADE Level K: Phoneme-Grapheme Correspondence Sum
# gradek_pgc_s: 	GRADE Level K: Phoneme-Grapheme Correspondence Stanine
# gradek_lc_sum: 	GRADE Level K: Listening Comprehension Sum
# gradek_lc_s: 	GRADE Level K: Listening Comprehension Stanine
# gradek_tt_sum: 	GRADE Level K: Total Test Sum
# gradek_tt_s: 	GRADE Level K: Total Test Stanine
# gradek_tt_ss: 	GRADE Level K: Total Test Standard Score
# ...
# azbio_open_way_sbn: 	How was the AZBio administered in speech babble noise?
# azbio_open_db_sbn: 	What was the presentation level (dB HL) for the AZBio in speech babble noise?
# azbio_open_snr_sbn: 	Select signal-to-noise ratio in speech babble noise
# azbio_open_per_ad_sbn: 	AZBio: Enter the % correct in the right ear in speech babble noise
# azbio_open_per_as_sbn: 	AZBio: Enter the % correct in the left ear in speech babble noise
# azbio_open_per_au_sbn: 	AZBio: Enter the % correct in both ears in speech babble noise
# babybio_age: 	Age at time of testing (BabyBio Sentence Test)
# babybio_open_noise: 	Select background noise options
# babybio_open_item_q: 	BabyBio: Enter the number of items presented in quiet
# babybio_open_way_q: 	How was the BabyBio administered in quiet?
# babybio_open_db_q: 	What was the presentation level (dB HL) for the BabyBio in quiet?
# babybio_open_per_ad_q: 	BabyBio: Enter the % correct in the right ear in quiet
# babybio_open_per_as_q: 	BabyBio: Enter the % correct in the left ear in quiet
# babybio_open_per_au_q: 	BabyBio: Enter the % correct in both ears in quiet
# babybio_open_item_ssn: 	BabyBio: Enter the number of items presented in steady state noise
# babybio_open_way_ssn: 	How was the BabyBio administered in steady state noise?
# babybio_open_db_ssn: 	What was the presentation level (dB HL) for the BabyBio in steady state noise?
# babybio_open_snr_ssn: 	Select signal-to-noise ratio in steady state noise
# babybio_open_per_ad_ssn: 	BabyBio: Enter the % correct in the right ear in steady state noise
# babybio_open_per_as_ssn: 	BabyBio: Enter the % correct in the left ear in steady state noise
# babybio_open_per_au_ssn: 	BabyBio: Enter the % correct in both ears in steady state noise
# babybio_open_item_sbn: 	BabyBio: Enter the number of items presented in speech babble noise
# babybio_open_way_sbn: 	How was the BabyBio administered in speech babble noise?
# babybio_open_db_sbn: 	What was the presentation level (dB HL) for the BabyBio in speech babble noise?
# babybio_open_snr_sbn: 	Select signal-to-noise ratio in speech babble noise
# babybio_open_per_ad_sbn: 	BabyBio: Enter the % correct in the right ear in speech babble noise
# babybio_open_per_as_sbn: 	BabyBio: Enter the % correct in the left ear in speech babble noise
# babybio_open_per_au_sbn: 	BabyBio: Enter the % correct in both ears in speech babble noise
# bkb_age: 	Age at time of testing (BKB-SIN)
# bkb_open_item: 	BKB: Enter the number of items presented
# bkb_open_db: 	What was the presentation level (dB HL) for the BKB-SIN?
# bkb_open_rs_ad: 	BKB: Enter SNR-50 (raw score) for the right ear
# bkb_open_rs_as: 	BKB: Enter SNR-50 (raw score) for the left ear
# bkb_open_rs_au: 	BKB: Enter SNR-50 (raw score) for the both ears
# bkb_open_per_ad: 	BKB: Select the SNR loss in the right ear
# bkb_open_per_as: 	BKB: Select the SNR loss in the left ear
# bkb_open_per_au: 	BKB: Select the SNR loss in both ears
# hint_age: 	Age at time of testing (HINT-C)
# hint_open_noise: 	Select background noise options
# hint_open_item: 	HINT-C: Enter the number of items presented in quiet
# hint_open_way: 	How were the HINT-C Sentences administered in quiet?
# hint_open_db: 	What was the presentation level (dB HL) for the HINT-C in quiet?
# hint_open_per_ad: 	HINT-C: Enter the % correct in the right ear in quiet
# hint_open_per_as: 	HINT-C: Enter the % correct in the left ear in quiet
# hint_open_per_au: 	HINT-C: Enter the % correct in both ears in quiet
# hint_open_item_ssn: 	HINT-C: Enter the number of items presented in steady state noise
# hint_open_way_ssn: 	How were the HINT-C Sentences administered in steady state noise?
# hint_open_db_ssn: 	What was the presentation level (dB HL) for the HINT-C in steady state noise?
# hint_open_snr_ssn: 	Select signal-to-noise ratio
# hint_open_per_ad_ssn: 	HINT-C: Enter the % correct in the right ear in steady state noise
# hint_open_per_as_ssn: 	HINT-C: Enter the % correct in the left ear in steady state noise
# hint_open_per_au_snn: 	HINT-C: Enter the % correct in both ears in steady state noise
# hint_open_item_sbn: 	HINT-C: Enter the number of items presented in speech babble noise
# hint_open_way_sbn: 	How were the HINT-C Sentences administered in speech babble noise?
# hint_open_db_sbn: 	What was the presentation level (dB HL) for the HINT-C in speech babble noise?
# hint_open_snr_sbn: 	Select signal-to-noise ratio
# hint_open_per_ad_sbn: 	HINT-C: Enter the % correct in the right ear in speech babble noise
# hint_open_per_as_sbn: 	HINT-C: Enter the % correct in the left ear in speech babble noise
# hint_open_per_au_sbn: 	HINT-C: Enter the % correct in both ears in speech babble noise
# otho_age: 	Age at time of testing (Other)
# oth_open_name: 	Enter the name of the test
# oth_open_item: 	Number of items presented
# oth_open_way: 	How was the test administered?
# oth_open_db: 	What was the presentation level (dB HL)?
# oth_open_per_ad: 	Enter the % correct in the right ear
# oth_open_per_as: 	Enter the % correct in the left ear
# oth_open_per_au: 	Enter the % correct in both ears
# othe2_age: 	Age at time of testing (Other)
# oth2_open_name: 	Enter the name of the test
# oth2_open_item: 	Number of items presented
# oth2_open_way: 	How was the test administered?
# oth2_open_db: 	What was the presentation level (dB HL)?
# oth2_open_per_ad: 	Enter the % correct in the right ear
# oth2_open_per_as: 	Enter the % correct in the left ear
# oth2_open_per_au: 	Enter the % correct in both ears
# oth3_age: 	Age at time of testing (Other)
# oth3_open_name: 	Enter the name of the test
# oth3_open_item: 	Number of items presented
# oth3_open_way: 	How was the test administered?
# oth3_open_db: 	What was the presentation level (dB HL)?
# oth3_open_per_ad: 	Enter the % correct in the right ear
# oth3_open_per_as: 	Enter the % correct in the left ear
# oth3_open_per_au: 	Enter the % correct in both ears
# test_sel9: 	Select the following tests completed.
# age_test_om: 	Age at time of testing
# om: 	Rate Oral Motor Skills
# age_test_voice: 	Age at time of testing
# voice: 	Rate Voice Quality
# age_test_flu: 	Age at time of testing
# fluency: 	Rate Fluency
# test_sel11: 	From the following list of tests, select the assessment(s) that were completed.
# age_ceg: 	Age at time of testing (CEG-Spanish)
# ceg_pd: 	CEG: PD Total Raw Score (aciertos; correct answers)
# ceg_nb: 	CEG: Raw score, bloque (correctos)
# ceg_ts_pr: 	CEG: Total Score Percentil Rank
# ceg_bs_pr: 	CEG: Bloque Score Percentil Rank
# age_test_eowpvts: 	Age at time of testing (EOWPVT-Spanish-Bilingual Edition)
# eowpvts_rs: 	EOWPVT-Spanish: Raw Score
# eowpvts_ss: 	EOWPVT-Spanish: Standard Score
# age_test_itpas: 	Age at time of testing (ITPA-Spanish)
# itpas_ca_rs: 	ITPA-S: Comprension auditiva raw score (listening comprehension)
# itpas_ca_pt: 	ITPA-S: Comprension auditiva puntuacion tipica (listening comprehension)
# itpas_cv_rs: 	ITPA-S: Comprension visual rs (visual comprehension)
# itpas_cv_pt: 	ITPA-S: Comprension visual puntuacion tipica (visual comprehension)
# itpas_msv_rs: 	ITPA-S: Memoria secuencial visomotora raw score (visual-motor memory)
# itpas_msv_pt: 	ITPA-S: Memoria secuencial visomotora puntuacion tipica (visual-motor memory)
# itpas_aa_rs: 	ITPA-S: Asociacion auditiva raw score (spoken analogies)
# itpas_aa_pt: 	ITPA-S: Asociacion auditiva puntuacion tipica (spoken analogies)
# itpas_msa_rs: 	ITPA-S: Memoria secuencial auditiva puntuacion tipica (sequential auditory memory)
# itpas_msa_pt: 	ITPA-S: Memoria secuencial auditiva raw score (sequential auditory memory)
# itpas_av_rs: 	ITPA-S: Asociacion visual raw score (visual analogies)
# itpas_av_pt: 	ITPA-S: Asociacion visual puntuacion tipica (visual analogies)
# itpas_iv_rs: 	ITPA-S: Integracion visual raw score (visual integration)
# itpas_iv_pt: 	ITPA-S: Integracion visual puntuacion tipica (visual integration)
# itpas_ev_rs: 	ITPA-S: Expresion verbal raw score (verbal expression)
# itpas_ev_pt: 	ITPA-S: Expresion verbal puntuacion tipica (verbal expression)
# itpas_ig_rs: 	ITPA-S: Integracion gramatical raw score (morphological closure)
# itpas_ig_pt: 	ITPA-S: Integracion gramatical puntuacion tipica morphological closure)
# itpas_em_rs: 	ITPA-S: Expresion motora raw score (gestures expression)
# itpas_em_pt: 	ITPA-S: Expresion motora puntuacion tipica (gestures expression)
# itpas_ia_rs: 	ITPA-S: Test complementario integracion auditiva raw score (phonological closure)
# itpas_ia_pt: 	ITPA-S: Test complementario integracion auditiva puntuacion tipica (phonological closure)
# age_test_mbs: 	Age at time of testing (MacArthur-Bates Inventario I)
# mbcdis_ec_rs: 	MacArthur - Bates-Inventario I: Comprension Temprana/Early Comprehension Raw Score
# mbcdis_epc_rs: 	MacArthur - Bates-Inventario I: Comprension de las Primeras Fraes/Early Phrase Comprehension
# mbcdis_mdh_rs: 	MacArthur - Bates-Inventario I: Maneras de Hablar Raw Score
# mbcdis_lv_rs: 	MacArthur - Bates-Inventario I: Lista de Vocabulario/Vocabulary List Raw Score
# mbcdis_pg_rs: 	MacArthur - Bates-Inventario I: Primeros Gestos/First Gestures Raw Score
# mbcdis_jar_rs: 	MacArthur - Bates-Inventario I: Juegos con Adultos y Rutinas/Routines & Games with Adults Raw Score
# mbcdis_ao_rs: 	MacArthur - Bates-Inventario I: Acciones con Objetos/Actions with Objects Raw Score
# mbcdis_jsa_rs: 	MacArthur - Bates-Inventario I: Jugar a Set Adulto/Pretencing to be an Adult Raw Score
# mbcdis_iota_rs: 	MacArthur - Bates-Inventario I: Imitacion de Otros Tipos de Actividades de Adultos/Imitation of Other Adult Activities Raw Score
# age_mbpe2: 	Age at time of testing (MacArthur - Bates-Inventario II)
# mbpe2_lv_rs: 	MacArthur - Bates-Inventario II: Lista de Vocabulario/Vocabulary List Raw Score
# mbpe2_cucn_rs: 	MacArthur - Bates-Inventario II: Como Usa y Comprende el Nino/a ie Lenguaje/Childr's Understanding and Use of Langauge Raw Score
# mbpe2_fv_rs: 	MacArthur - Bates-Inventario II: Formas de Verbos/ Verb Forms Raw Score
# mbpe2_cf_srs: 	MacArthur - Bates-Inventario II: Complejidad de Frases/Phrase Complexity Simple/Simple Raw Score
# mbpe2_cf_scs: 	MacArthur - Bates-Inventario II: Complejidad de Frases/Phrase Complexity Compeja/Complex Raw Score
# age_ppvts: 	Age at time of testing (PPVT:III-Spanish)
# ppvts_pd: 	PPVT:III-Spanish: Puntuacion directa (Raw score)
# ppvts_ci: 	PPVT:III-Spanish: CI (standard score)
# ppvts_s: 	PPVT: III-Spanish: Eneatipo (Stanine)
# ppvts_pr: 	PPVT: III-Spanish: Percentil Rank
# age_test_plsspan: 	Age at time of testing (PLS- Spanish)
# age_test_pls_ver: 	Select the PLS version administered
# plss_ac_rs: 	PLS-Spanish: Auditory Comprehension Raw Score
# plss_ac_ss: 	PLS-Spanish: Auditory Comprehension Standard Score
# plss_ec_rs: 	PLS-Spanish: Expressive Communication Raw Score
# plss_ec_ss: 	PLS-Spanish: Expressive Communication Standard Score
# plss_tl_rs: 	PLS-Spanish: Total Language Score Standard Score Total
# plss_tl_ss: 	PLS-Spanish: Total Language Score Standard Score
# age_test_rowpvts: 	Age at time of testing (ROWPVT-Spanish-Bilingual Edition)
# rowpvts_rs: 	ROWPVT-Spanish: Raw Score
# rowpvts_ss: 	ROWPVT-Spanish: Standard Score
# age_pe: 	Age at time of testing (Gardner Expresivo)
# pe_pb: 	Gardner Expresivo: Puntaje bruto (raw score)
# pe_ci: 	Gardner Expresivo: Cociente intelectual (standard score)
# pe_gdp: 	Gardner Expresivo: Grupo de pertenencia (stanine)
# age_pr: 	Age at time of testing (Gardner Receptivo)
# pr_pb: 	Gardner Receptivo: Puntaje bruto (raw score)
# pr_ci: 	Gardner Receptivo: Cociente intelectual (standard score)
# pr_gdp: 	Gardner Receptivo: Grupo de pertenencia (stanine)
# tato_age: 	Age at time of testing (Listas de palabras foneticamente balanceadas del Dr. Tato)
# tato_way: 	How was the Listas de palabras foneticamente balanceadas del Dr. Tato administered?
# tato_db: 	What was the presentation level (dB HL) for the Listas de palabras foneticamente balanceadas del Dr. Tato ?
# tato_per_ad: 	Listas de palabras foneticamente balanceadas del Dr. Tato: Enter the word % correct in the right ear
# tato_per_as: 	Listas de palabras foneticamente balanceadas del Dr. Tato: Enter the word % correct in the left ear
# tato_per_au: 	Listas de palabras foneticamente balanceadas del Dr. Tato:  Enter the word % correct in both ears
# sent_age: 	Age at time of testing (Listas de oraciones en Formato abierto Teresita Mansilla)
# sent_way: 	How was the Listas de oraciones en Formato abierto Teresita Mansilla administered?
# sent_db: 	What was the presentation level (dB HL) for the Listas de oraciones en Formato abierto Teresita Mansilla?
# sent_rs_ad: 	Listas de oraciones en Formato abierto Teresita Mansilla: Enter the raw score correct in the right ear
# sent_per_ad: 	Listas de oraciones en Formato abierto Teresita Mansilla: Enter the word % correct in the right ear
# sent_rs_as: 	Listas de oraciones en Formato abierto Teresita Mansilla: Enter the raw score correct in the left ear
# sent_per_as: 	Listas de oraciones en Formato abierto Teresita Mansilla: Enter the word % correct in the left ear
# sent_rs_au: 	Listas de oraciones en Formato abierto Teresita Mansill:  Enter the raw score correct in both ears
# sent_per_au: 	Listas de oraciones en Formato abierto Teresita Mansill:  Enter the word % correct in both ears
# vocales_age: 	Age at time of testing (Analisis de vocales)
# vocales_way: 	How was the Analisis de vocales administered?
# vocales_db: 	What was the presentation level (dB HL) for the Analisis de vocales?
# vocales_rs_ad: 	Analisis de vocales: Enter the raw score correct in the right ear
# vocales_per_ad: 	Analisis de vocales: Enter the word % correct in the right ear
# vocales_rs_as: 	Analisis de vocales: Enter the raw score correct in the left ear
# vocales_per_as: 	Analisis de vocales: Enter the word % correct in the left ear
# vocales_rs_au: 	Analisis de vocales:  Enter the raw score correct in both ears
# vocales_per_au: 	Analisis de vocales:  Enter the word % correct in both ears
# cons_age: 	Age at time of testing (Analisis de consonantes)
# cons_way: 	How was the Analisis de consonantes administered?
# cons_db: 	What was the presentation level (dB HL) for the Analisis de consonantes?
# cons_rs_ad: 	Analisis de consonantes: Enter the raw score correct in the right ear
# cons_per_ad: 	Analisis de consonantes: Enter the word % correct in the right ear
# cons_rs_as: 	Analisis de consonantes: Enter the raw score correct in the left ear
# cons_per_as: 	Analisis de consonantes: Enter the word % correct in the left ear
# cons_rs_au: 	Analisis de consonantes:  Enter the raw score correct in both ears
# cons_per_au: 	Analisis de consonantes:  Enter the word % correct in both ears
# ling_age: 	Age at time of testing (Test de Ling)
# ling_way: 	How was the Test de Ling administered?
# ling_db: 	What was the presentation level (dB HL) for the Test de Ling?
# ling_rs_au: 	Test de Ling:  Enter the raw score correct in both ears
# ling_per_au: 	Test de Ling:  Enter the word % correct in both ears
# esp_sp_age: 	Age at time of testing (ESP-Spanish)
# esp_sp_way: 	How was the ESP-Spanish administered?
# esp_sp_db: 	What was the presentation level (dB HL) for the ESP-Spanish?
# esp_sp_ver: 	Select version of the ESP-Spanish administered
# esp_sp_rs_au: 	ESP-Spanish:  Enter the raw score correct in both ears
# esp_sp_per_au: 	ESP-Spanish:  Enter the word % correct in both ears
# pips_age: 	Age at time of testing (PIP-S)
# pips_way: 	How was the PIP-S administered?
# pips_db: 	What was the presentation level (dB HL) for the PIP-S?
# pips_rs_au: 	PIP-S:  Enter the raw score correct in both ears
# pips_per_au: 	PIP-S:  Enter the word % correct in both ears
# pipv_age: 	Age at time of testing (PIPV)
# pipv_way: 	How was the PIPV administered?
# pipv_db: 	What was the presentation level (dB HL) for the PIPV?
# pipv_ver: 	Select version of the PIPV administered
# pipv_rs_au: 	PIPV:  Enter the raw score correct in both ears
# pipv_per_au: 	PIPV:  Enter the word % correct in both ears
# pipc_age: 	Age at time of testing (PIPC)
# pipc_way: 	How was the PIPC administered?
# pipc_db: 	What was the presentation level (dB HL) for the PIPC?
# pipc_ver: 	Select version of the PIPC administered
# pipc_rs_au: 	PIPC:  Enter the raw score correct in both ears
# pipc_per_au: 	PIPC:  Enter the word % correct in both ears

# %% [markdown]
# Import each database from REDCap:

# %%
articulation_fields = ['study_id','redcap_event_name','age_test_aaps','aaps_ss','age_test_gf2','gf2_ss']
articulation = lsl_dr_project.export_records(fields=articulation_fields, format='df', df_kwargs={'index_col':None})

# %%
expressive_fields = ['study_id','redcap_event_name','age_test_eowpvt','eowpvt_ss','age_test_evt','evt_ss']
expressive = lsl_dr_project.export_records(fields=expressive_fields, format='df', df_kwargs={'index_col':None})

# %%
receptive_fields = ['study_id','redcap_event_name','age_test_ppvt','ppvt_ss','age_test_rowpvt','rowpvt_ss']
receptive = lsl_dr_project.export_records(fields=receptive_fields, format='df', df_kwargs={'index_col':None})

# %%
language_fields = ['study_id','redcap_event_name','pls_ac_ss','pls_ec_ss','pls_choice','age_test_pls',
                   'owls_lc_ss','owls_oe_ss','age_test_owls',
                   'celfp_rl_ss','celfp_el_ss','age_test_celp',
                   'celf_elss','celf_rlss','age_test_celf']
language_raw = lsl_dr_project.export_records(fields=language_fields, format='df', df_kwargs={'index_col':None})

# %%
language_raw
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8216 entries, 0 to 8215
# Data columns (total 16 columns):
# study_id             8216  non-null values
# redcap_event_name    8216  non-null values
# age_test_celp        1104  non-null values
# celfp_rl_ss          1024  non-null values
# celfp_el_ss          1023  non-null values
# age_test_celf        596  non-null values
# celf_rlss            449  non-null values
# celf_elss            471  non-null values
# age_test_owls        536  non-null values
# owls_lc_ss           574  non-null values
# owls_oe_ss           565  non-null values
# age_test_pls         1985  non-null values
# pls_choice___0       8216  non-null values
# pls_choice___1       8216  non-null values
# pls_ac_ss            1982  non-null values
# pls_ec_ss            1979  non-null values
# dtypes: float64(12), int64(2), object(2)

# %%
demographic_fields = ['study_id','redcap_event_name','redcap_data_access_group',
'hl','prim_lang','mother_ed','premature_age',
'onset_1','age_int','age','age_ci','degree_hl_ad','type_hl_ad','tech_ad','degree_hl_as',
'type_hl_as','tech_as','etiology','etiology_2']
demographic = lsl_dr_project.export_records(fields=demographic_fields, format='df', df_kwargs={'index_col':None})

# %%
demographic.etiology.value_counts()
# Out:
# 1    2356
# 0     527
# 3     213
# 2     105
# dtype: int64

# %% [markdown]
# ## Cleaning languge dataset
#
# 5 language measures:
#
# - 3 versions of CELF
# - PLS
#     - pls_ac_rs: 	PLS: Auditory Comprehension Raw Score
#     - pls_ac_ss: 	PLS: Auditory Comprehension Standard Score
#     - pls_ec_rs: 	PLS: Expressive Communication Raw Score
#     - pls_ec_ss: 	PLS: Expressive Communication Standard Score
#     - pls_tl_rs: 	PLS: Total Language Score Standard Score Total
#     - pls_tl_ss: 	PLS: Total Language Score Standard Score
# - OWLS
#     - age_test_owls: 	Age at time of testing (OWLS)
#     - owls_lc_rs: 	OWLS: Listening Comprehension Raw Score
#     - owls_lc_ss: 	OWLS: Listening Comprehension Standard Score
#     - owls_oe_rs: 	OWLS: Oral Expression Raw Score
#     - owls_oe_ss: 	OWLS: Oral Expression Standard Score
#     - owls_oc_sss: 	OWLS: Oral Composite Sum of Listening Comprehension and Oral Expression Standard Scores
#     - owls_oc_ss: 	OWLS: Oral Composite Standard Score
#     - owls_wes_trs: 	OWLS: Written Expression Scale Total Raw Score
#     - owls_wes_as: 	OWLS: Written Expression Scale Ability Score
#     - owls_wes_ss: 	OWLS: Written Expression Scale Standard Score
#     - owsl_lc: 	OWLS: Written Expression Scale Language Composite (Sum of written expression age-based standard score, listening comprehension standard score and oral expression standard score)
#     - owls_lcss: 	OWLS: Language Composite Standard Score

# %%
# Test type
language_raw["test_name"] = None
language_raw["test_type"] = None
language_raw["test_name"] = None
language_raw["score"] = None
CELP = language_raw.age_test_celp.notnull()
CELF = language_raw.age_test_celf.notnull()
PLS = language_raw.age_test_pls.notnull()
OWLS = language_raw.age_test_owls.notnull()

language_raw['age_test'] = None
language_raw['age_test'][CELP] = language_raw.age_test_celp
language_raw['age_test'][CELF] = language_raw.age_test_celf
language_raw['age_test'][PLS] = language_raw.age_test_pls
language_raw['age_test'][OWLS] = language_raw.age_test_owls

language1 = language_raw[CELP | CELF | PLS | OWLS]
language2 = language1.copy()

language1["test_type"][CELP] = "CELF-P2 Receptive Language"
language1["test_type"][CELF] = "CELF-4 Receptive Language"
language1["test_type"][PLS] = "PLS Auditory Comprehension"
language1["test_type"][OWLS] = "OWLS Listening Comprehension"

language1["score"][CELP] = language1.celfp_rl_ss
language1["score"][CELF] = language1.celf_rlss
language1["score"][PLS] = language1.pls_ac_ss
language1["score"][OWLS] = language1.owls_lc_ss


language2["test_type"][CELP] = "CELF-P2 Expressive Language"
language2["test_type"][CELF] = "CELF-4 Expressive Language"
language2["test_type"][PLS] = "PLS Expressive Comprehension"
language2["test_type"][OWLS] = "OWLS Oral Expression"

language2["score"][CELP] = language1.celfp_el_ss
language2["score"][CELF] = language1.celf_elss
language2["score"][PLS] = language1.pls_ec_ss
language2["score"][OWLS] = language1.owls_oe_ss

language = pd.concat([language1, language2])

print language.test_type.value_counts()
print("There are {0} null values for score".format(sum(language["score"].isnull())))
# Out:
# PLS Expressive Comprehension    1920
# PLS Auditory Comprehension      1920
# CELF-P2 Receptive Language       847
# CELF-P2 Expressive Language      847
# OWLS Oral Expression             536
# OWLS Listening Comprehension     536
# CELF-4 Expressive Language       460
# CELF-4 Receptive Language        460
# dtype: int64
# There are 527 null values for score

# %% [markdown]
# A `school` variable was added, which is the first four columns of the `study_id`:

# %%
language["school"] = language.study_id.str.slice(0,4)

# %%
language = language[["study_id", "score", "test_type", "school", "age_test"]]
language["domain"] = "Language"
language.head()
# Out:
#           study_id score                     test_type school age_test    domain
# 2   0101-2003-0101   NaN    PLS Auditory Comprehension   0101       54  Language
# 7   0101-2003-0101    61  OWLS Listening Comprehension   0101      113  Language
# 11  0101-2003-0102    55    PLS Auditory Comprehension   0101       44  Language
# 12  0101-2003-0102    77    PLS Auditory Comprehension   0101       54  Language
# 13  0101-2003-0102    93    CELF-P2 Receptive Language   0101       68  Language

# %% [markdown]
# ## Cleaning articulation dataset
#
# We converted the articulation dataset into a "long" format:

# %%
# Test type
articulation["test_type"] = None
ARIZ = articulation.aaps_ss.notnull()
GF = articulation.gf2_ss.notnull()
articulation = articulation[ARIZ | GF]
articulation["test_type"][ARIZ & GF] = "Arizonia and Goldman"
articulation["test_type"][ARIZ & GF-True] = "Arizonia"
articulation["test_type"][ARIZ-True & GF] = "Goldman"

print articulation.test_type.value_counts()
print("There are {0} null values for test_type".format(sum(articulation["test_type"].isnull())))

# Test score (Arizonia if both)
articulation["score"] = articulation.aaps_ss
articulation["score"][ARIZ-True & GF] = articulation.gf2_ss[ARIZ-True & GF]
# Out:
# Goldman                 2696
# Arizonia                 421
# Arizonia and Goldman      17
# dtype: int64
# There are 0 null values for test_type

# %% [markdown]
# A `school` variable was added, which is the first four columns of the `study_id`:

# %%
articulation["school"] = articulation.study_id.str.slice(0,4)

# %% [markdown]
# The age was taken to be the Arizonia age if there are both test types:

# %%
articulation["age_test"] = articulation.age_test_aaps
articulation.age_test[articulation.age_test.isnull()] = articulation.age_test_gf2[articulation.age_test.isnull()]
print articulation.age_test.describe()
# Out:
# count    3132.000000
# mean       67.092593
# std        29.259416
# min         0.000000
# 25%        47.000000
# 50%        59.000000
# 75%        78.000000
# max       243.000000
# dtype: float64

# %% [markdown]
# Finally, we dropped unwanted columns and added a domain identification column for merging:

# %%
articulation.columns
# Out:
# Index([u'study_id', u'redcap_event_name', u'age_test_aaps', u'aaps_ss', u'age_test_gf2', u'gf2_ss', u'test_type', u'score', u'school', u'age_test'], dtype=object)

# %%
articulation = articulation.drop(["redcap_event_name", "age_test_aaps", "age_test_gf2", "aaps_ss", "gf2_ss"], axis=1)
articulation["domain"] = "Articulation"
articulation.head()
# Out:
#           study_id test_type  score school  age_test        domain
# 3   0101-2003-0101   Goldman     78   0101        80  Articulation
# 11  0101-2003-0102   Goldman     72   0101        44  Articulation
# 12  0101-2003-0102   Goldman     97   0101        54  Articulation
# 16  0101-2004-0101   Goldman     75   0101        53  Articulation
# 17  0101-2004-0101   Goldman     80   0101        66  Articulation

# %% [markdown]
# ## Cleaning demographic dataset
#
# We excluded unwanted columns and rows for which age, gender or race were missing:

# %%
# Retain only subset of columns
#demographic = demographic[demographic.age.notnull()]

# %% [markdown]
# Due to sample size considerations, we reduced the non-English primary language variable to English (0) and non-English (1):

# %%
demographic["non_english"] = None
demographic.non_english[demographic.prim_lang.notnull()] = demographic.prim_lang[demographic.prim_lang.notnull()]>0
print demographic.non_english.value_counts()
print("There are {0} null values for non_english".format(sum(demographic.non_english.isnull())))
# Out:
# False    2335
# True      482
# dtype: int64
# There are 5399 null values for non_english

# %% [markdown]
# Mother's education (`mother_ed`) and father's education (`father_ed`) were both recoded to:
#
# * 0=no high school diploma
# * 1=high school
# * 2=undergraduate
# * 3=graduate
#
# Category 6 (unknown) was recoded as missing.

# %%
demographic = demographic.rename(columns={"mother_ed":"_mother_ed"})
demographic["mother_ed"] = demographic._mother_ed.copy()
demographic.mother_ed[demographic._mother_ed==1] = 0
demographic.mother_ed[(demographic._mother_ed==2) | (demographic.mother_ed==3)] = 1
demographic.mother_ed[demographic._mother_ed==4] = 2
demographic.mother_ed[demographic._mother_ed==5] = 3
demographic.mother_ed[demographic._mother_ed==6] = None
print("_mother_ed:")
print demographic._mother_ed.value_counts()
print("mother_ed:")
print demographic.mother_ed.value_counts()
print("\nThere are {0} null values for mother_ed".format(sum(demographic.mother_ed.isnull())))
# Out:
# _mother_ed:
# 6    779
# 4    560
# 3    392
# 5    318
# 2    240
# 1    108
# 0     46
# dtype: int64
# mother_ed:
# 1    632
# 2    560
# 3    318
# 0    154
# dtype: int64
#
# There are 6552 null values for mother_ed

# %% [markdown]
# Secondary diagnosis

# %%
demographic['secondary_diagnosis'] = demographic.etiology==0

# %%
demographic.secondary_diagnosis.value_counts()
# Out:
# False    7689
# True      527
# dtype: int64

# %%
demographic.secondary_diagnosis.mean()
# Out:
# 0.064143135345666985

# %% [markdown]
# Premature status was recoded to True (premature) and False (full-term). Here, premature indicates <36 weeks.

# %%
demographic['premature_weeks'] = demographic.premature_age.copy()
demographic.premature_weeks[demographic.premature_age==9] = None
demographic.premature_weeks = abs(demographic.premature_weeks-8)*2
print("There are {0} null values for premature_weeks".format(sum(demographic.premature_weeks.isnull())))
# Out:
# There are 5983 null values for premature_weeks

# %%
demographic.premature_weeks.value_counts()
# Out:
# 0     1904
# 2      112
# 4       72
# 12      43
# 10      34
# 6       33
# 8       24
# 14       9
# 16       2
# dtype: int64

# %% [markdown]
# `hearing_loss_birth` was added to indicate whether individuals had hearing loss within the first 3 months of life:

# %%
'''
demographic["hearing_loss_birth"] = pd.Series((demographic.onset==1) | (demographic.onset==3), dtype=object)
demographic.hearing_loss_birth[demographic.onset==2] = None
print("onset:")
print demographic.onset.value_counts()
print("\nhearing_loss_birth:")
print demographic.hearing_loss_birth.value_counts()
print("There are {0} null values for hearing_loss_birth".format(sum(demographic.hearing_loss_birth.isnull())))
'''
# Out:
# '\ndemographic["hearing_loss_birth"] = pd.Series((demographic.onset==1) | (demographic.onset==3), dtype=object)\ndemographic.hearing_loss_birth[demographic.onset==2] = None\nprint("onset:")\nprint demographic.onset.value_counts()\nprint("\nhearing_loss_birth:")\nprint demographic.hearing_loss_birth.value_counts()\nprint("There are {0} null values for hearing_loss_birth".format(sum(demographic.hearing_loss_birth.isnull())))\n'

# %% [markdown]
# Recode impant technology variables for each ear to one of four categories (None, Baha, Hearing aid, Cochlear implant):

# %%
tech_cats = ["None", "Baha", "Hearing aid", "Cochlear"]

demographic["tech_right"] = demographic.tech_ad.copy()
demographic.tech_right[demographic.tech_right==6] = 0
demographic.tech_right[demographic.tech_right==4] = 1
demographic.tech_right[demographic.tech_right==5] = 1
demographic.tech_right[demographic.tech_right==3] = 2
demographic.tech_right[demographic.tech_right==7] = 3
demographic.tech_right = np.abs(demographic.tech_right - 3)

demographic["tech_left"] = demographic.tech_as.copy()
demographic.tech_left[demographic.tech_left==6] = 0
demographic.tech_left[demographic.tech_left==4] = 1
demographic.tech_left[demographic.tech_left==5] = 1
demographic.tech_left[demographic.tech_left==3] = 2
demographic.tech_left[demographic.tech_left==7] = 3
demographic.tech_left = np.abs(demographic.tech_left - 3)

# %% [markdown]
# Substitute valid missing values for hearing loss:

# %%
demographic.type_hl_ad[demographic.type_hl_ad==5] = None
demographic.type_hl_as[demographic.type_hl_as==5] = None

# %% [markdown]
# Create `degree_hl`, which is the maximum level of hearing loss in either ear:

# %%
demographic["degree_hl"] = np.maximum(demographic.degree_hl_ad, demographic.degree_hl_as)

# %% [markdown]
# Create compound indicator variable for each technology (Baha, Hearing aid, Chochlear implant):
#
# * 0=none
# * 1=one ear
# * 2=both ears.

# %%
demographic["baha"] = 0
demographic.baha = demographic.baha.astype(object)
demographic.baha[(demographic.tech_right==1) | (demographic.tech_left==1)] = 1
demographic.baha[(demographic.tech_right==1) & (demographic.tech_left==1)] = 2
demographic.baha[(demographic.tech_right.isnull()) & (demographic.tech_left.isnull())] = None
print("baha:")
print demographic.baha.value_counts()
print("There are {0} null values for baha".format(sum(demographic.baha.isnull())))

demographic["hearing_aid"] = 0
demographic.hearing_aid = demographic.hearing_aid.astype(object)
demographic.hearing_aid[(demographic.tech_right==2) | (demographic.tech_left==2)] = 1
demographic.hearing_aid[(demographic.tech_right==2) & (demographic.tech_left==2)] = 2
demographic.hearing_aid[(demographic.tech_right.isnull()) & (demographic.tech_right.isnull())] = None
print("\nhearing_aid:")
print demographic.hearing_aid.value_counts()
print("There are {0} null values for hearing_aid".format(sum(demographic.hearing_aid.isnull())))

demographic["cochlear"] = 0
demographic.cochlear = demographic.cochlear.astype(object)
demographic.cochlear[(demographic.tech_right==3) | (demographic.tech_left==3)] = 1
demographic.cochlear[(demographic.tech_right==3) & (demographic.tech_left==3)] = 2
demographic.cochlear[(demographic.tech_right.isnull()) & (demographic.tech_left.isnull())] = None
print("\ncochlear:")
print demographic.cochlear.value_counts()
print("There are {0} null values for cochlear".format(sum(demographic.cochlear.isnull())))
print len(demographic)
# Out:
# baha:
# 0    5673
# 1     161
# 2      75
# dtype: int64
# There are 2307 null values for baha
#
# hearing_aid:
# 0    2689
# 2    2207
# 1     961
# dtype: int64
# There are 2359 null values for hearing_aid
#
# cochlear:
# 0    3110
# 2    1631
# 1    1168
# dtype: int64
# There are 2307 null values for cochlear
# 8216

# %% [markdown]
# Identify bilateral and bimodal individuals:

# %%
demographic["bilateral"] = demographic.cochlear==2
demographic["bimodal"] = (demographic.cochlear==1) & (demographic.hearing_aid==1)

# %%
demographic.bilateral.sum(), demographic.bimodal.sum()
# Out:
# (1631, 705)

# %% [markdown]
# Filter out non-bilateral/bimodal individuals:

# %%
demographic = demographic[demographic.bilateral | demographic.bimodal]

# %%
demographic['type'] = np.where(demographic.bilateral, 'bilateral', 'bimodal')

# %%
demographic
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2336 entries, 17 to 8208
# Data columns (total 31 columns):
# study_id               2336  non-null values
# redcap_event_name      2336  non-null values
# hl                     1408  non-null values
# prim_lang              760  non-null values
# _mother_ed             667  non-null values
# premature_age          708  non-null values
# onset_1                298  non-null values
# age_int                234  non-null values
# age                    883  non-null values
# etiology               878  non-null values
# etiology_2             275  non-null values
# degree_hl_ad           2203  non-null values
# type_hl_ad             2194  non-null values
# tech_ad                2336  non-null values
# age_ci                 642  non-null values
# degree_hl_as           2197  non-null values
# type_hl_as             2197  non-null values
# tech_as                2336  non-null values
# non_english            760  non-null values
# mother_ed              458  non-null values
# secondary_diagnosis    2336  non-null values
# premature_weeks        538  non-null values
# tech_right             2336  non-null values
# tech_left              2336  non-null values
# degree_hl              2187  non-null values
# baha                   2336  non-null values
# hearing_aid            2336  non-null values
# cochlear               2336  non-null values
# bilateral              2336  non-null values
# bimodal                2336  non-null values
# type                   2336  non-null values
# dtypes: bool(3), float64(20), object(8)

# %% [markdown]
# ## Cleaning expressive vocabulary dataset
#
# We converted the expressive vocabulary dataset to "long" format:

# %%
# Test type
expressive["test_type"] = None
EOWPVT = expressive.eowpvt_ss.notnull()
EVT = expressive.evt_ss.notnull()
expressive = expressive[EOWPVT | EVT]
expressive["test_type"][EOWPVT & EVT] = "EOWPVT and EVT"
expressive["test_type"][EOWPVT & (EVT-True)] = "EOWPVT"
expressive["test_type"][(EOWPVT-True) & EVT] = "EVT"
print("There are {0} null values for test_type".format(sum(expressive["test_type"].isnull())))

expressive["score"] = expressive.eowpvt_ss
expressive["score"][EOWPVT-True & EVT] = expressive.evt_ss[(EOWPVT-True) & EVT]
# Out:
# There are 0 null values for test_type

# %%
expressive.test_type.value_counts()
# Out:
# EVT               2263
# EOWPVT            1489
# EOWPVT and EVT      78
# dtype: int64

# %% [markdown]
# A `school` variable was added, which is the first four columns of the `study_id`:

# %%
expressive["school"] = expressive.study_id.str.slice(0,4)

# %% [markdown]
# The age was taken to be the EOWPVT age if there are both test types:

# %%
expressive["age_test"] = expressive.age_test_eowpvt
expressive.age_test[expressive.age_test.isnull()] = expressive.age_test_evt[expressive.age_test.isnull()]

# %% [markdown]
# Finally, we dropped unwanted columns and added a domain identification column for merging:

# %%
expressive = expressive[["study_id", "score", "test_type", "school", "age_test"]]
expressive["domain"] = "Expressive Vocabulary"
expressive.head()
# Out:
#           study_id  score test_type school  age_test                 domain
# 2   0101-2003-0101     60    EOWPVT   0101        54  Expressive Vocabulary
# 4   0101-2003-0101     84    EOWPVT   0101        80  Expressive Vocabulary
# 7   0101-2003-0101     90    EOWPVT   0101       113  Expressive Vocabulary
# 16  0101-2004-0101     90    EOWPVT   0101        53  Expressive Vocabulary
# 17  0101-2004-0101     87    EOWPVT   0101       NaN  Expressive Vocabulary

# %%
expressive
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3830 entries, 2 to 8207
# Data columns (total 6 columns):
# study_id     3830  non-null values
# score        3830  non-null values
# test_type    3830  non-null values
# school       3830  non-null values
# age_test     3807  non-null values
# domain       3830  non-null values
# dtypes: float64(2), object(4)

# %% [markdown]
# ## Cleaning receptive vocabulary dataset

# %% [markdown]
# We converted the receptive vocabulary data table to "long" format:

# %%
receptive.columns
# Out:
# Index([u'study_id', u'redcap_event_name', u'age_test_ppvt', u'ppvt_ss', u'age_test_rowpvt', u'rowpvt_ss'], dtype=object)

# %%
# Test type
receptive["test_type"] = None
PPVT = receptive.ppvt_ss.notnull()
ROWPVT = receptive.rowpvt_ss.notnull()
receptive = receptive[PPVT | ROWPVT]
receptive["test_type"][PPVT & ROWPVT] = "PPVT and ROWPVT"
receptive["test_type"][PPVT & (ROWPVT-True)] = "PPVT"
receptive["test_type"][(PPVT-True) & ROWPVT] = "ROWPVT"
print("There are {0} null values for test_type".format(sum(receptive["test_type"].isnull())))

receptive["score"] = receptive.ppvt_ss
receptive["score"][(PPVT-True) & ROWPVT] = receptive.rowpvt_ss[(PPVT-True) & ROWPVT]
# Out:
# There are 0 null values for test_type

# %% [markdown]
# A `school` variable was added, which is the first four columns of the `study_id`:

# %%
receptive["school"] = receptive.study_id.str.slice(0,4)

# %% [markdown]
# The age was taken to be the PPVT age if there are both test types:

# %%
receptive["age_test"] = receptive.age_test_ppvt
receptive.age_test[receptive.age_test.isnull()] = receptive.age_test_rowpvt[receptive.age_test.isnull()]

# %% [markdown]
# Finally, we dropped unwanted columns and added a domain identification column for merging:

# %%
receptive = receptive[["study_id", "score", "test_type", "school", "age_test"]]
receptive["domain"] = "Receptive Vocabulary"
receptive.head()
# Out:
#           study_id  score test_type school  age_test                domain
# 4   0101-2003-0101     90      PPVT   0101        80  Receptive Vocabulary
# 7   0101-2003-0101    101    ROWPVT   0101       113  Receptive Vocabulary
# 11  0101-2003-0102     55      PPVT   0101        44  Receptive Vocabulary
# 12  0101-2003-0102     80      PPVT   0101        54  Receptive Vocabulary
# 13  0101-2003-0102    101      PPVT   0101        68  Receptive Vocabulary

# %% [markdown]
# ## Merge datasets
#
# The four datasets were mereged into a single table. First, we concatenate the test scores data:

# %%
test_scores = pd.concat([articulation, expressive, receptive, language])

# %% [markdown]
# Then we perform a merge between the demographic data and the test scores data:

# %%
test_scores
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18444 entries, 3 to 8207
# Data columns (total 6 columns):
# age_test     18373  non-null values
# domain       18444  non-null values
# school       18444  non-null values
# score        17917  non-null values
# study_id     18444  non-null values
# test_type    18444  non-null values
# dtypes: object(6)

# %%
lsl_dr = pd.merge(demographic, test_scores, on="study_id")
lsl_dr = lsl_dr[lsl_dr.score.notnull() & lsl_dr.age.notnull() & lsl_dr.age_test.notnull() & lsl_dr.score.notnull()]

# %%
lsl_dr.score = lsl_dr.score.astype(float)

# %%
lsl_dr.shape
# Out:
# (5398, 36)

# %%
lsl_dr.hist(column='age', by=lsl_dr.type)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1118be690>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1119b7610>], dtype=object)

# %%
def score_summary(domain, bimodal=False):
    subset = lsl_dr[(lsl_dr.domain==domain) & (lsl_dr.bimodal==bimodal)]
    subset['age_test'] = (subset.age_test/12).dropna().astype(int)
    subset.age_test[subset.age_test > 11] = 11
    subset = subset[subset.age_test>1]
    byage = subset.groupby('age_test')
    n = byage.study_id.count()
    mean = byage.score.mean()
    sd = byage.score.std()
    min = byage.score.min()
    max = byage.score.max()
    summary = pd.DataFrame({'Sample Size':n, 'Mean':mean, 
    'SD':sd, 'Min':min, 'Max':max})
    return summary[['Sample Size','Mean','SD','Min','Max']]

# %%
receptive_summary = pd.concat([score_summary("Receptive Vocabulary", bimodal=True), 
                               score_summary("Receptive Vocabulary", bimodal=False)], keys=['bimodal','bilateral'])
receptive_summary
# Out:
#                     Sample Size       Mean         SD  Min  Max
#           age_test
# bimodal   2                  12  87.583333  24.081144   47  128
#           3                  55  83.000000  19.150476   40  140
#           4                  78  85.051282  16.262376   55  131
#           5                  73  82.232877  16.285236   40  114
#           6                  43  77.674419  13.934747   40  102
#           7                  30  73.566667  15.426541   41  103
#           8                  17  70.117647  19.448272   40   93
#           9                  11  69.090909  24.373980   40  113
#           10                  9  65.444444  15.460523   40   93
#           11                 17  63.823529  13.866485   44   92
# bilateral 2                  46  88.717391  20.026275   40  129
#           3                 158  85.867089  20.682650   36  141
#           4                 198  87.505051  18.998196   40  139
#           5                 150  84.933333  16.410697   40  123
#           6                  87  83.080460  13.802779   49  118
#           7                  65  80.261538  13.753723   42  110
#           8                  39  75.358974  13.590800   44  112
#           9                  27  71.777778  23.950804   25  160
#           10                 18  69.000000  12.672341   37   97
#           11                 29  68.482759  20.461847   20  123

# %%
def plot_summary(summary_data, var='Sample Size', color='seagreen'):
    fig, axes = plt.subplots(nrows=1, ncols=2)
    var = 'Sample Size'
    for m,mode in enumerate(['bimodal', 'bilateral']):
        summary_data.ix[mode][var].plot(ax=axes[m], kind='bar', grid=False, color=color)
        axes[m].set_title(mode)
        for i,x in enumerate(summary_data.ix[mode][var]):
            axes[m].annotate('%i' % x, (i+0.5, x+1), va="bottom", ha="center")

# %%
plot_summary(receptive_summary)

# %%
expressive_summary = pd.concat([score_summary("Expressive Vocabulary", bimodal=True), 
                               score_summary("Expressive Vocabulary", bimodal=False)], keys=['bimodal','bilateral'])
expressive_summary
# Out:
#                     Sample Size       Mean         SD  Min  Max
#           age_test
# bimodal   2                  17  86.235294  21.695418   55  123
#           3                  50  83.840000  21.985487   50  145
#           4                  76  86.789474  20.096644   55  140
#           5                  72  84.222222  18.942628   45  130
#           6                  42  77.357143  14.333691   47  106
#           7                  30  74.900000  16.369336   38  107
#           8                  15  74.733333  18.828044   40   99
#           9                   9  71.888889  19.009501   55  113
#           10                  9  69.666667  15.866632   52  100
#           11                 18  74.611111  10.874357   58  100
# bilateral 2                  46  89.021739  26.938192   23  141
#           3                 153  86.738562  23.731162   39  145
#           4                 196  87.428571  22.547500    0  140
#           5                 153  85.673203  17.682444   40  130
#           6                  89  85.325843  15.382823   45  112
#           7                  68  83.647059  15.088559   59  130
#           8                  36  79.111111  14.998624   55  113
#           9                  26  75.384615  22.067310   36  145
#           10                 19  74.526316  12.549318   55   94
#           11                 27  77.518519  21.260962   36  139

# %%
plot_summary(expressive_summary)

# %%
articulation_summary = pd.concat([score_summary("Articulation", bimodal=True), 
                               score_summary("Articulation", bimodal=False)], keys=['bimodal','bilateral'])
articulation_summary
# Out:
#                     Sample Size       Mean         SD  Min  Max
#           age_test
# bimodal   2                  10  88.100000  12.931014   63  103
#           3                  40  77.400000  15.239624   50  101
#           4                  66  76.515152  20.708410   39  119
#           5                  67  78.477612  19.146452   40  111
#           6                  37  74.972973  21.461188   39  109
#           7                  27  72.296296  21.359226   39  108
#           8                  14  68.214286  26.347321   40  106
#           9                   8  67.500000  15.638780   40   84
#           10                  5  75.000000  21.517435   40   94
#           11                 15  79.533333  14.196914   55  103
# bilateral 2                  34  80.117647  14.692329   53  110
#           3                 119  77.126050  19.079475   40  120
#           4                 164  78.750000  19.915273   40  118
#           5                 137  78.744526  21.151425   39  113
#           6                  82  77.219512  20.216131   40  110
#           7                  61  78.295082  21.047046   35  107
#           8                  25  71.160000  23.497659   40  103
#           9                  16  72.000000  25.043961   39  106
#           10                 13  72.538462  23.708702   40  100
#           11                 14  72.500000  15.751679   47  100

# %%
plot_summary(articulation_summary)

# %%
language_summary = pd.concat([score_summary("Language", bimodal=True), 
                               score_summary("Language", bimodal=False)], keys=['bimodal','bilateral'])
language_summary
# Out:
#                     Sample Size       Mean         SD  Min  Max
#           age_test
# bimodal   2                  48  79.229167  20.737713   52  150
#           3                 113  75.743363  16.888171   50  132
#           4                 126  76.214286  16.713399   45  124
#           5                 104  77.932692  17.833243   45  114
#           6                  52  70.307692  13.936183   47   98
#           7                  52  64.057692  15.789564   45   98
#           8                  24  62.375000  18.191762   45  115
#           9                   8  51.250000   7.611082   40   61
#           11                 10  92.500000  16.507574   71  115
# bilateral 2                 197  80.761421  21.020858   50  146
#           3                 334  79.664671  21.516698   50  145
#           4                 342  79.476608  20.116910   48  141
#           5                 287  76.675958  17.959635   45  129
#           6                 146  72.767123  17.968954   44  115
#           7                 123  68.780488  18.519611   40  108
#           8                  57  66.298246  19.232566   40   99
#           9                  16  73.062500  21.889019   40  102
#           10                 14  64.285714  21.762454   40  110
#           11                  4  67.250000  26.272609   40   94

# %%
for t in language.test_type.value_counts().index:
    lsl_dr[lsl_dr.test_type==t].boxplot(column='score', by='bimodal')
    xlabel(t)

# %%
demographic.bimodal.sum()
# Out:
# 705

# %%
demographic.bilateral.sum()
# Out:
# 1631

# %%
demographic.degree_hl.value_counts()
# Out:
# 6    1973
# 5     182
# 4      21
# 2       5
# 3       3
# 1       3
# dtype: int64

# %% [markdown]
# ## Test Score Model

# %%
from pymc import Bernoulli, Normal, Uniform, invlogit, logit, deterministic, MCMC, Matplot
from pymc import Lambda, Dirichlet, Categorical, DiscreteUniform, Exponential

def generate_model(dataset):
    
    # Extract data to local variables
    age = np.array(dataset.age)
    school = np.array(dataset.school)
    study_id = np.array(dataset.study_id)
    score = np.array(dataset.score)
    bimodal = np.array(dataset.bimodal)
    
    # Transform some data
    age_std = (age - age.mean())/12.
    
    # Imputation of primary language
    p_lang = Uniform('p_lang', 0, 1, value=0.1)
    non_english_masked = np.ma.masked_array(dataset.non_english.values, dataset.non_english.isnull(), fill_value=0)
    non_english = Bernoulli('non_english', p=p_lang, value=non_english_masked, observed=True)
    
    # Imputation of premature
    prem_masked = np.ma.masked_array(dataset.premature_weeks.values, dataset.premature_weeks.isnull(), fill_value=0)
    prem = DiscreteUniform('p_prem', 0, 16, value=prem_masked, observed=True)
    
    # Imputation of age of cochlear implant
    beta_ci = Uniform('beta_ci', 0, 100, value=30)
    age_ci_masked = np.ma.masked_array(dataset.age_ci.values, dataset.age_ci.isnull(), fill_value=0)
    age_ci = Exponential('age_ci', 1./beta_ci, value=age_ci_masked, observed=True)
    
    # Imputation of hearing loss
    hl_cats = 7
    p_hl = Dirichlet("p_hl", np.ones(hl_cats), value=[1./hl_cats]*(hl_cats-1))
    hl_masked = np.ma.masked_array(dataset.degree_hl.values, dataset.degree_hl.isnull(), fill_value=6)
    hl = Categorical('hl', p_hl, value=hl_masked, observed=True)

    
    mean_score = Normal("mean_score", 0, 0.001, value=100)
    
    # Indices to school random effects
    unique_schools = np.unique(school)
    school_index = [list(unique_schools).index(s) for s in school]

    # School random effect
    sigma_school = Uniform("sigma_school", 0, 1000, value=1)
    tau_school = sigma_school**-2
    alpha_school = Normal("alpha_school", mu=0, tau=tau_school, value=np.zeros(len(unique_schools)))
    
    # Indices to child random effects
    unique_child = np.unique(study_id)
    child_index = [list(unique_child).index(s) for s in study_id]
    
    # Individual random effect
    sigma_child = Uniform("sigma_child", 0, 1000, value=1)
    tau_child = sigma_child**-2    
    alpha_child = Normal("alpha_child", mu=50, tau=tau_child, value=np.zeros(len(unique_child)))
    
    @deterministic
    def intercept(a0=mean_score, a1=alpha_child, a2=alpha_school):
        """Random intercepts"""
        return a0 + a2[school_index] + a1[child_index]
    
    # Age effect
    beta_age = Normal("beta_age", mu=0, tau=0.001, value=0)
    
    # Non-english primary language effect
    beta_lang = Normal("beta_lang", mu=0, tau=0.001, value=0)
    
    # Premature effect
    beta_prem = Normal("beta_prem", mu=0, tau=0.001, value=0)
    
    # Age at amplification effect
    beta_age_ci = Normal("beta_age_ci", mu=0, tau=0.001, value=0)
    
    # Degree of hearing loss effect
    beta_hearing_loss = Normal("beta_hearing_loss", mu=0, tau=0.001, value=0)
    
    # Bimodal effect (relative to bilateral)
    beta_bimodal = Normal("beta_bimodal", mu=0, tau=0.001, value=0)

    betas = [beta_age, beta_lang, beta_prem, beta_age_ci, beta_hearing_loss, beta_bimodal]

    @deterministic
    def theta(b0=intercept, b=betas, x_non_english=non_english, x_prem=prem, x_age_ci=age_ci, x_hl=hl):
        
        t = b0 + b[0]*age_std + b[1]*x_non_english + b[2]*x_prem + b[3]*x_age_ci + b[4]*x_hl + b[5]*bimodal
        
        return t
    
    sigma = Uniform("sigma", 0, 1000, value=10)
    tau = sigma**-2
    
    # Data likelihood
    score_like = Normal("score_like", mu=theta, tau=tau, value=score, observed=True)
    score_like_pred = Normal("score_like_pred", mu=theta, tau=tau, value=score)
    
    return MCMC(locals())

# %%
Mlang = generate_model(lsl_dr[lsl_dr.domain=='Language'])

# %%
Mlang.sample(100000, 90000)
# Out:
#  [                  0%                  ] 2 of 100000 complete in 1.8 sec
#  [                  0%                  ] 65 of 100000 complete in 2.3 sec
#  [                  0%                  ] 127 of 100000 complete in 2.8 sec
#  [                  0%                  ] 193 of 100000 complete in 3.3 sec
#  [                  0%                  ] 258 of 100000 complete in 3.8 sec
#  [                  0%                  ] 321 of 100000 complete in 4.3 sec
#  [                  0%                  ] 376 of 100000 complete in 4.8 sec
#  [                  0%                  ] 440 of 100000 complete in 5.3 sec
#  [                  0%                  ] 497 of 100000 complete in 5.8 sec
#  [                  0%                  ] 556 of 100000 complete in 6.3 sec
#  [                  0%                  ] 611 of 100000 complete in 6.8 sec
#  [                  0%                  ] 672 of 100000 complete in 7.3 sec
#  [                  0%                  ] 729 of 100000 complete in 7.8 sec
#  [                  0%                  ] 794 of 100000 complete in 8.4 sec
#  [                  0%                  ] 853 of 100000 complete in 8.9 sec
#  [                  0%                  ] 903 of 100000 complete in 9.4 sec
#  [                  0%                  ] 962 of 100000 complete in 9.9 sec
#  [                  1%                  ] 1022 of 100000 complete in 10.4 sec
#  [                  1%                  ] 1085 of 100000 complete in 10.9 sec
#  [                  1%                  ] 1148 of 100000 complete in 11.4 sec
#  [                  1%                  ] 1212 of 100000 complete in 11.9 sec
#  [                  1%                  ] 1270 of 100000 complete in 12.4 sec
#  [                  1%                  ] 1326 of 100000 complete in 12.9 sec
#  [                  1%                  ] 1383 of 100000 complete in 13.4 sec
#  [                  1%                  ] 1431 of 100000 complete in 13.9 sec
#  [                  1%                  ] 1493 of 100000 complete in 14.4 sec
#  [                  1%                  ] 1555 of 100000 complete in 14.9 sec
#  [                  1%                  ] 1614 of 100000 complete in 15.4 sec
#  [                  1%                  ] 1675 of 100000 complete in 15.9 sec
#  [                  1%                  ] 1743 of 100000 complete in 16.4 sec
#  [                  1%                  ] 1810 of 100000 complete in 16.9 sec
#  [                  1%                  ] 1876 of 100000 complete in 17.4 sec
#  [                  1%                  ] 1935 of 100000 complete in 18.0 sec
#  [                  2%                  ] 2003 of 100000 complete in 18.5 sec
#  [                  2%                  ] 2062 of 100000 complete in 19.0 sec
#  [                  2%                  ] 2127 of 100000 complete in 19.5 sec
#  [                  2%                  ] 2192 of 100000 complete in 20.0 sec
#  [                  2%                  ] 2257 of 100000 complete in 20.5 sec
#  [                  2%                  ] 2324 of 100000 complete in 21.0 sec
#  [                  2%                  ] 2393 of 100000 complete in 21.5 sec
#  [                  2%                  ] 2460 of 100000 complete in 22.0 sec
#  [                  2%                  ] 2527 of 100000 complete in 22.5 sec
#  [                  2%                  ] 2593 of 100000 complete in 23.0 sec
#  [-                 2%                  ] 2661 of 100000 complete in 23.5 sec
#  [-                 2%                  ] 2728 of 100000 complete in 24.0 sec
#  [-                 2%                  ] 2793 of 100000 complete in 24.5 sec
#  [-                 2%                  ] 2859 of 100000 complete in 25.0 sec
#  [-                 2%                  ] 2927 of 100000 complete in 25.5 sec
#  [-                 2%                  ] 2994 of 100000 complete in 26.0 sec
#  [-                 3%                  ] 3059 of 100000 complete in 26.5 sec
#  [-                 3%                  ] 3125 of 100000 complete in 27.0 sec
#  [-                 3%                  ] 3192 of 100000 complete in 27.5 sec
#  [-                 3%                  ] 3258 of 100000 complete in 28.0 sec
#  [-                 3%                  ] 3319 of 100000 complete in 28.5 sec
#  [-                 3%                  ] 3383 of 100000 complete in 29.0 sec
#  [-                 3%                  ] 3449 of 100000 complete in 29.6 sec
#  [-                 3%                  ] 3515 of 100000 complete in 30.1 sec
#  [-                 3%                  ] 3579 of 100000 complete in 30.6 sec
#  [-                 3%                  ] 3644 of 100000 complete in 31.1 sec
#  [-                 3%                  ] 3710 of 100000 complete in 31.6 sec
#  [-                 3%                  ] 3775 of 100000 complete in 32.1 sec
#  [-                 3%                  ] 3840 of 100000 complete in 32.6 sec
#  [-                 3%                  ] 3901 of 100000 complete in 33.1 sec
#  [-                 3%                  ] 3966 of 100000 complete in 33.6 sec
#  [-                 4%                  ] 4029 of 100000 complete in 34.1 sec
#  [-                 4%                  ] 4093 of 100000 complete in 34.6 sec
#  [-                 4%                  ] 4159 of 100000 complete in 35.1 sec
#  [-                 4%                  ] 4224 of 100000 complete in 35.6 sec
#  [-                 4%                  ] 4290 of 100000 complete in 36.1 sec
#  [-                 4%                  ] 4352 of 100000 complete in 36.6 sec
#  [-                 4%                  ] 4417 of 100000 complete in 37.1 sec
#  [-                 4%                  ] 4484 of 100000 complete in 37.6 sec
#  [-                 4%                  ] 4544 of 100000 complete in 38.1 sec
#  [-                 4%                  ] 4605 of 100000 complete in 38.6 sec
#  [-                 4%                  ] 4648 of 100000 complete in 39.1 sec
#  [-                 4%                  ] 4708 of 100000 complete in 39.6 sec
#  [-                 4%                  ] 4772 of 100000 complete in 40.1 sec
#  [-                 4%                  ] 4828 of 100000 complete in 40.7 sec
#  [-                 4%                  ] 4890 of 100000 complete in 41.2 sec
#  [-                 4%                  ] 4955 of 100000 complete in 41.7 sec
#  [-                 5%                  ] 5020 of 100000 complete in 42.2 sec
#  [-                 5%                  ] 5085 of 100000 complete in 42.7 sec
#  [-                 5%                  ] 5149 of 100000 complete in 43.2 sec
#  [-                 5%                  ] 5214 of 100000 complete in 43.7 sec
#  [--                5%                  ] 5276 of 100000 complete in 44.2 sec
#  [--                5%                  ] 5337 of 100000 complete in 44.7 sec
#  [--                5%                  ] 5403 of 100000 complete in 45.2 sec
#  [--                5%                  ] 5468 of 100000 complete in 45.7 sec
#  [--                5%                  ] 5534 of 100000 complete in 46.2 sec
#  [--                5%                  ] 5596 of 100000 complete in 46.7 sec
#  [--                5%                  ] 5660 of 100000 complete in 47.2 sec
#  [--                5%                  ] 5725 of 100000 complete in 47.7 sec
#  [--                5%                  ] 5791 of 100000 complete in 48.2 sec
#  [--                5%                  ] 5854 of 100000 complete in 48.7 sec
#  [--                5%                  ] 5918 of 100000 complete in 49.2 sec
#  [--                5%                  ] 5981 of 100000 complete in 49.7 sec
#  [--                6%                  ] 6046 of 100000 complete in 50.2 sec
#  [--                6%                  ] 6108 of 100000 complete in 50.7 sec
#  [--                6%                  ] 6174 of 100000 complete in 51.2 sec
#  [--                6%                  ] 6234 of 100000 complete in 51.8 sec
#  [--                6%                  ] 6300 of 100000 complete in 52.3 sec
#  [--                6%                  ] 6363 of 100000 complete in 52.8 sec
#  [--                6%                  ] 6427 of 100000 complete in 53.3 sec
#  [--                6%                  ] 6491 of 100000 complete in 53.8 sec
#  [--                6%                  ] 6554 of 100000 complete in 54.3 sec
#  [--                6%                  ] 6616 of 100000 complete in 54.8 sec
#  [--                6%                  ] 6676 of 100000 complete in 55.3 sec
#  [--                6%                  ] 6735 of 100000 complete in 55.8 sec
#  [--                6%                  ] 6799 of 100000 complete in 56.3 sec
#  [--                6%                  ] 6861 of 100000 complete in 56.8 sec
#  [--                6%                  ] 6917 of 100000 complete in 57.3 sec
#  [--                6%                  ] 6980 of 100000 complete in 57.8 sec
#  [--                7%                  ] 7045 of 100000 complete in 58.3 sec
#  [--                7%                  ] 7107 of 100000 complete in 58.8 sec
#  [--                7%                  ] 7172 of 100000 complete in 59.3 sec
#  [--                7%                  ] 7239 of 100000 complete in 59.8 sec
#  [--                7%                  ] 7305 of 100000 complete in 60.3 sec
#  [--                7%                  ] 7365 of 100000 complete in 60.8 sec
#  [--                7%                  ] 7430 of 100000 complete in 61.3 sec
#  [--                7%                  ] 7497 of 100000 complete in 61.8 sec
#  [--                7%                  ] 7564 of 100000 complete in 62.3 sec
#  [--                7%                  ] 7629 of 100000 complete in 62.8 sec
#  [--                7%                  ] 7695 of 100000 complete in 63.3 sec
#  [--                7%                  ] 7761 of 100000 complete in 63.8 sec
#  [--                7%                  ] 7827 of 100000 complete in 64.4 sec
#  [--                7%                  ] 7890 of 100000 complete in 64.9 sec
#  [---               7%                  ] 7957 of 100000 complete in 65.4 sec
#  [---               8%                  ] 8020 of 100000 complete in 65.9 sec
#  [---               8%                  ] 8086 of 100000 complete in 66.4 sec
#  [---               8%                  ] 8150 of 100000 complete in 66.9 sec
#  [---               8%                  ] 8212 of 100000 complete in 67.4 sec
#  [---               8%                  ] 8277 of 100000 complete in 67.9 sec
#  [---               8%                  ] 8340 of 100000 complete in 68.4 sec
#  [---               8%                  ] 8403 of 100000 complete in 68.9 sec
#  [---               8%                  ] 8464 of 100000 complete in 69.4 sec
#  [---               8%                  ] 8511 of 100000 complete in 69.9 sec
#  [---               8%                  ] 8573 of 100000 complete in 70.4 sec
#  [---               8%                  ] 8631 of 100000 complete in 70.9 sec
#  [---               8%                  ] 8688 of 100000 complete in 71.4 sec
#  [---               8%                  ] 8750 of 100000 complete in 71.9 sec
#  [---               8%                  ] 8809 of 100000 complete in 72.4 sec
#  [---               8%                  ] 8874 of 100000 complete in 72.9 sec
#  [---               8%                  ] 8939 of 100000 complete in 73.4 sec
#  [---               9%                  ] 9006 of 100000 complete in 73.9 sec
#  [---               9%                  ] 9071 of 100000 complete in 74.4 sec
#  [---               9%                  ] 9137 of 100000 complete in 74.9 sec
#  [---               9%                  ] 9203 of 100000 complete in 75.4 sec
#  [---               9%                  ] 9261 of 100000 complete in 75.9 sec
#  [---               9%                  ] 9319 of 100000 complete in 76.5 sec
#  [---               9%                  ] 9369 of 100000 complete in 77.0 sec
#  [---               9%                  ] 9431 of 100000 complete in 77.5 sec
#  [---               9%                  ] 9495 of 100000 complete in 78.0 sec
#  [---               9%                  ] 9561 of 100000 complete in 78.5 sec
#  [---               9%                  ] 9617 of 100000 complete in 79.0 sec
#  [---               9%                  ] 9659 of 100000 complete in 79.5 sec
#  [---               9%                  ] 9704 of 100000 complete in 80.0 sec
#  [---               9%                  ] 9734 of 100000 complete in 80.5 sec
#  [---               9%                  ] 9775 of 100000 complete in 81.0 sec
#  [---               9%                  ] 9816 of 100000 complete in 81.5 sec
#  [---               9%                  ] 9851 of 100000 complete in 82.0 sec
#  [---               9%                  ] 9888 of 100000 complete in 82.5 sec
#  [---               9%                  ] 9936 of 100000 complete in 83.0 sec
#  [---               9%                  ] 9978 of 100000 complete in 83.5 sec
#  [---              10%                  ] 10025 of 100000 complete in 84.0 sec
#  [---              10%                  ] 10076 of 100000 complete in 84.5 sec
#  [---              10%                  ] 10126 of 100000 complete in 85.0 sec
#  [---              10%                  ] 10181 of 100000 complete in 85.5 sec
#  [---              10%                  ] 10236 of 100000 complete in 86.1 sec
#  [---              10%                  ] 10276 of 100000 complete in 86.6 sec
#  [---              10%                  ] 10326 of 100000 complete in 87.1 sec
#  [---              10%                  ] 10366 of 100000 complete in 87.6 sec
#  [---              10%                  ] 10416 of 100000 complete in 88.1 sec
#  [---              10%                  ] 10472 of 100000 complete in 88.6 sec
#  [---              10%                  ] 10525 of 100000 complete in 89.1 sec
#  [----             10%                  ] 10579 of 100000 complete in 89.6 sec
#  [----             10%                  ] 10632 of 100000 complete in 90.1 sec
#  [----             10%                  ] 10676 of 100000 complete in 90.6 sec
#  [----             10%                  ] 10719 of 100000 complete in 91.1 sec
#  [----             10%                  ] 10769 of 100000 complete in 91.6 sec
#  [----             10%                  ] 10819 of 100000 complete in 92.1 sec
#  [----             10%                  ] 10873 of 100000 complete in 92.6 sec
#  [----             10%                  ] 10919 of 100000 complete in 93.1 sec
#  [----             10%                  ] 10964 of 100000 complete in 93.6 sec
#  [----             11%                  ] 11008 of 100000 complete in 94.1 sec
#  [----             11%                  ] 11053 of 100000 complete in 94.6 sec
#  [----             11%                  ] 11101 of 100000 complete in 95.1 sec
#  [----             11%                  ] 11153 of 100000 complete in 95.6 sec
#  [----             11%                  ] 11206 of 100000 complete in 96.2 sec
#  [----             11%                  ] 11258 of 100000 complete in 96.7 sec
#  [----             11%                  ] 11312 of 100000 complete in 97.2 sec
#  [----             11%                  ] 11359 of 100000 complete in 97.7 sec
#  [----             11%                  ] 11412 of 100000 complete in 98.2 sec
#  [----             11%                  ] 11470 of 100000 complete in 98.7 sec
#  [----             11%                  ] 11530 of 100000 complete in 99.2 sec
#  [----             11%                  ] 11589 of 100000 complete in 99.7 sec
#  [----             11%                  ] 11647 of 100000 complete in 100.2 sec
#  [----             11%                  ] 11708 of 100000 complete in 100.7 sec
#  [----             11%                  ] 11773 of 100000 complete in 101.2 sec
#  [----             11%                  ] 11838 of 100000 complete in 101.7 sec
#  [----             11%                  ] 11903 of 100000 complete in 102.2 sec
#  [----             11%                  ] 11961 of 100000 complete in 102.7 sec
#  [----             12%                  ] 12021 of 100000 complete in 103.2 sec
#  [----             12%                  ] 12070 of 100000 complete in 103.7 sec
#  [----             12%                  ] 12121 of 100000 complete in 104.2 sec
#  [----             12%                  ] 12175 of 100000 complete in 104.7 sec
#  [----             12%                  ] 12225 of 100000 complete in 105.2 sec
#  [----             12%                  ] 12278 of 100000 complete in 105.7 sec
#  [----             12%                  ] 12334 of 100000 complete in 106.3 sec
#  [----             12%                  ] 12382 of 100000 complete in 106.8 sec
#  [----             12%                  ] 12439 of 100000 complete in 107.3 sec
#  [----             12%                  ] 12497 of 100000 complete in 107.8 sec
#  [----             12%                  ] 12561 of 100000 complete in 108.3 sec
#  [----             12%                  ] 12617 of 100000 complete in 108.8 sec
#  [----             12%                  ] 12677 of 100000 complete in 109.3 sec
#  [----             12%                  ] 12736 of 100000 complete in 109.8 sec
#  [----             12%                  ] 12796 of 100000 complete in 110.3 sec
#  [----             12%                  ] 12857 of 100000 complete in 110.8 sec
#  [----             12%                  ] 12917 of 100000 complete in 111.3 sec
#  [----             12%                  ] 12981 of 100000 complete in 111.8 sec
#  [----             13%                  ] 13046 of 100000 complete in 112.3 sec
#  [----             13%                  ] 13107 of 100000 complete in 112.8 sec
#  [-----            13%                  ] 13170 of 100000 complete in 113.3 sec
#  [-----            13%                  ] 13236 of 100000 complete in 113.8 sec
#  [-----            13%                  ] 13296 of 100000 complete in 114.3 sec
#  [-----            13%                  ] 13360 of 100000 complete in 114.8 sec
#  [-----            13%                  ] 13421 of 100000 complete in 115.3 sec
#  [-----            13%                  ] 13475 of 100000 complete in 115.8 sec
#  [-----            13%                  ] 13524 of 100000 complete in 116.3 sec
#  [-----            13%                  ] 13572 of 100000 complete in 116.9 sec
#  [-----            13%                  ] 13623 of 100000 complete in 117.4 sec
#  [-----            13%                  ] 13682 of 100000 complete in 117.9 sec
#  [-----            13%                  ] 13747 of 100000 complete in 118.4 sec
#  [-----            13%                  ] 13808 of 100000 complete in 118.9 sec
#  [-----            13%                  ] 13865 of 100000 complete in 119.4 sec
#  [-----            13%                  ] 13915 of 100000 complete in 119.9 sec
#  [-----            13%                  ] 13976 of 100000 complete in 120.4 sec
#  [-----            14%                  ] 14037 of 100000 complete in 120.9 sec
#  [-----            14%                  ] 14101 of 100000 complete in 121.4 sec
#  [-----            14%                  ] 14161 of 100000 complete in 121.9 sec
#  [-----            14%                  ] 14208 of 100000 complete in 122.4 sec
#  [-----            14%                  ] 14257 of 100000 complete in 122.9 sec
#  [-----            14%                  ] 14306 of 100000 complete in 123.4 sec
#  [-----            14%                  ] 14366 of 100000 complete in 123.9 sec
#  [-----            14%                  ] 14430 of 100000 complete in 124.4 sec
#  [-----            14%                  ] 14486 of 100000 complete in 124.9 sec
#  [-----            14%                  ] 14546 of 100000 complete in 125.4 sec
#  [-----            14%                  ] 14613 of 100000 complete in 125.9 sec
#  [-----            14%                  ] 14678 of 100000 complete in 126.4 sec
#  [-----            14%                  ] 14742 of 100000 complete in 127.0 sec
#  [-----            14%                  ] 14808 of 100000 complete in 127.5 sec
#  [-----            14%                  ] 14868 of 100000 complete in 128.0 sec
#  [-----            14%                  ] 14925 of 100000 complete in 128.5 sec
#  [-----            14%                  ] 14987 of 100000 complete in 129.0 sec
#  [-----            15%                  ] 15050 of 100000 complete in 129.5 sec
#  [-----            15%                  ] 15115 of 100000 complete in 130.0 sec
#  [-----            15%                  ] 15176 of 100000 complete in 130.5 sec
#  [-----            15%                  ] 15241 of 100000 complete in 131.0 sec
#  [-----            15%                  ] 15307 of 100000 complete in 131.5 sec
#  [-----            15%                  ] 15372 of 100000 complete in 132.0 sec
#  [-----            15%                  ] 15429 of 100000 complete in 132.5 sec
#  [-----            15%                  ] 15493 of 100000 complete in 133.0 sec
#  [-----            15%                  ] 15560 of 100000 complete in 133.5 sec
#  [-----            15%                  ] 15626 of 100000 complete in 134.0 sec
#  [-----            15%                  ] 15691 of 100000 complete in 134.5 sec
#  [-----            15%                  ] 15751 of 100000 complete in 135.0 sec
#  [------           15%                  ] 15815 of 100000 complete in 135.5 sec
#  [------           15%                  ] 15876 of 100000 complete in 136.0 sec
#  [------           15%                  ] 15942 of 100000 complete in 136.5 sec
#  [------           16%                  ] 16007 of 100000 complete in 137.0 sec
#  [------           16%                  ] 16072 of 100000 complete in 137.5 sec
#  [------           16%                  ] 16138 of 100000 complete in 138.0 sec
#  [------           16%                  ] 16203 of 100000 complete in 138.5 sec
#  [------           16%                  ] 16268 of 100000 complete in 139.0 sec
#  [------           16%                  ] 16333 of 100000 complete in 139.5 sec
#  [------           16%                  ] 16399 of 100000 complete in 140.0 sec
#  [------           16%                  ] 16464 of 100000 complete in 140.6 sec
#  [------           16%                  ] 16525 of 100000 complete in 141.1 sec
#  [------           16%                  ] 16590 of 100000 complete in 141.6 sec
#  [------           16%                  ] 16655 of 100000 complete in 142.1 sec
#  [------           16%                  ] 16712 of 100000 complete in 142.6 sec
#  [------           16%                  ] 16758 of 100000 complete in 143.1 sec
#  [------           16%                  ] 16809 of 100000 complete in 143.6 sec
#  [------           16%                  ] 16865 of 100000 complete in 144.1 sec
#  [------           16%                  ] 16920 of 100000 complete in 144.6 sec
#  [------           16%                  ] 16985 of 100000 complete in 145.1 sec
#  [------           17%                  ] 17042 of 100000 complete in 145.6 sec
#  [------           17%                  ] 17094 of 100000 complete in 146.1 sec
#  [------           17%                  ] 17143 of 100000 complete in 146.6 sec
#  [------           17%                  ] 17204 of 100000 complete in 147.1 sec
#  [------           17%                  ] 17268 of 100000 complete in 147.6 sec
#  [------           17%                  ] 17324 of 100000 complete in 148.1 sec
#  [------           17%                  ] 17378 of 100000 complete in 148.6 sec
#  [------           17%                  ] 17439 of 100000 complete in 149.1 sec
#  [------           17%                  ] 17498 of 100000 complete in 149.6 sec
#  [------           17%                  ] 17547 of 100000 complete in 150.1 sec
#  [------           17%                  ] 17595 of 100000 complete in 150.6 sec
#  [------           17%                  ] 17649 of 100000 complete in 151.1 sec
#  [------           17%                  ] 17711 of 100000 complete in 151.7 sec
#  [------           17%                  ] 17759 of 100000 complete in 152.2 sec
#  [------           17%                  ] 17810 of 100000 complete in 152.7 sec
#  [------           17%                  ] 17865 of 100000 complete in 153.2 sec
#  [------           17%                  ] 17926 of 100000 complete in 153.7 sec
#  [------           17%                  ] 17989 of 100000 complete in 154.2 sec
#  [------           18%                  ] 18033 of 100000 complete in 154.7 sec
#  [------           18%                  ] 18081 of 100000 complete in 155.2 sec
#  [------           18%                  ] 18133 of 100000 complete in 155.7 sec
#  [------           18%                  ] 18180 of 100000 complete in 156.2 sec
#  [------           18%                  ] 18229 of 100000 complete in 156.7 sec
#  [------           18%                  ] 18272 of 100000 complete in 157.2 sec
#  [------           18%                  ] 18322 of 100000 complete in 157.7 sec
#  [------           18%                  ] 18376 of 100000 complete in 158.2 sec
#  [-------          18%                  ] 18423 of 100000 complete in 158.7 sec
#  [-------          18%                  ] 18473 of 100000 complete in 159.2 sec
#  [-------          18%                  ] 18521 of 100000 complete in 159.7 sec
#  [-------          18%                  ] 18577 of 100000 complete in 160.2 sec
#  [-------          18%                  ] 18621 of 100000 complete in 160.8 sec
#  [-------          18%                  ] 18665 of 100000 complete in 161.3 sec
#  [-------          18%                  ] 18710 of 100000 complete in 161.8 sec
#  [-------          18%                  ] 18755 of 100000 complete in 162.3 sec
#  [-------          18%                  ] 18799 of 100000 complete in 162.8 sec
#  [-------          18%                  ] 18843 of 100000 complete in 163.3 sec
#  [-------          18%                  ] 18905 of 100000 complete in 163.8 sec
#  [-------          18%                  ] 18955 of 100000 complete in 164.3 sec
#  [-------          18%                  ] 18999 of 100000 complete in 164.8 sec
#  [-------          19%                  ] 19043 of 100000 complete in 165.3 sec
#  [-------          19%                  ] 19096 of 100000 complete in 165.8 sec
#  [-------          19%                  ] 19142 of 100000 complete in 166.3 sec
#  [-------          19%                  ] 19202 of 100000 complete in 166.8 sec
#  [-------          19%                  ] 19268 of 100000 complete in 167.3 sec
#  [-------          19%                  ] 19328 of 100000 complete in 167.8 sec
#  [-------          19%                  ] 19390 of 100000 complete in 168.3 sec
#  [-------          19%                  ] 19453 of 100000 complete in 168.8 sec
#  [-------          19%                  ] 19512 of 100000 complete in 169.3 sec
#  [-------          19%                  ] 19573 of 100000 complete in 169.8 sec
#  [-------          19%                  ] 19640 of 100000 complete in 170.3 sec
#  [-------          19%                  ] 19702 of 100000 complete in 170.9 sec
#  [-------          19%                  ] 19757 of 100000 complete in 171.4 sec
#  [-------          19%                  ] 19806 of 100000 complete in 171.9 sec
#  [-------          19%                  ] 19854 of 100000 complete in 172.4 sec
#  [-------          19%                  ] 19899 of 100000 complete in 172.9 sec
#  [-------          19%                  ] 19939 of 100000 complete in 173.4 sec
#  [-------          19%                  ] 19989 of 100000 complete in 173.9 sec
#  [-------          20%                  ] 20035 of 100000 complete in 174.4 sec
#  [-------          20%                  ] 20099 of 100000 complete in 174.9 sec
#  [-------          20%                  ] 20160 of 100000 complete in 175.4 sec
#  [-------          20%                  ] 20226 of 100000 complete in 175.9 sec
#  [-------          20%                  ] 20294 of 100000 complete in 176.4 sec
#  [-------          20%                  ] 20360 of 100000 complete in 176.9 sec
#  [-------          20%                  ] 20427 of 100000 complete in 177.4 sec
#  [-------          20%                  ] 20493 of 100000 complete in 177.9 sec
#  [-------          20%                  ] 20559 of 100000 complete in 178.4 sec
#  [-------          20%                  ] 20618 of 100000 complete in 178.9 sec
#  [-------          20%                  ] 20678 of 100000 complete in 179.4 sec
#  [-------          20%                  ] 20734 of 100000 complete in 179.9 sec
#  [-------          20%                  ] 20794 of 100000 complete in 180.4 sec
#  [-------          20%                  ] 20849 of 100000 complete in 181.0 sec
#  [-------          20%                  ] 20908 of 100000 complete in 181.5 sec
#  [-------          20%                  ] 20962 of 100000 complete in 182.0 sec
#  [-------          21%                  ] 21027 of 100000 complete in 182.5 sec
#  [--------         21%                  ] 21093 of 100000 complete in 183.0 sec
#  [--------         21%                  ] 21161 of 100000 complete in 183.5 sec
#  [--------         21%                  ] 21218 of 100000 complete in 184.0 sec
#  [--------         21%                  ] 21284 of 100000 complete in 184.5 sec
#  [--------         21%                  ] 21351 of 100000 complete in 185.0 sec
#  [--------         21%                  ] 21417 of 100000 complete in 185.5 sec
#  [--------         21%                  ] 21483 of 100000 complete in 186.0 sec
#  [--------         21%                  ] 21548 of 100000 complete in 186.5 sec
#  [--------         21%                  ] 21611 of 100000 complete in 187.0 sec
#  [--------         21%                  ] 21668 of 100000 complete in 187.5 sec
#  [--------         21%                  ] 21731 of 100000 complete in 188.0 sec
#  [--------         21%                  ] 21794 of 100000 complete in 188.5 sec
#  [--------         21%                  ] 21860 of 100000 complete in 189.0 sec
#  [--------         21%                  ] 21908 of 100000 complete in 189.5 sec
#  [--------         21%                  ] 21972 of 100000 complete in 190.0 sec
#  [--------         22%                  ] 22037 of 100000 complete in 190.5 sec
#  [--------         22%                  ] 22104 of 100000 complete in 191.0 sec
#  [--------         22%                  ] 22171 of 100000 complete in 191.5 sec
#  [--------         22%                  ] 22235 of 100000 complete in 192.0 sec
#  [--------         22%                  ] 22297 of 100000 complete in 192.5 sec
#  [--------         22%                  ] 22349 of 100000 complete in 193.0 sec
#  [--------         22%                  ] 22413 of 100000 complete in 193.6 sec
#  [--------         22%                  ] 22479 of 100000 complete in 194.1 sec
#  [--------         22%                  ] 22537 of 100000 complete in 194.6 sec
#  [--------         22%                  ] 22600 of 100000 complete in 195.1 sec
#  [--------         22%                  ] 22667 of 100000 complete in 195.6 sec
#  [--------         22%                  ] 22733 of 100000 complete in 196.1 sec
#  [--------         22%                  ] 22799 of 100000 complete in 196.6 sec
#  [--------         22%                  ] 22863 of 100000 complete in 197.1 sec
#  [--------         22%                  ] 22929 of 100000 complete in 197.6 sec
#  [--------         22%                  ] 22987 of 100000 complete in 198.1 sec
#  [--------         23%                  ] 23038 of 100000 complete in 198.6 sec
#  [--------         23%                  ] 23103 of 100000 complete in 199.1 sec
#  [--------         23%                  ] 23167 of 100000 complete in 199.6 sec
#  [--------         23%                  ] 23233 of 100000 complete in 200.1 sec
#  [--------         23%                  ] 23296 of 100000 complete in 200.6 sec
#  [--------         23%                  ] 23364 of 100000 complete in 201.1 sec
#  [--------         23%                  ] 23431 of 100000 complete in 201.6 sec
#  [--------         23%                  ] 23496 of 100000 complete in 202.1 sec
#  [--------         23%                  ] 23558 of 100000 complete in 202.6 sec
#  [--------         23%                  ] 23624 of 100000 complete in 203.1 sec
#  [---------        23%                  ] 23690 of 100000 complete in 203.6 sec
#  [---------        23%                  ] 23753 of 100000 complete in 204.1 sec
#  [---------        23%                  ] 23812 of 100000 complete in 204.6 sec
#  [---------        23%                  ] 23879 of 100000 complete in 205.1 sec
#  [---------        23%                  ] 23940 of 100000 complete in 205.6 sec
#  [---------        24%                  ] 24002 of 100000 complete in 206.1 sec
#  [---------        24%                  ] 24062 of 100000 complete in 206.7 sec
#  [---------        24%                  ] 24125 of 100000 complete in 207.2 sec
#  [---------        24%                  ] 24179 of 100000 complete in 207.7 sec
#  [---------        24%                  ] 24234 of 100000 complete in 208.2 sec
#  [---------        24%                  ] 24296 of 100000 complete in 208.7 sec
#  [---------        24%                  ] 24353 of 100000 complete in 209.2 sec
#  [---------        24%                  ] 24419 of 100000 complete in 209.7 sec
#  [---------        24%                  ] 24479 of 100000 complete in 210.2 sec
#  [---------        24%                  ] 24539 of 100000 complete in 210.7 sec
#  [---------        24%                  ] 24601 of 100000 complete in 211.2 sec
#  [---------        24%                  ] 24667 of 100000 complete in 211.7 sec
#  [---------        24%                  ] 24730 of 100000 complete in 212.2 sec
#  [---------        24%                  ] 24789 of 100000 complete in 212.7 sec
#  [---------        24%                  ] 24846 of 100000 complete in 213.2 sec
#  [---------        24%                  ] 24902 of 100000 complete in 213.7 sec
#  [---------        24%                  ] 24961 of 100000 complete in 214.2 sec
#  [---------        25%                  ] 25017 of 100000 complete in 214.7 sec
#  [---------        25%                  ] 25074 of 100000 complete in 215.2 sec
#  [---------        25%                  ] 25132 of 100000 complete in 215.7 sec
#  [---------        25%                  ] 25193 of 100000 complete in 216.2 sec
#  [---------        25%                  ] 25243 of 100000 complete in 216.7 sec
#  [---------        25%                  ] 25311 of 100000 complete in 217.2 sec
#  [---------        25%                  ] 25376 of 100000 complete in 217.7 sec
#  [---------        25%                  ] 25441 of 100000 complete in 218.2 sec
#  [---------        25%                  ] 25506 of 100000 complete in 218.7 sec
#  [---------        25%                  ] 25574 of 100000 complete in 219.2 sec
#  [---------        25%                  ] 25641 of 100000 complete in 219.7 sec
#  [---------        25%                  ] 25709 of 100000 complete in 220.3 sec
#  [---------        25%                  ] 25764 of 100000 complete in 220.8 sec
#  [---------        25%                  ] 25826 of 100000 complete in 221.3 sec
#  [---------        25%                  ] 25887 of 100000 complete in 221.8 sec
#  [---------        25%                  ] 25953 of 100000 complete in 222.3 sec
#  [---------        26%                  ] 26019 of 100000 complete in 222.8 sec
#  [---------        26%                  ] 26087 of 100000 complete in 223.3 sec
#  [---------        26%                  ] 26155 of 100000 complete in 223.8 sec
#  [---------        26%                  ] 26222 of 100000 complete in 224.3 sec
#  [---------        26%                  ] 26289 of 100000 complete in 224.8 sec
#  [----------       26%                  ] 26354 of 100000 complete in 225.3 sec
#  [----------       26%                  ] 26422 of 100000 complete in 225.8 sec
#  [----------       26%                  ] 26489 of 100000 complete in 226.3 sec
#  [----------       26%                  ] 26555 of 100000 complete in 226.8 sec
#  [----------       26%                  ] 26621 of 100000 complete in 227.3 sec
#  [----------       26%                  ] 26689 of 100000 complete in 227.8 sec
#  [----------       26%                  ] 26750 of 100000 complete in 228.3 sec
#  [----------       26%                  ] 26814 of 100000 complete in 228.8 sec
#  [----------       26%                  ] 26881 of 100000 complete in 229.3 sec
#  [----------       26%                  ] 26949 of 100000 complete in 229.8 sec
#  [----------       27%                  ] 27015 of 100000 complete in 230.3 sec
#  [----------       27%                  ] 27081 of 100000 complete in 230.8 sec
#  [----------       27%                  ] 27148 of 100000 complete in 231.3 sec
#  [----------       27%                  ] 27214 of 100000 complete in 231.8 sec
#  [----------       27%                  ] 27275 of 100000 complete in 232.3 sec
#  [----------       27%                  ] 27336 of 100000 complete in 232.9 sec
#  [----------       27%                  ] 27402 of 100000 complete in 233.4 sec
#  [----------       27%                  ] 27469 of 100000 complete in 233.9 sec
#  [----------       27%                  ] 27529 of 100000 complete in 234.4 sec
#  [----------       27%                  ] 27593 of 100000 complete in 234.9 sec
#  [----------       27%                  ] 27651 of 100000 complete in 235.4 sec
#  [----------       27%                  ] 27713 of 100000 complete in 235.9 sec
#  [----------       27%                  ] 27771 of 100000 complete in 236.4 sec
#  [----------       27%                  ] 27825 of 100000 complete in 236.9 sec
#  [----------       27%                  ] 27888 of 100000 complete in 237.4 sec
#  [----------       27%                  ] 27939 of 100000 complete in 237.9 sec
#  [----------       27%                  ] 27997 of 100000 complete in 238.4 sec
#  [----------       28%                  ] 28061 of 100000 complete in 238.9 sec
#  [----------       28%                  ] 28121 of 100000 complete in 239.4 sec
#  [----------       28%                  ] 28174 of 100000 complete in 239.9 sec
#  [----------       28%                  ] 28227 of 100000 complete in 240.4 sec
#  [----------       28%                  ] 28284 of 100000 complete in 240.9 sec
#  [----------       28%                  ] 28349 of 100000 complete in 241.4 sec
#  [----------       28%                  ] 28405 of 100000 complete in 241.9 sec
#  [----------       28%                  ] 28467 of 100000 complete in 242.4 sec
#  [----------       28%                  ] 28526 of 100000 complete in 242.9 sec
#  [----------       28%                  ] 28584 of 100000 complete in 243.4 sec
#  [----------       28%                  ] 28641 of 100000 complete in 243.9 sec
#  [----------       28%                  ] 28696 of 100000 complete in 244.5 sec
#  [----------       28%                  ] 28754 of 100000 complete in 245.0 sec
#  [----------       28%                  ] 28814 of 100000 complete in 245.5 sec
#  [----------       28%                  ] 28878 of 100000 complete in 246.0 sec
#  [----------       28%                  ] 28935 of 100000 complete in 246.5 sec
#  [-----------      28%                  ] 28991 of 100000 complete in 247.0 sec
#  [-----------      29%                  ] 29052 of 100000 complete in 247.5 sec
#  [-----------      29%                  ] 29119 of 100000 complete in 248.0 sec
#  [-----------      29%                  ] 29177 of 100000 complete in 248.5 sec
#  [-----------      29%                  ] 29233 of 100000 complete in 249.0 sec
#  [-----------      29%                  ] 29284 of 100000 complete in 249.5 sec
#  [-----------      29%                  ] 29338 of 100000 complete in 250.0 sec
#  [-----------      29%                  ] 29394 of 100000 complete in 250.5 sec
#  [-----------      29%                  ] 29453 of 100000 complete in 251.0 sec
#  [-----------      29%                  ] 29512 of 100000 complete in 251.5 sec
#  [-----------      29%                  ] 29567 of 100000 complete in 252.0 sec
#  [-----------      29%                  ] 29624 of 100000 complete in 252.5 sec
#  [-----------      29%                  ] 29679 of 100000 complete in 253.0 sec
#  [-----------      29%                  ] 29732 of 100000 complete in 253.5 sec
#  [-----------      29%                  ] 29791 of 100000 complete in 254.0 sec
#  [-----------      29%                  ] 29847 of 100000 complete in 254.5 sec
#  [-----------      29%                  ] 29902 of 100000 complete in 255.0 sec
#  [-----------      29%                  ] 29962 of 100000 complete in 255.5 sec
#  [-----------      30%                  ] 30021 of 100000 complete in 256.0 sec
#  [-----------      30%                  ] 30077 of 100000 complete in 256.6 sec
#  [-----------      30%                  ] 30144 of 100000 complete in 257.1 sec
#  [-----------      30%                  ] 30209 of 100000 complete in 257.6 sec
#  [-----------      30%                  ] 30274 of 100000 complete in 258.1 sec
#  [-----------      30%                  ] 30333 of 100000 complete in 258.6 sec
#  [-----------      30%                  ] 30392 of 100000 complete in 259.1 sec
#  [-----------      30%                  ] 30452 of 100000 complete in 259.6 sec
#  [-----------      30%                  ] 30508 of 100000 complete in 260.1 sec
#  [-----------      30%                  ] 30572 of 100000 complete in 260.6 sec
#  [-----------      30%                  ] 30635 of 100000 complete in 261.1 sec
#  [-----------      30%                  ] 30699 of 100000 complete in 261.6 sec
#  [-----------      30%                  ] 30766 of 100000 complete in 262.1 sec
#  [-----------      30%                  ] 30831 of 100000 complete in 262.6 sec
#  [-----------      30%                  ] 30895 of 100000 complete in 263.1 sec
#  [-----------      30%                  ] 30959 of 100000 complete in 263.6 sec
#  [-----------      31%                  ] 31016 of 100000 complete in 264.1 sec
#  [-----------      31%                  ] 31083 of 100000 complete in 264.6 sec
#  [-----------      31%                  ] 31149 of 100000 complete in 265.1 sec
#  [-----------      31%                  ] 31211 of 100000 complete in 265.6 sec
#  [-----------      31%                  ] 31278 of 100000 complete in 266.1 sec
#  [-----------      31%                  ] 31341 of 100000 complete in 266.6 sec
#  [-----------      31%                  ] 31408 of 100000 complete in 267.1 sec
#  [-----------      31%                  ] 31475 of 100000 complete in 267.6 sec
#  [-----------      31%                  ] 31534 of 100000 complete in 268.1 sec
#  [------------     31%                  ] 31589 of 100000 complete in 268.6 sec
#  [------------     31%                  ] 31655 of 100000 complete in 269.1 sec
#  [------------     31%                  ] 31722 of 100000 complete in 269.7 sec
#  [------------     31%                  ] 31789 of 100000 complete in 270.2 sec
#  [------------     31%                  ] 31851 of 100000 complete in 270.7 sec
#  [------------     31%                  ] 31918 of 100000 complete in 271.2 sec
#  [------------     31%                  ] 31985 of 100000 complete in 271.7 sec
#  [------------     32%                  ] 32048 of 100000 complete in 272.2 sec
#  [------------     32%                  ] 32105 of 100000 complete in 272.7 sec
#  [------------     32%                  ] 32170 of 100000 complete in 273.2 sec
#  [------------     32%                  ] 32233 of 100000 complete in 273.7 sec
#  [------------     32%                  ] 32299 of 100000 complete in 274.2 sec
#  [------------     32%                  ] 32362 of 100000 complete in 274.7 sec
#  [------------     32%                  ] 32428 of 100000 complete in 275.2 sec
#  [------------     32%                  ] 32492 of 100000 complete in 275.7 sec
#  [------------     32%                  ] 32550 of 100000 complete in 276.2 sec
#  [------------     32%                  ] 32614 of 100000 complete in 276.7 sec
#  [------------     32%                  ] 32675 of 100000 complete in 277.2 sec
#  [------------     32%                  ] 32742 of 100000 complete in 277.7 sec
#  [------------     32%                  ] 32808 of 100000 complete in 278.2 sec
#  [------------     32%                  ] 32874 of 100000 complete in 278.7 sec
#  [------------     32%                  ] 32941 of 100000 complete in 279.2 sec
#  [------------     33%                  ] 33008 of 100000 complete in 279.7 sec
#  [------------     33%                  ] 33075 of 100000 complete in 280.2 sec
#  [------------     33%                  ] 33141 of 100000 complete in 280.7 sec
#  [------------     33%                  ] 33207 of 100000 complete in 281.3 sec
#  [------------     33%                  ] 33270 of 100000 complete in 281.8 sec
#  [------------     33%                  ] 33337 of 100000 complete in 282.3 sec
#  [------------     33%                  ] 33403 of 100000 complete in 282.8 sec
#  [------------     33%                  ] 33467 of 100000 complete in 283.3 sec
#  [------------     33%                  ] 33535 of 100000 complete in 283.8 sec
#  [------------     33%                  ] 33603 of 100000 complete in 284.3 sec
#  [------------     33%                  ] 33668 of 100000 complete in 284.8 sec
#  [------------     33%                  ] 33736 of 100000 complete in 285.3 sec
#  [------------     33%                  ] 33800 of 100000 complete in 285.8 sec
#  [------------     33%                  ] 33868 of 100000 complete in 286.3 sec
#  [------------     33%                  ] 33931 of 100000 complete in 286.8 sec
#  [------------     33%                  ] 33998 of 100000 complete in 287.3 sec
#  [------------     34%                  ] 34065 of 100000 complete in 287.8 sec
#  [------------     34%                  ] 34131 of 100000 complete in 288.3 sec
#  [------------     34%                  ] 34197 of 100000 complete in 288.8 sec
#  [-------------    34%                  ] 34264 of 100000 complete in 289.3 sec
#  [-------------    34%                  ] 34331 of 100000 complete in 289.8 sec
#  [-------------    34%                  ] 34399 of 100000 complete in 290.3 sec
#  [-------------    34%                  ] 34463 of 100000 complete in 290.8 sec
#  [-------------    34%                  ] 34522 of 100000 complete in 291.3 sec
#  [-------------    34%                  ] 34588 of 100000 complete in 291.8 sec
#  [-------------    34%                  ] 34650 of 100000 complete in 292.3 sec
#  [-------------    34%                  ] 34716 of 100000 complete in 292.8 sec
#  [-------------    34%                  ] 34783 of 100000 complete in 293.3 sec
#  [-------------    34%                  ] 34850 of 100000 complete in 293.8 sec
#  [-------------    34%                  ] 34918 of 100000 complete in 294.3 sec
#  [-------------    34%                  ] 34983 of 100000 complete in 294.8 sec
#  [-------------    35%                  ] 35050 of 100000 complete in 295.3 sec
#  [-------------    35%                  ] 35117 of 100000 complete in 295.8 sec
#  [-------------    35%                  ] 35185 of 100000 complete in 296.4 sec
#  [-------------    35%                  ] 35250 of 100000 complete in 296.9 sec
#  [-------------    35%                  ] 35319 of 100000 complete in 297.4 sec
#  [-------------    35%                  ] 35383 of 100000 complete in 297.9 sec
#  [-------------    35%                  ] 35447 of 100000 complete in 298.4 sec
#  [-------------    35%                  ] 35511 of 100000 complete in 298.9 sec
#  [-------------    35%                  ] 35579 of 100000 complete in 299.4 sec
#  [-------------    35%                  ] 35645 of 100000 complete in 299.9 sec
#  [-------------    35%                  ] 35711 of 100000 complete in 300.4 sec
#  [-------------    35%                  ] 35777 of 100000 complete in 300.9 sec
#  [-------------    35%                  ] 35845 of 100000 complete in 301.4 sec
#  [-------------    35%                  ] 35912 of 100000 complete in 301.9 sec
#  [-------------    35%                  ] 35980 of 100000 complete in 302.4 sec
#  [-------------    36%                  ] 36043 of 100000 complete in 302.9 sec
#  [-------------    36%                  ] 36106 of 100000 complete in 303.4 sec
#  [-------------    36%                  ] 36172 of 100000 complete in 303.9 sec
#  [-------------    36%                  ] 36238 of 100000 complete in 304.4 sec
#  [-------------    36%                  ] 36303 of 100000 complete in 304.9 sec
#  [-------------    36%                  ] 36368 of 100000 complete in 305.4 sec
#  [-------------    36%                  ] 36436 of 100000 complete in 305.9 sec
# ...
#  [-----------------87%-------------     ] 87104 of 100000 complete in 692.4 sec
#  [-----------------87%-------------     ] 87171 of 100000 complete in 692.9 sec
#  [-----------------87%-------------     ] 87238 of 100000 complete in 693.4 sec
#  [-----------------87%-------------     ] 87305 of 100000 complete in 693.9 sec
#  [-----------------87%-------------     ] 87369 of 100000 complete in 694.4 sec
#  [-----------------87%-------------     ] 87434 of 100000 complete in 694.9 sec
#  [-----------------87%-------------     ] 87498 of 100000 complete in 695.5 sec
#  [-----------------87%-------------     ] 87565 of 100000 complete in 696.0 sec
#  [-----------------87%-------------     ] 87630 of 100000 complete in 696.5 sec
#  [-----------------87%-------------     ] 87697 of 100000 complete in 697.0 sec
#  [-----------------87%-------------     ] 87762 of 100000 complete in 697.5 sec
#  [-----------------87%-------------     ] 87830 of 100000 complete in 698.0 sec
#  [-----------------87%-------------     ] 87895 of 100000 complete in 698.5 sec
#  [-----------------87%-------------     ] 87962 of 100000 complete in 699.0 sec
#  [-----------------88%-------------     ] 88027 of 100000 complete in 699.5 sec
#  [-----------------88%-------------     ] 88092 of 100000 complete in 700.0 sec
#  [-----------------88%-------------     ] 88149 of 100000 complete in 700.5 sec
#  [-----------------88%-------------     ] 88217 of 100000 complete in 701.0 sec
#  [-----------------88%-------------     ] 88284 of 100000 complete in 701.5 sec
#  [-----------------88%-------------     ] 88352 of 100000 complete in 702.0 sec
#  [-----------------88%-------------     ] 88419 of 100000 complete in 702.5 sec
#  [-----------------88%-------------     ] 88485 of 100000 complete in 703.0 sec
#  [-----------------88%-------------     ] 88552 of 100000 complete in 703.5 sec
#  [-----------------88%-------------     ] 88620 of 100000 complete in 704.0 sec
#  [-----------------88%-------------     ] 88686 of 100000 complete in 704.5 sec
#  [-----------------88%-------------     ] 88753 of 100000 complete in 705.0 sec
#  [-----------------88%-------------     ] 88818 of 100000 complete in 705.5 sec
#  [-----------------88%-------------     ] 88883 of 100000 complete in 706.0 sec
#  [-----------------88%-------------     ] 88949 of 100000 complete in 706.5 sec
#  [-----------------89%-------------     ] 89017 of 100000 complete in 707.0 sec
#  [-----------------89%-------------     ] 89084 of 100000 complete in 707.6 sec
#  [-----------------89%-------------     ] 89151 of 100000 complete in 708.1 sec
#  [-----------------89%-------------     ] 89217 of 100000 complete in 708.6 sec
#  [-----------------89%-------------     ] 89284 of 100000 complete in 709.1 sec
#  [-----------------89%-------------     ] 89351 of 100000 complete in 709.6 sec
#  [-----------------89%-------------     ] 89414 of 100000 complete in 710.1 sec
#  [-----------------89%--------------    ] 89481 of 100000 complete in 710.6 sec
#  [-----------------89%--------------    ] 89547 of 100000 complete in 711.1 sec
#  [-----------------89%--------------    ] 89609 of 100000 complete in 711.6 sec
#  [-----------------89%--------------    ] 89676 of 100000 complete in 712.1 sec
#  [-----------------89%--------------    ] 89741 of 100000 complete in 712.6 sec
#  [-----------------89%--------------    ] 89807 of 100000 complete in 713.1 sec
#  [-----------------89%--------------    ] 89874 of 100000 complete in 713.6 sec
#  [-----------------89%--------------    ] 89939 of 100000 complete in 714.1 sec
#  [-----------------90%--------------    ] 90002 of 100000 complete in 714.6 sec
#  [-----------------90%--------------    ] 90066 of 100000 complete in 715.1 sec
#  [-----------------90%--------------    ] 90134 of 100000 complete in 715.6 sec
#  [-----------------90%--------------    ] 90201 of 100000 complete in 716.1 sec
#  [-----------------90%--------------    ] 90260 of 100000 complete in 716.6 sec
#  [-----------------90%--------------    ] 90325 of 100000 complete in 717.1 sec
#  [-----------------90%--------------    ] 90389 of 100000 complete in 717.6 sec
#  [-----------------90%--------------    ] 90455 of 100000 complete in 718.2 sec
#  [-----------------90%--------------    ] 90520 of 100000 complete in 718.7 sec
#  [-----------------90%--------------    ] 90585 of 100000 complete in 719.2 sec
#  [-----------------90%--------------    ] 90651 of 100000 complete in 719.7 sec
#  [-----------------90%--------------    ] 90716 of 100000 complete in 720.2 sec
#  [-----------------90%--------------    ] 90780 of 100000 complete in 720.7 sec
#  [-----------------90%--------------    ] 90846 of 100000 complete in 721.2 sec
#  [-----------------90%--------------    ] 90913 of 100000 complete in 721.7 sec
#  [-----------------90%--------------    ] 90974 of 100000 complete in 722.2 sec
#  [-----------------91%--------------    ] 91039 of 100000 complete in 722.7 sec
#  [-----------------91%--------------    ] 91103 of 100000 complete in 723.2 sec
#  [-----------------91%--------------    ] 91170 of 100000 complete in 723.7 sec
#  [-----------------91%--------------    ] 91238 of 100000 complete in 724.2 sec
#  [-----------------91%--------------    ] 91298 of 100000 complete in 724.7 sec
#  [-----------------91%--------------    ] 91365 of 100000 complete in 725.2 sec
#  [-----------------91%--------------    ] 91428 of 100000 complete in 725.7 sec
#  [-----------------91%--------------    ] 91494 of 100000 complete in 726.2 sec
#  [-----------------91%--------------    ] 91558 of 100000 complete in 726.7 sec
#  [-----------------91%--------------    ] 91624 of 100000 complete in 727.2 sec
#  [-----------------91%--------------    ] 91687 of 100000 complete in 727.7 sec
#  [-----------------91%--------------    ] 91752 of 100000 complete in 728.2 sec
#  [-----------------91%--------------    ] 91817 of 100000 complete in 728.7 sec
#  [-----------------91%--------------    ] 91881 of 100000 complete in 729.2 sec
#  [-----------------91%--------------    ] 91947 of 100000 complete in 729.7 sec
#  [-----------------92%--------------    ] 92014 of 100000 complete in 730.3 sec
#  [-----------------92%--------------    ] 92077 of 100000 complete in 730.8 sec
#  [-----------------92%---------------   ] 92144 of 100000 complete in 731.3 sec
#  [-----------------92%---------------   ] 92211 of 100000 complete in 731.8 sec
#  [-----------------92%---------------   ] 92279 of 100000 complete in 732.3 sec
#  [-----------------92%---------------   ] 92340 of 100000 complete in 732.8 sec
#  [-----------------92%---------------   ] 92405 of 100000 complete in 733.3 sec
#  [-----------------92%---------------   ] 92472 of 100000 complete in 733.8 sec
#  [-----------------92%---------------   ] 92537 of 100000 complete in 734.3 sec
#  [-----------------92%---------------   ] 92604 of 100000 complete in 734.8 sec
#  [-----------------92%---------------   ] 92669 of 100000 complete in 735.3 sec
#  [-----------------92%---------------   ] 92735 of 100000 complete in 735.8 sec
#  [-----------------92%---------------   ] 92802 of 100000 complete in 736.3 sec
#  [-----------------92%---------------   ] 92867 of 100000 complete in 736.8 sec
#  [-----------------92%---------------   ] 92934 of 100000 complete in 737.3 sec
#  [-----------------93%---------------   ] 93002 of 100000 complete in 737.8 sec
#  [-----------------93%---------------   ] 93065 of 100000 complete in 738.3 sec
#  [-----------------93%---------------   ] 93131 of 100000 complete in 738.8 sec
#  [-----------------93%---------------   ] 93197 of 100000 complete in 739.3 sec
#  [-----------------93%---------------   ] 93264 of 100000 complete in 739.8 sec
#  [-----------------93%---------------   ] 93325 of 100000 complete in 740.3 sec
#  [-----------------93%---------------   ] 93389 of 100000 complete in 740.8 sec
#  [-----------------93%---------------   ] 93453 of 100000 complete in 741.3 sec
#  [-----------------93%---------------   ] 93520 of 100000 complete in 741.8 sec
#  [-----------------93%---------------   ] 93588 of 100000 complete in 742.3 sec
#  [-----------------93%---------------   ] 93654 of 100000 complete in 742.8 sec
#  [-----------------93%---------------   ] 93718 of 100000 complete in 743.3 sec
#  [-----------------93%---------------   ] 93781 of 100000 complete in 743.8 sec
#  [-----------------93%---------------   ] 93848 of 100000 complete in 744.3 sec
#  [-----------------93%---------------   ] 93910 of 100000 complete in 744.9 sec
#  [-----------------93%---------------   ] 93977 of 100000 complete in 745.4 sec
#  [-----------------94%---------------   ] 94044 of 100000 complete in 745.9 sec
#  [-----------------94%---------------   ] 94110 of 100000 complete in 746.4 sec
#  [-----------------94%---------------   ] 94174 of 100000 complete in 746.9 sec
#  [-----------------94%---------------   ] 94238 of 100000 complete in 747.4 sec
#  [-----------------94%---------------   ] 94301 of 100000 complete in 747.9 sec
#  [-----------------94%---------------   ] 94369 of 100000 complete in 748.4 sec
#  [-----------------94%---------------   ] 94431 of 100000 complete in 748.9 sec
#  [-----------------94%---------------   ] 94496 of 100000 complete in 749.4 sec
#  [-----------------94%---------------   ] 94564 of 100000 complete in 749.9 sec
#  [-----------------94%---------------   ] 94629 of 100000 complete in 750.4 sec
#  [-----------------94%---------------   ] 94695 of 100000 complete in 750.9 sec
#  [-----------------94%----------------  ] 94763 of 100000 complete in 751.4 sec
#  [-----------------94%----------------  ] 94830 of 100000 complete in 751.9 sec
#  [-----------------94%----------------  ] 94896 of 100000 complete in 752.4 sec
#  [-----------------94%----------------  ] 94962 of 100000 complete in 752.9 sec
#  [-----------------95%----------------  ] 95029 of 100000 complete in 753.4 sec
#  [-----------------95%----------------  ] 95097 of 100000 complete in 753.9 sec
#  [-----------------95%----------------  ] 95157 of 100000 complete in 754.4 sec
#  [-----------------95%----------------  ] 95224 of 100000 complete in 754.9 sec
#  [-----------------95%----------------  ] 95288 of 100000 complete in 755.4 sec
#  [-----------------95%----------------  ] 95348 of 100000 complete in 755.9 sec
#  [-----------------95%----------------  ] 95410 of 100000 complete in 756.4 sec
#  [-----------------95%----------------  ] 95475 of 100000 complete in 756.9 sec
#  [-----------------95%----------------  ] 95542 of 100000 complete in 757.4 sec
#  [-----------------95%----------------  ] 95608 of 100000 complete in 757.9 sec
#  [-----------------95%----------------  ] 95672 of 100000 complete in 758.4 sec
#  [-----------------95%----------------  ] 95738 of 100000 complete in 759.0 sec
#  [-----------------95%----------------  ] 95802 of 100000 complete in 759.5 sec
#  [-----------------95%----------------  ] 95867 of 100000 complete in 760.0 sec
#  [-----------------95%----------------  ] 95932 of 100000 complete in 760.5 sec
#  [-----------------95%----------------  ] 95998 of 100000 complete in 761.0 sec
#  [-----------------96%----------------  ] 96063 of 100000 complete in 761.5 sec
#  [-----------------96%----------------  ] 96130 of 100000 complete in 762.0 sec
#  [-----------------96%----------------  ] 96196 of 100000 complete in 762.5 sec
#  [-----------------96%----------------  ] 96263 of 100000 complete in 763.0 sec
#  [-----------------96%----------------  ] 96331 of 100000 complete in 763.5 sec
#  [-----------------96%----------------  ] 96398 of 100000 complete in 764.0 sec
#  [-----------------96%----------------  ] 96463 of 100000 complete in 764.5 sec
#  [-----------------96%----------------  ] 96522 of 100000 complete in 765.0 sec
#  [-----------------96%----------------  ] 96590 of 100000 complete in 765.5 sec
#  [-----------------96%----------------  ] 96657 of 100000 complete in 766.0 sec
#  [-----------------96%----------------  ] 96722 of 100000 complete in 766.5 sec
#  [-----------------96%----------------  ] 96789 of 100000 complete in 767.0 sec
#  [-----------------96%----------------  ] 96855 of 100000 complete in 767.5 sec
#  [-----------------96%----------------  ] 96922 of 100000 complete in 768.0 sec
#  [-----------------96%----------------  ] 96989 of 100000 complete in 768.5 sec
#  [-----------------97%----------------  ] 97056 of 100000 complete in 769.0 sec
#  [-----------------97%----------------  ] 97123 of 100000 complete in 769.5 sec
#  [-----------------97%----------------  ] 97189 of 100000 complete in 770.0 sec
#  [-----------------97%----------------  ] 97250 of 100000 complete in 770.6 sec
#  [-----------------97%----------------  ] 97316 of 100000 complete in 771.1 sec
#  [-----------------97%----------------- ] 97380 of 100000 complete in 771.6 sec
#  [-----------------97%----------------- ] 97448 of 100000 complete in 772.1 sec
#  [-----------------97%----------------- ] 97512 of 100000 complete in 772.6 sec
#  [-----------------97%----------------- ] 97579 of 100000 complete in 773.1 sec
#  [-----------------97%----------------- ] 97646 of 100000 complete in 773.6 sec
#  [-----------------97%----------------- ] 97714 of 100000 complete in 774.1 sec
#  [-----------------97%----------------- ] 97778 of 100000 complete in 774.6 sec
#  [-----------------97%----------------- ] 97844 of 100000 complete in 775.1 sec
#  [-----------------97%----------------- ] 97908 of 100000 complete in 775.6 sec
#  [-----------------97%----------------- ] 97974 of 100000 complete in 776.1 sec
#  [-----------------98%----------------- ] 98039 of 100000 complete in 776.6 sec
#  [-----------------98%----------------- ] 98107 of 100000 complete in 777.1 sec
#  [-----------------98%----------------- ] 98173 of 100000 complete in 777.6 sec
#  [-----------------98%----------------- ] 98240 of 100000 complete in 778.1 sec
#  [-----------------98%----------------- ] 98302 of 100000 complete in 778.6 sec
#  [-----------------98%----------------- ] 98367 of 100000 complete in 779.1 sec
#  [-----------------98%----------------- ] 98435 of 100000 complete in 779.6 sec
#  [-----------------98%----------------- ] 98501 of 100000 complete in 780.1 sec
#  [-----------------98%----------------- ] 98565 of 100000 complete in 780.6 sec
#  [-----------------98%----------------- ] 98627 of 100000 complete in 781.1 sec
#  [-----------------98%----------------- ] 98692 of 100000 complete in 781.6 sec
#  [-----------------98%----------------- ] 98759 of 100000 complete in 782.1 sec
#  [-----------------98%----------------- ] 98822 of 100000 complete in 782.6 sec
#  [-----------------98%----------------- ] 98888 of 100000 complete in 783.2 sec
#  [-----------------98%----------------- ] 98954 of 100000 complete in 783.7 sec
#  [-----------------99%----------------- ] 99021 of 100000 complete in 784.2 sec
#  [-----------------99%----------------- ] 99087 of 100000 complete in 784.7 sec
#  [-----------------99%----------------- ] 99152 of 100000 complete in 785.2 sec
#  [-----------------99%----------------- ] 99219 of 100000 complete in 785.7 sec
#  [-----------------99%----------------- ] 99285 of 100000 complete in 786.2 sec
#  [-----------------99%----------------- ] 99348 of 100000 complete in 786.7 sec
#  [-----------------99%----------------- ] 99414 of 100000 complete in 787.2 sec
#  [-----------------99%----------------- ] 99479 of 100000 complete in 787.7 sec
#  [-----------------99%----------------- ] 99546 of 100000 complete in 788.2 sec
#  [-----------------99%----------------- ] 99609 of 100000 complete in 788.7 sec
#  [-----------------99%----------------- ] 99672 of 100000 complete in 789.2 sec
#  [-----------------99%----------------- ] 99736 of 100000 complete in 789.7 sec
#  [-----------------99%----------------- ] 99802 of 100000 complete in 790.2 sec
#  [-----------------99%----------------- ] 99863 of 100000 complete in 790.7 sec
#  [-----------------99%----------------- ] 99928 of 100000 complete in 791.2 sec
#  [-----------------99%----------------- ] 99991 of 100000 complete in 791.7 sec
#  [-----------------100%-----------------] 100000 of 100000 complete in 791.8 sec

# %%
Mlang.sample(100000, 90000)
# Out:
#  [                  0%                  ] 2 of 100000 complete in 3.1 sec
#  [                  0%                  ] 61 of 100000 complete in 3.6 sec
#  [                  0%                  ] 127 of 100000 complete in 4.1 sec
#  [                  0%                  ] 192 of 100000 complete in 4.6 sec
#  [                  0%                  ] 259 of 100000 complete in 5.1 sec
#  [                  0%                  ] 325 of 100000 complete in 5.7 sec
#  [                  0%                  ] 392 of 100000 complete in 6.2 sec
#  [                  0%                  ] 453 of 100000 complete in 6.7 sec
#  [                  0%                  ] 520 of 100000 complete in 7.2 sec
#  [                  0%                  ] 584 of 100000 complete in 7.7 sec
#  [                  0%                  ] 651 of 100000 complete in 8.2 sec
#  [                  0%                  ] 712 of 100000 complete in 8.7 sec
#  [                  0%                  ] 779 of 100000 complete in 9.2 sec
#  [                  0%                  ] 838 of 100000 complete in 9.7 sec
#  [                  0%                  ] 905 of 100000 complete in 10.2 sec
#  [                  0%                  ] 965 of 100000 complete in 10.7 sec
#  [                  1%                  ] 1030 of 100000 complete in 11.2 sec
#  [                  1%                  ] 1095 of 100000 complete in 11.7 sec
#  [                  1%                  ] 1157 of 100000 complete in 12.2 sec
#  [                  1%                  ] 1217 of 100000 complete in 12.7 sec
#  [                  1%                  ] 1281 of 100000 complete in 13.2 sec
#  [                  1%                  ] 1347 of 100000 complete in 13.7 sec
#  [                  1%                  ] 1406 of 100000 complete in 14.2 sec
#  [                  1%                  ] 1470 of 100000 complete in 14.7 sec
#  [                  1%                  ] 1532 of 100000 complete in 15.2 sec
#  [                  1%                  ] 1598 of 100000 complete in 15.7 sec
#  [                  1%                  ] 1664 of 100000 complete in 16.2 sec
#  [                  1%                  ] 1729 of 100000 complete in 16.7 sec
#  [                  1%                  ] 1795 of 100000 complete in 17.2 sec
#  [                  1%                  ] 1862 of 100000 complete in 17.7 sec
#  [                  1%                  ] 1927 of 100000 complete in 18.2 sec
#  [                  1%                  ] 1987 of 100000 complete in 18.7 sec
#  [                  2%                  ] 2049 of 100000 complete in 19.3 sec
#  [                  2%                  ] 2114 of 100000 complete in 19.8 sec
#  [                  2%                  ] 2181 of 100000 complete in 20.3 sec
#  [                  2%                  ] 2247 of 100000 complete in 20.8 sec
#  [                  2%                  ] 2315 of 100000 complete in 21.3 sec
#  [                  2%                  ] 2382 of 100000 complete in 21.8 sec
#  [                  2%                  ] 2451 of 100000 complete in 22.3 sec
#  [                  2%                  ] 2518 of 100000 complete in 22.8 sec
#  [                  2%                  ] 2584 of 100000 complete in 23.3 sec
#  [-                 2%                  ] 2651 of 100000 complete in 23.8 sec
#  [-                 2%                  ] 2714 of 100000 complete in 24.3 sec
#  [-                 2%                  ] 2775 of 100000 complete in 24.8 sec
#  [-                 2%                  ] 2839 of 100000 complete in 25.3 sec
#  [-                 2%                  ] 2904 of 100000 complete in 25.8 sec
#  [-                 2%                  ] 2969 of 100000 complete in 26.3 sec
#  [-                 3%                  ] 3034 of 100000 complete in 26.8 sec
#  [-                 3%                  ] 3103 of 100000 complete in 27.3 sec
#  [-                 3%                  ] 3168 of 100000 complete in 27.8 sec
#  [-                 3%                  ] 3223 of 100000 complete in 28.3 sec
#  [-                 3%                  ] 3271 of 100000 complete in 28.8 sec
#  [-                 3%                  ] 3320 of 100000 complete in 29.3 sec
#  [-                 3%                  ] 3377 of 100000 complete in 29.8 sec
#  [-                 3%                  ] 3437 of 100000 complete in 30.3 sec
#  [-                 3%                  ] 3501 of 100000 complete in 30.8 sec
#  [-                 3%                  ] 3566 of 100000 complete in 31.3 sec
#  [-                 3%                  ] 3633 of 100000 complete in 31.8 sec
#  [-                 3%                  ] 3699 of 100000 complete in 32.4 sec
#  [-                 3%                  ] 3763 of 100000 complete in 32.9 sec
#  [-                 3%                  ] 3825 of 100000 complete in 33.4 sec
#  [-                 3%                  ] 3893 of 100000 complete in 33.9 sec
#  [-                 3%                  ] 3958 of 100000 complete in 34.4 sec
#  [-                 4%                  ] 4023 of 100000 complete in 34.9 sec
#  [-                 4%                  ] 4085 of 100000 complete in 35.4 sec
#  [-                 4%                  ] 4152 of 100000 complete in 35.9 sec
#  [-                 4%                  ] 4219 of 100000 complete in 36.4 sec
#  [-                 4%                  ] 4285 of 100000 complete in 36.9 sec
#  [-                 4%                  ] 4351 of 100000 complete in 37.4 sec
#  [-                 4%                  ] 4420 of 100000 complete in 37.9 sec
#  [-                 4%                  ] 4485 of 100000 complete in 38.4 sec
#  [-                 4%                  ] 4549 of 100000 complete in 38.9 sec
#  [-                 4%                  ] 4615 of 100000 complete in 39.4 sec
#  [-                 4%                  ] 4683 of 100000 complete in 39.9 sec
#  [-                 4%                  ] 4745 of 100000 complete in 40.4 sec
#  [-                 4%                  ] 4809 of 100000 complete in 40.9 sec
#  [-                 4%                  ] 4875 of 100000 complete in 41.4 sec
#  [-                 4%                  ] 4943 of 100000 complete in 41.9 sec
#  [-                 5%                  ] 5009 of 100000 complete in 42.4 sec
#  [-                 5%                  ] 5075 of 100000 complete in 42.9 sec
#  [-                 5%                  ] 5142 of 100000 complete in 43.5 sec
#  [-                 5%                  ] 5209 of 100000 complete in 44.0 sec
#  [--                5%                  ] 5273 of 100000 complete in 44.5 sec
#  [--                5%                  ] 5340 of 100000 complete in 45.0 sec
#  [--                5%                  ] 5406 of 100000 complete in 45.5 sec
#  [--                5%                  ] 5470 of 100000 complete in 46.0 sec
#  [--                5%                  ] 5536 of 100000 complete in 46.5 sec
#  [--                5%                  ] 5603 of 100000 complete in 47.0 sec
#  [--                5%                  ] 5671 of 100000 complete in 47.5 sec
#  [--                5%                  ] 5739 of 100000 complete in 48.0 sec
#  [--                5%                  ] 5804 of 100000 complete in 48.5 sec
#  [--                5%                  ] 5872 of 100000 complete in 49.0 sec
#  [--                5%                  ] 5939 of 100000 complete in 49.5 sec
#  [--                6%                  ] 6004 of 100000 complete in 50.0 sec
#  [--                6%                  ] 6068 of 100000 complete in 50.5 sec
#  [--                6%                  ] 6131 of 100000 complete in 51.0 sec
#  [--                6%                  ] 6196 of 100000 complete in 51.5 sec
#  [--                6%                  ] 6263 of 100000 complete in 52.0 sec
#  [--                6%                  ] 6328 of 100000 complete in 52.5 sec
#  [--                6%                  ] 6396 of 100000 complete in 53.0 sec
#  [--                6%                  ] 6463 of 100000 complete in 53.5 sec
#  [--                6%                  ] 6530 of 100000 complete in 54.0 sec
#  [--                6%                  ] 6595 of 100000 complete in 54.5 sec
#  [--                6%                  ] 6664 of 100000 complete in 55.0 sec
#  [--                6%                  ] 6731 of 100000 complete in 55.5 sec
#  [--                6%                  ] 6799 of 100000 complete in 56.0 sec
#  [--                6%                  ] 6862 of 100000 complete in 56.5 sec
#  [--                6%                  ] 6928 of 100000 complete in 57.0 sec
#  [--                6%                  ] 6995 of 100000 complete in 57.5 sec
#  [--                7%                  ] 7061 of 100000 complete in 58.0 sec
#  [--                7%                  ] 7127 of 100000 complete in 58.5 sec
#  [--                7%                  ] 7194 of 100000 complete in 59.0 sec
#  [--                7%                  ] 7261 of 100000 complete in 59.5 sec
#  [--                7%                  ] 7329 of 100000 complete in 60.0 sec
#  [--                7%                  ] 7396 of 100000 complete in 60.5 sec
#  [--                7%                  ] 7464 of 100000 complete in 61.0 sec
#  [--                7%                  ] 7532 of 100000 complete in 61.6 sec
#  [--                7%                  ] 7595 of 100000 complete in 62.1 sec
#  [--                7%                  ] 7661 of 100000 complete in 62.6 sec
#  [--                7%                  ] 7729 of 100000 complete in 63.1 sec
#  [--                7%                  ] 7796 of 100000 complete in 63.6 sec
#  [--                7%                  ] 7860 of 100000 complete in 64.1 sec
#  [---               7%                  ] 7925 of 100000 complete in 64.6 sec
#  [---               7%                  ] 7992 of 100000 complete in 65.1 sec
#  [---               8%                  ] 8060 of 100000 complete in 65.6 sec
#  [---               8%                  ] 8128 of 100000 complete in 66.1 sec
#  [---               8%                  ] 8195 of 100000 complete in 66.6 sec
#  [---               8%                  ] 8263 of 100000 complete in 67.1 sec
#  [---               8%                  ] 8326 of 100000 complete in 67.6 sec
#  [---               8%                  ] 8394 of 100000 complete in 68.1 sec
#  [---               8%                  ] 8461 of 100000 complete in 68.6 sec
#  [---               8%                  ] 8529 of 100000 complete in 69.1 sec
#  [---               8%                  ] 8594 of 100000 complete in 69.6 sec
#  [---               8%                  ] 8662 of 100000 complete in 70.1 sec
#  [---               8%                  ] 8725 of 100000 complete in 70.6 sec
#  [---               8%                  ] 8788 of 100000 complete in 71.1 sec
#  [---               8%                  ] 8854 of 100000 complete in 71.6 sec
#  [---               8%                  ] 8922 of 100000 complete in 72.1 sec
#  [---               8%                  ] 8987 of 100000 complete in 72.6 sec
#  [---               9%                  ] 9054 of 100000 complete in 73.1 sec
#  [---               9%                  ] 9121 of 100000 complete in 73.6 sec
#  [---               9%                  ] 9188 of 100000 complete in 74.2 sec
#  [---               9%                  ] 9254 of 100000 complete in 74.7 sec
#  [---               9%                  ] 9322 of 100000 complete in 75.2 sec
#  [---               9%                  ] 9389 of 100000 complete in 75.7 sec
#  [---               9%                  ] 9457 of 100000 complete in 76.2 sec
#  [---               9%                  ] 9524 of 100000 complete in 76.7 sec
#  [---               9%                  ] 9591 of 100000 complete in 77.2 sec
#  [---               9%                  ] 9657 of 100000 complete in 77.7 sec
#  [---               9%                  ] 9720 of 100000 complete in 78.2 sec
#  [---               9%                  ] 9785 of 100000 complete in 78.7 sec
#  [---               9%                  ] 9853 of 100000 complete in 79.2 sec
#  [---               9%                  ] 9920 of 100000 complete in 79.7 sec
#  [---               9%                  ] 9987 of 100000 complete in 80.2 sec
#  [---              10%                  ] 10051 of 100000 complete in 80.7 sec
#  [---              10%                  ] 10119 of 100000 complete in 81.2 sec
#  [---              10%                  ] 10185 of 100000 complete in 81.7 sec
#  [---              10%                  ] 10253 of 100000 complete in 82.2 sec
#  [---              10%                  ] 10319 of 100000 complete in 82.7 sec
#  [---              10%                  ] 10386 of 100000 complete in 83.2 sec
#  [---              10%                  ] 10447 of 100000 complete in 83.7 sec
#  [---              10%                  ] 10512 of 100000 complete in 84.2 sec
#  [----             10%                  ] 10572 of 100000 complete in 84.7 sec
#  [----             10%                  ] 10639 of 100000 complete in 85.2 sec
#  [----             10%                  ] 10704 of 100000 complete in 85.7 sec
#  [----             10%                  ] 10771 of 100000 complete in 86.2 sec
#  [----             10%                  ] 10837 of 100000 complete in 86.7 sec
#  [----             10%                  ] 10904 of 100000 complete in 87.3 sec
#  [----             10%                  ] 10970 of 100000 complete in 87.8 sec
#  [----             11%                  ] 11037 of 100000 complete in 88.3 sec
#  [----             11%                  ] 11101 of 100000 complete in 88.8 sec
#  [----             11%                  ] 11166 of 100000 complete in 89.3 sec
#  [----             11%                  ] 11233 of 100000 complete in 89.8 sec
#  [----             11%                  ] 11300 of 100000 complete in 90.3 sec
#  [----             11%                  ] 11366 of 100000 complete in 90.8 sec
#  [----             11%                  ] 11434 of 100000 complete in 91.3 sec
#  [----             11%                  ] 11502 of 100000 complete in 91.8 sec
#  [----             11%                  ] 11570 of 100000 complete in 92.3 sec
#  [----             11%                  ] 11636 of 100000 complete in 92.8 sec
#  [----             11%                  ] 11703 of 100000 complete in 93.3 sec
#  [----             11%                  ] 11769 of 100000 complete in 93.8 sec
#  [----             11%                  ] 11831 of 100000 complete in 94.3 sec
#  [----             11%                  ] 11896 of 100000 complete in 94.8 sec
#  [----             11%                  ] 11958 of 100000 complete in 95.3 sec
#  [----             12%                  ] 12024 of 100000 complete in 95.8 sec
#  [----             12%                  ] 12093 of 100000 complete in 96.3 sec
#  [----             12%                  ] 12157 of 100000 complete in 96.8 sec
#  [----             12%                  ] 12225 of 100000 complete in 97.3 sec
#  [----             12%                  ] 12292 of 100000 complete in 97.8 sec
#  [----             12%                  ] 12359 of 100000 complete in 98.3 sec
#  [----             12%                  ] 12423 of 100000 complete in 98.8 sec
#  [----             12%                  ] 12490 of 100000 complete in 99.3 sec
#  [----             12%                  ] 12553 of 100000 complete in 99.8 sec
#  [----             12%                  ] 12620 of 100000 complete in 100.3 sec
#  [----             12%                  ] 12684 of 100000 complete in 100.9 sec
#  [----             12%                  ] 12746 of 100000 complete in 101.4 sec
#  [----             12%                  ] 12814 of 100000 complete in 101.9 sec
#  [----             12%                  ] 12878 of 100000 complete in 102.4 sec
#  [----             12%                  ] 12943 of 100000 complete in 102.9 sec
#  [----             13%                  ] 13011 of 100000 complete in 103.4 sec
#  [----             13%                  ] 13078 of 100000 complete in 103.9 sec
#  [----             13%                  ] 13144 of 100000 complete in 104.4 sec
#  [-----            13%                  ] 13210 of 100000 complete in 104.9 sec
#  [-----            13%                  ] 13275 of 100000 complete in 105.4 sec
#  [-----            13%                  ] 13341 of 100000 complete in 105.9 sec
#  [-----            13%                  ] 13407 of 100000 complete in 106.4 sec
#  [-----            13%                  ] 13475 of 100000 complete in 106.9 sec
#  [-----            13%                  ] 13542 of 100000 complete in 107.4 sec
#  [-----            13%                  ] 13608 of 100000 complete in 107.9 sec
#  [-----            13%                  ] 13673 of 100000 complete in 108.4 sec
#  [-----            13%                  ] 13740 of 100000 complete in 108.9 sec
#  [-----            13%                  ] 13808 of 100000 complete in 109.4 sec
#  [-----            13%                  ] 13874 of 100000 complete in 109.9 sec
#  [-----            13%                  ] 13936 of 100000 complete in 110.4 sec
#  [-----            14%                  ] 14002 of 100000 complete in 110.9 sec
#  [-----            14%                  ] 14069 of 100000 complete in 111.4 sec
#  [-----            14%                  ] 14135 of 100000 complete in 111.9 sec
#  [-----            14%                  ] 14201 of 100000 complete in 112.4 sec
#  [-----            14%                  ] 14266 of 100000 complete in 112.9 sec
#  [-----            14%                  ] 14332 of 100000 complete in 113.5 sec
#  [-----            14%                  ] 14395 of 100000 complete in 114.0 sec
#  [-----            14%                  ] 14460 of 100000 complete in 114.5 sec
#  [-----            14%                  ] 14528 of 100000 complete in 115.0 sec
#  [-----            14%                  ] 14595 of 100000 complete in 115.5 sec
#  [-----            14%                  ] 14659 of 100000 complete in 116.0 sec
#  [-----            14%                  ] 14726 of 100000 complete in 116.5 sec
#  [-----            14%                  ] 14794 of 100000 complete in 117.0 sec
#  [-----            14%                  ] 14859 of 100000 complete in 117.5 sec
#  [-----            14%                  ] 14924 of 100000 complete in 118.0 sec
#  [-----            14%                  ] 14990 of 100000 complete in 118.5 sec
#  [-----            15%                  ] 15057 of 100000 complete in 119.0 sec
#  [-----            15%                  ] 15122 of 100000 complete in 119.5 sec
#  [-----            15%                  ] 15175 of 100000 complete in 120.0 sec
#  [-----            15%                  ] 15239 of 100000 complete in 120.5 sec
#  [-----            15%                  ] 15305 of 100000 complete in 121.0 sec
#  [-----            15%                  ] 15369 of 100000 complete in 121.5 sec
#  [-----            15%                  ] 15433 of 100000 complete in 122.0 sec
#  [-----            15%                  ] 15498 of 100000 complete in 122.5 sec
#  [-----            15%                  ] 15565 of 100000 complete in 123.0 sec
#  [-----            15%                  ] 15631 of 100000 complete in 123.5 sec
#  [-----            15%                  ] 15699 of 100000 complete in 124.0 sec
#  [-----            15%                  ] 15764 of 100000 complete in 124.5 sec
#  [------           15%                  ] 15830 of 100000 complete in 125.0 sec
#  [------           15%                  ] 15896 of 100000 complete in 125.5 sec
#  [------           15%                  ] 15963 of 100000 complete in 126.0 sec
#  [------           16%                  ] 16025 of 100000 complete in 126.5 sec
#  [------           16%                  ] 16093 of 100000 complete in 127.1 sec
#  [------           16%                  ] 16161 of 100000 complete in 127.6 sec
#  [------           16%                  ] 16229 of 100000 complete in 128.1 sec
#  [------           16%                  ] 16292 of 100000 complete in 128.6 sec
#  [------           16%                  ] 16359 of 100000 complete in 129.1 sec
#  [------           16%                  ] 16422 of 100000 complete in 129.6 sec
#  [------           16%                  ] 16487 of 100000 complete in 130.1 sec
#  [------           16%                  ] 16550 of 100000 complete in 130.6 sec
#  [------           16%                  ] 16617 of 100000 complete in 131.1 sec
#  [------           16%                  ] 16685 of 100000 complete in 131.6 sec
#  [------           16%                  ] 16750 of 100000 complete in 132.1 sec
#  [------           16%                  ] 16815 of 100000 complete in 132.6 sec
#  [------           16%                  ] 16884 of 100000 complete in 133.1 sec
#  [------           16%                  ] 16951 of 100000 complete in 133.6 sec
#  [------           17%                  ] 17018 of 100000 complete in 134.1 sec
#  [------           17%                  ] 17084 of 100000 complete in 134.6 sec
#  [------           17%                  ] 17151 of 100000 complete in 135.1 sec
#  [------           17%                  ] 17217 of 100000 complete in 135.6 sec
#  [------           17%                  ] 17282 of 100000 complete in 136.1 sec
#  [------           17%                  ] 17348 of 100000 complete in 136.6 sec
#  [------           17%                  ] 17415 of 100000 complete in 137.1 sec
#  [------           17%                  ] 17480 of 100000 complete in 137.6 sec
#  [------           17%                  ] 17540 of 100000 complete in 138.1 sec
#  [------           17%                  ] 17604 of 100000 complete in 138.6 sec
#  [------           17%                  ] 17671 of 100000 complete in 139.1 sec
#  [------           17%                  ] 17738 of 100000 complete in 139.6 sec
#  [------           17%                  ] 17805 of 100000 complete in 140.2 sec
#  [------           17%                  ] 17872 of 100000 complete in 140.7 sec
#  [------           17%                  ] 17940 of 100000 complete in 141.2 sec
#  [------           18%                  ] 18005 of 100000 complete in 141.7 sec
#  [------           18%                  ] 18072 of 100000 complete in 142.2 sec
#  [------           18%                  ] 18134 of 100000 complete in 142.7 sec
#  [------           18%                  ] 18201 of 100000 complete in 143.2 sec
#  [------           18%                  ] 18268 of 100000 complete in 143.7 sec
#  [------           18%                  ] 18334 of 100000 complete in 144.2 sec
#  [------           18%                  ] 18401 of 100000 complete in 144.7 sec
#  [-------          18%                  ] 18467 of 100000 complete in 145.2 sec
#  [-------          18%                  ] 18535 of 100000 complete in 145.7 sec
#  [-------          18%                  ] 18601 of 100000 complete in 146.2 sec
#  [-------          18%                  ] 18666 of 100000 complete in 146.7 sec
#  [-------          18%                  ] 18733 of 100000 complete in 147.2 sec
#  [-------          18%                  ] 18801 of 100000 complete in 147.7 sec
#  [-------          18%                  ] 18865 of 100000 complete in 148.2 sec
#  [-------          18%                  ] 18927 of 100000 complete in 148.7 sec
#  [-------          18%                  ] 18994 of 100000 complete in 149.2 sec
#  [-------          19%                  ] 19061 of 100000 complete in 149.7 sec
#  [-------          19%                  ] 19127 of 100000 complete in 150.2 sec
#  [-------          19%                  ] 19191 of 100000 complete in 150.7 sec
#  [-------          19%                  ] 19257 of 100000 complete in 151.2 sec
#  [-------          19%                  ] 19325 of 100000 complete in 151.7 sec
#  [-------          19%                  ] 19391 of 100000 complete in 152.2 sec
#  [-------          19%                  ] 19454 of 100000 complete in 152.7 sec
#  [-------          19%                  ] 19520 of 100000 complete in 153.3 sec
#  [-------          19%                  ] 19585 of 100000 complete in 153.8 sec
#  [-------          19%                  ] 19652 of 100000 complete in 154.3 sec
#  [-------          19%                  ] 19718 of 100000 complete in 154.8 sec
#  [-------          19%                  ] 19785 of 100000 complete in 155.3 sec
#  [-------          19%                  ] 19853 of 100000 complete in 155.8 sec
#  [-------          19%                  ] 19917 of 100000 complete in 156.3 sec
#  [-------          19%                  ] 19982 of 100000 complete in 156.8 sec
#  [-------          20%                  ] 20050 of 100000 complete in 157.3 sec
#  [-------          20%                  ] 20117 of 100000 complete in 157.8 sec
#  [-------          20%                  ] 20186 of 100000 complete in 158.3 sec
#  [-------          20%                  ] 20247 of 100000 complete in 158.8 sec
#  [-------          20%                  ] 20315 of 100000 complete in 159.3 sec
#  [-------          20%                  ] 20382 of 100000 complete in 159.8 sec
#  [-------          20%                  ] 20449 of 100000 complete in 160.3 sec
#  [-------          20%                  ] 20514 of 100000 complete in 160.8 sec
#  [-------          20%                  ] 20576 of 100000 complete in 161.3 sec
#  [-------          20%                  ] 20642 of 100000 complete in 161.8 sec
#  [-------          20%                  ] 20709 of 100000 complete in 162.3 sec
#  [-------          20%                  ] 20773 of 100000 complete in 162.8 sec
#  [-------          20%                  ] 20840 of 100000 complete in 163.3 sec
#  [-------          20%                  ] 20907 of 100000 complete in 163.8 sec
#  [-------          20%                  ] 20971 of 100000 complete in 164.3 sec
#  [-------          21%                  ] 21036 of 100000 complete in 164.8 sec
#  [--------         21%                  ] 21103 of 100000 complete in 165.3 sec
#  [--------         21%                  ] 21170 of 100000 complete in 165.8 sec
#  [--------         21%                  ] 21237 of 100000 complete in 166.3 sec
#  [--------         21%                  ] 21304 of 100000 complete in 166.8 sec
#  [--------         21%                  ] 21372 of 100000 complete in 167.3 sec
#  [--------         21%                  ] 21435 of 100000 complete in 167.8 sec
#  [--------         21%                  ] 21503 of 100000 complete in 168.4 sec
#  [--------         21%                  ] 21567 of 100000 complete in 168.9 sec
#  [--------         21%                  ] 21632 of 100000 complete in 169.4 sec
#  [--------         21%                  ] 21698 of 100000 complete in 169.9 sec
#  [--------         21%                  ] 21765 of 100000 complete in 170.4 sec
#  [--------         21%                  ] 21832 of 100000 complete in 170.9 sec
#  [--------         21%                  ] 21899 of 100000 complete in 171.4 sec
#  [--------         21%                  ] 21965 of 100000 complete in 171.9 sec
#  [--------         22%                  ] 22031 of 100000 complete in 172.4 sec
#  [--------         22%                  ] 22099 of 100000 complete in 172.9 sec
#  [--------         22%                  ] 22167 of 100000 complete in 173.4 sec
#  [--------         22%                  ] 22234 of 100000 complete in 173.9 sec
#  [--------         22%                  ] 22300 of 100000 complete in 174.4 sec
#  [--------         22%                  ] 22363 of 100000 complete in 174.9 sec
#  [--------         22%                  ] 22430 of 100000 complete in 175.4 sec
#  [--------         22%                  ] 22498 of 100000 complete in 175.9 sec
#  [--------         22%                  ] 22564 of 100000 complete in 176.4 sec
#  [--------         22%                  ] 22632 of 100000 complete in 176.9 sec
#  [--------         22%                  ] 22700 of 100000 complete in 177.4 sec
#  [--------         22%                  ] 22766 of 100000 complete in 177.9 sec
#  [--------         22%                  ] 22832 of 100000 complete in 178.4 sec
#  [--------         22%                  ] 22900 of 100000 complete in 178.9 sec
#  [--------         22%                  ] 22966 of 100000 complete in 179.4 sec
#  [--------         23%                  ] 23034 of 100000 complete in 179.9 sec
#  [--------         23%                  ] 23097 of 100000 complete in 180.4 sec
#  [--------         23%                  ] 23165 of 100000 complete in 180.9 sec
#  [--------         23%                  ] 23232 of 100000 complete in 181.5 sec
#  [--------         23%                  ] 23296 of 100000 complete in 182.0 sec
#  [--------         23%                  ] 23362 of 100000 complete in 182.5 sec
#  [--------         23%                  ] 23429 of 100000 complete in 183.0 sec
#  [--------         23%                  ] 23497 of 100000 complete in 183.5 sec
#  [--------         23%                  ] 23564 of 100000 complete in 184.0 sec
#  [--------         23%                  ] 23627 of 100000 complete in 184.5 sec
#  [---------        23%                  ] 23694 of 100000 complete in 185.0 sec
#  [---------        23%                  ] 23757 of 100000 complete in 185.5 sec
#  [---------        23%                  ] 23825 of 100000 complete in 186.0 sec
#  [---------        23%                  ] 23891 of 100000 complete in 186.5 sec
#  [---------        23%                  ] 23959 of 100000 complete in 187.0 sec
#  [---------        24%                  ] 24027 of 100000 complete in 187.5 sec
#  [---------        24%                  ] 24094 of 100000 complete in 188.0 sec
#  [---------        24%                  ] 24160 of 100000 complete in 188.5 sec
#  [---------        24%                  ] 24228 of 100000 complete in 189.0 sec
#  [---------        24%                  ] 24295 of 100000 complete in 189.5 sec
#  [---------        24%                  ] 24362 of 100000 complete in 190.0 sec
#  [---------        24%                  ] 24424 of 100000 complete in 190.5 sec
#  [---------        24%                  ] 24484 of 100000 complete in 191.0 sec
#  [---------        24%                  ] 24550 of 100000 complete in 191.5 sec
#  [---------        24%                  ] 24618 of 100000 complete in 192.0 sec
#  [---------        24%                  ] 24684 of 100000 complete in 192.6 sec
#  [---------        24%                  ] 24751 of 100000 complete in 193.1 sec
#  [---------        24%                  ] 24818 of 100000 complete in 193.6 sec
#  [---------        24%                  ] 24885 of 100000 complete in 194.1 sec
#  [---------        24%                  ] 24947 of 100000 complete in 194.6 sec
#  [---------        25%                  ] 25015 of 100000 complete in 195.1 sec
#  [---------        25%                  ] 25082 of 100000 complete in 195.6 sec
#  [---------        25%                  ] 25149 of 100000 complete in 196.1 sec
#  [---------        25%                  ] 25211 of 100000 complete in 196.6 sec
#  [---------        25%                  ] 25278 of 100000 complete in 197.1 sec
#  [---------        25%                  ] 25343 of 100000 complete in 197.6 sec
#  [---------        25%                  ] 25408 of 100000 complete in 198.1 sec
#  [---------        25%                  ] 25468 of 100000 complete in 198.6 sec
#  [---------        25%                  ] 25530 of 100000 complete in 199.1 sec
#  [---------        25%                  ] 25579 of 100000 complete in 199.6 sec
#  [---------        25%                  ] 25627 of 100000 complete in 200.1 sec
#  [---------        25%                  ] 25683 of 100000 complete in 200.6 sec
#  [---------        25%                  ] 25743 of 100000 complete in 201.1 sec
#  [---------        25%                  ] 25803 of 100000 complete in 201.6 sec
#  [---------        25%                  ] 25858 of 100000 complete in 202.1 sec
#  [---------        25%                  ] 25913 of 100000 complete in 202.6 sec
#  [---------        25%                  ] 25978 of 100000 complete in 203.1 sec
#  [---------        26%                  ] 26042 of 100000 complete in 203.6 sec
#  [---------        26%                  ] 26100 of 100000 complete in 204.1 sec
#  [---------        26%                  ] 26157 of 100000 complete in 204.6 sec
#  [---------        26%                  ] 26215 of 100000 complete in 205.2 sec
#  [---------        26%                  ] 26279 of 100000 complete in 205.7 sec
#  [----------       26%                  ] 26344 of 100000 complete in 206.2 sec
#  [----------       26%                  ] 26407 of 100000 complete in 206.7 sec
#  [----------       26%                  ] 26467 of 100000 complete in 207.2 sec
#  [----------       26%                  ] 26534 of 100000 complete in 207.7 sec
#  [----------       26%                  ] 26600 of 100000 complete in 208.2 sec
#  [----------       26%                  ] 26665 of 100000 complete in 208.7 sec
#  [----------       26%                  ] 26727 of 100000 complete in 209.2 sec
#  [----------       26%                  ] 26793 of 100000 complete in 209.7 sec
#  [----------       26%                  ] 26859 of 100000 complete in 210.2 sec
#  [----------       26%                  ] 26923 of 100000 complete in 210.7 sec
#  [----------       26%                  ] 26989 of 100000 complete in 211.2 sec
#  [----------       27%                  ] 27056 of 100000 complete in 211.7 sec
#  [----------       27%                  ] 27121 of 100000 complete in 212.2 sec
#  [----------       27%                  ] 27180 of 100000 complete in 212.7 sec
#  [----------       27%                  ] 27247 of 100000 complete in 213.2 sec
#  [----------       27%                  ] 27313 of 100000 complete in 213.7 sec
#  [----------       27%                  ] 27381 of 100000 complete in 214.2 sec
#  [----------       27%                  ] 27444 of 100000 complete in 214.7 sec
#  [----------       27%                  ] 27509 of 100000 complete in 215.2 sec
#  [----------       27%                  ] 27575 of 100000 complete in 215.7 sec
#  [----------       27%                  ] 27642 of 100000 complete in 216.2 sec
#  [----------       27%                  ] 27701 of 100000 complete in 216.7 sec
#  [----------       27%                  ] 27762 of 100000 complete in 217.2 sec
#  [----------       27%                  ] 27825 of 100000 complete in 217.7 sec
#  [----------       27%                  ] 27891 of 100000 complete in 218.2 sec
#  [----------       27%                  ] 27956 of 100000 complete in 218.7 sec
#  [----------       28%                  ] 28024 of 100000 complete in 219.2 sec
#  [----------       28%                  ] 28090 of 100000 complete in 219.7 sec
#  [----------       28%                  ] 28157 of 100000 complete in 220.3 sec
#  [----------       28%                  ] 28220 of 100000 complete in 220.8 sec
#  [----------       28%                  ] 28288 of 100000 complete in 221.3 sec
#  [----------       28%                  ] 28348 of 100000 complete in 221.8 sec
#  [----------       28%                  ] 28413 of 100000 complete in 222.3 sec
#  [----------       28%                  ] 28472 of 100000 complete in 222.8 sec
#  [----------       28%                  ] 28533 of 100000 complete in 223.3 sec
#  [----------       28%                  ] 28598 of 100000 complete in 223.8 sec
#  [----------       28%                  ] 28663 of 100000 complete in 224.3 sec
#  [----------       28%                  ] 28722 of 100000 complete in 224.8 sec
#  [----------       28%                  ] 28779 of 100000 complete in 225.3 sec
#  [----------       28%                  ] 28846 of 100000 complete in 225.8 sec
#  [----------       28%                  ] 28912 of 100000 complete in 226.3 sec
#  [-----------      28%                  ] 28977 of 100000 complete in 226.8 sec
#  [-----------      29%                  ] 29043 of 100000 complete in 227.3 sec
#  [-----------      29%                  ] 29110 of 100000 complete in 227.8 sec
#  [-----------      29%                  ] 29177 of 100000 complete in 228.3 sec
#  [-----------      29%                  ] 29236 of 100000 complete in 228.8 sec
#  [-----------      29%                  ] 29303 of 100000 complete in 229.3 sec
#  [-----------      29%                  ] 29363 of 100000 complete in 229.8 sec
#  [-----------      29%                  ] 29422 of 100000 complete in 230.3 sec
#  [-----------      29%                  ] 29478 of 100000 complete in 230.8 sec
#  [-----------      29%                  ] 29539 of 100000 complete in 231.3 sec
#  [-----------      29%                  ] 29601 of 100000 complete in 231.8 sec
#  [-----------      29%                  ] 29667 of 100000 complete in 232.3 sec
#  [-----------      29%                  ] 29730 of 100000 complete in 232.8 sec
#  [-----------      29%                  ] 29797 of 100000 complete in 233.3 sec
#  [-----------      29%                  ] 29863 of 100000 complete in 233.8 sec
#  [-----------      29%                  ] 29926 of 100000 complete in 234.4 sec
#  [-----------      29%                  ] 29991 of 100000 complete in 234.9 sec
#  [-----------      30%                  ] 30059 of 100000 complete in 235.4 sec
#  [-----------      30%                  ] 30124 of 100000 complete in 235.9 sec
#  [-----------      30%                  ] 30191 of 100000 complete in 236.4 sec
#  [-----------      30%                  ] 30258 of 100000 complete in 236.9 sec
#  [-----------      30%                  ] 30324 of 100000 complete in 237.4 sec
#  [-----------      30%                  ] 30391 of 100000 complete in 237.9 sec
#  [-----------      30%                  ] 30455 of 100000 complete in 238.4 sec
#  [-----------      30%                  ] 30521 of 100000 complete in 238.9 sec
#  [-----------      30%                  ] 30585 of 100000 complete in 239.4 sec
#  [-----------      30%                  ] 30633 of 100000 complete in 239.9 sec
#  [-----------      30%                  ] 30697 of 100000 complete in 240.4 sec
#  [-----------      30%                  ] 30760 of 100000 complete in 240.9 sec
#  [-----------      30%                  ] 30826 of 100000 complete in 241.4 sec
#  [-----------      30%                  ] 30892 of 100000 complete in 241.9 sec
#  [-----------      30%                  ] 30955 of 100000 complete in 242.4 sec
#  [-----------      31%                  ] 31021 of 100000 complete in 242.9 sec
#  [-----------      31%                  ] 31085 of 100000 complete in 243.4 sec
#  [-----------      31%                  ] 31150 of 100000 complete in 243.9 sec
#  [-----------      31%                  ] 31214 of 100000 complete in 244.4 sec
#  [-----------      31%                  ] 31271 of 100000 complete in 244.9 sec
#  [-----------      31%                  ] 31328 of 100000 complete in 245.4 sec
#  [-----------      31%                  ] 31390 of 100000 complete in 245.9 sec
#  [-----------      31%                  ] 31456 of 100000 complete in 246.4 sec
#  [-----------      31%                  ] 31523 of 100000 complete in 246.9 sec
#  [------------     31%                  ] 31591 of 100000 complete in 247.4 sec
#  [------------     31%                  ] 31659 of 100000 complete in 248.0 sec
#  [------------     31%                  ] 31724 of 100000 complete in 248.5 sec
#  [------------     31%                  ] 31792 of 100000 complete in 249.0 sec
#  [------------     31%                  ] 31859 of 100000 complete in 249.5 sec
#  [------------     31%                  ] 31920 of 100000 complete in 250.0 sec
#  [------------     31%                  ] 31981 of 100000 complete in 250.5 sec
#  [------------     32%                  ] 32042 of 100000 complete in 251.0 sec
#  [------------     32%                  ] 32103 of 100000 complete in 251.5 sec
#  [------------     32%                  ] 32168 of 100000 complete in 252.0 sec
#  [------------     32%                  ] 32233 of 100000 complete in 252.5 sec
#  [------------     32%                  ] 32298 of 100000 complete in 253.0 sec
#  [------------     32%                  ] 32365 of 100000 complete in 253.5 sec
#  [------------     32%                  ] 32431 of 100000 complete in 254.0 sec
#  [------------     32%                  ] 32494 of 100000 complete in 254.5 sec
#  [------------     32%                  ] 32561 of 100000 complete in 255.0 sec
#  [------------     32%                  ] 32624 of 100000 complete in 255.5 sec
#  [------------     32%                  ] 32689 of 100000 complete in 256.0 sec
#  [------------     32%                  ] 32751 of 100000 complete in 256.5 sec
#  [------------     32%                  ] 32811 of 100000 complete in 257.0 sec
#  [------------     32%                  ] 32870 of 100000 complete in 257.5 sec
#  [------------     32%                  ] 32935 of 100000 complete in 258.0 sec
#  [------------     33%                  ] 33000 of 100000 complete in 258.5 sec
#  [------------     33%                  ] 33067 of 100000 complete in 259.0 sec
#  [------------     33%                  ] 33133 of 100000 complete in 259.5 sec
#  [------------     33%                  ] 33199 of 100000 complete in 260.0 sec
#  [------------     33%                  ] 33262 of 100000 complete in 260.5 sec
#  [------------     33%                  ] 33328 of 100000 complete in 261.0 sec
#  [------------     33%                  ] 33394 of 100000 complete in 261.5 sec
#  [------------     33%                  ] 33452 of 100000 complete in 262.0 sec
#  [------------     33%                  ] 33518 of 100000 complete in 262.6 sec
#  [------------     33%                  ] 33584 of 100000 complete in 263.1 sec
#  [------------     33%                  ] 33650 of 100000 complete in 263.6 sec
#  [------------     33%                  ] 33714 of 100000 complete in 264.1 sec
#  [------------     33%                  ] 33769 of 100000 complete in 264.6 sec
#  [------------     33%                  ] 33821 of 100000 complete in 265.1 sec
#  [------------     33%                  ] 33886 of 100000 complete in 265.6 sec
#  [------------     33%                  ] 33953 of 100000 complete in 266.1 sec
#  [------------     34%                  ] 34014 of 100000 complete in 266.6 sec
#  [------------     34%                  ] 34081 of 100000 complete in 267.1 sec
#  [------------     34%                  ] 34149 of 100000 complete in 267.6 sec
#  [-------------    34%                  ] 34216 of 100000 complete in 268.1 sec
#  [-------------    34%                  ] 34276 of 100000 complete in 268.6 sec
#  [-------------    34%                  ] 34333 of 100000 complete in 269.1 sec
#  [-------------    34%                  ] 34394 of 100000 complete in 269.6 sec
#  [-------------    34%                  ] 34457 of 100000 complete in 270.1 sec
#  [-------------    34%                  ] 34513 of 100000 complete in 270.6 sec
#  [-------------    34%                  ] 34570 of 100000 complete in 271.1 sec
#  [-------------    34%                  ] 34627 of 100000 complete in 271.6 sec
#  [-------------    34%                  ] 34687 of 100000 complete in 272.1 sec
#  [-------------    34%                  ] 34750 of 100000 complete in 272.6 sec
#  [-------------    34%                  ] 34810 of 100000 complete in 273.1 sec
#  [-------------    34%                  ] 34868 of 100000 complete in 273.6 sec
#  [-------------    34%                  ] 34927 of 100000 complete in 274.2 sec
#  [-------------    34%                  ] 34986 of 100000 complete in 274.7 sec
#  [-------------    35%                  ] 35052 of 100000 complete in 275.2 sec
#  [-------------    35%                  ] 35110 of 100000 complete in 275.7 sec
#  [-------------    35%                  ] 35177 of 100000 complete in 276.2 sec
#  [-------------    35%                  ] 35237 of 100000 complete in 276.7 sec
#  [-------------    35%                  ] 35291 of 100000 complete in 277.2 sec
#  [-------------    35%                  ] 35347 of 100000 complete in 277.7 sec
#  [-------------    35%                  ] 35408 of 100000 complete in 278.2 sec
#  [-------------    35%                  ] 35463 of 100000 complete in 278.7 sec
#  [-------------    35%                  ] 35520 of 100000 complete in 279.2 sec
#  [-------------    35%                  ] 35578 of 100000 complete in 279.7 sec
#  [-------------    35%                  ] 35639 of 100000 complete in 280.2 sec
#  [-------------    35%                  ] 35703 of 100000 complete in 280.7 sec
#  [-------------    35%                  ] 35762 of 100000 complete in 281.2 sec
#  [-------------    35%                  ] 35822 of 100000 complete in 281.7 sec
#  [-------------    35%                  ] 35881 of 100000 complete in 282.2 sec
#  [-------------    35%                  ] 35924 of 100000 complete in 282.7 sec
#  [-------------    35%                  ] 35978 of 100000 complete in 283.2 sec
#  [-------------    36%                  ] 36033 of 100000 complete in 283.7 sec
#  [-------------    36%                  ] 36095 of 100000 complete in 284.2 sec
#  [-------------    36%                  ] 36155 of 100000 complete in 284.8 sec
#  [-------------    36%                  ] 36221 of 100000 complete in 285.3 sec
#  [-------------    36%                  ] 36288 of 100000 complete in 285.8 sec
#  [-------------    36%                  ] 36355 of 100000 complete in 286.3 sec
#  [-------------    36%                  ] 36420 of 100000 complete in 286.8 sec
#  [-------------    36%                  ] 36488 of 100000 complete in 287.3 sec
#  [-------------    36%                  ] 36554 of 100000 complete in 287.8 sec
#  [-------------    36%                  ] 36617 of 100000 complete in 288.3 sec
#  [-------------    36%                  ] 36682 of 100000 complete in 288.8 sec
#  [-------------    36%                  ] 36749 of 100000 complete in 289.3 sec
#  [-------------    36%                  ] 36816 of 100000 complete in 289.8 sec
#  [--------------   36%                  ] 36883 of 100000 complete in 290.3 sec
#  [--------------   36%                  ] 36949 of 100000 complete in 290.8 sec
#  [--------------   37%                  ] 37015 of 100000 complete in 291.3 sec
#  [--------------   37%                  ] 37080 of 100000 complete in 291.8 sec
#  [--------------   37%                  ] 37148 of 100000 complete in 292.3 sec
#  [--------------   37%                  ] 37214 of 100000 complete in 292.8 sec
#  [--------------   37%                  ] 37276 of 100000 complete in 293.3 sec
#  [--------------   37%                  ] 37339 of 100000 complete in 293.8 sec
#  [--------------   37%                  ] 37407 of 100000 complete in 294.3 sec
#  [--------------   37%                  ] 37472 of 100000 complete in 294.8 sec
#  [--------------   37%                  ] 37541 of 100000 complete in 295.3 sec
#  [--------------   37%                  ] 37608 of 100000 complete in 295.8 sec
#  [--------------   37%                  ] 37673 of 100000 complete in 296.3 sec
#  [--------------   37%                  ] 37739 of 100000 complete in 296.8 sec
#  [--------------   37%                  ] 37804 of 100000 complete in 297.3 sec
#  [--------------   37%                  ] 37872 of 100000 complete in 297.8 sec
#  [--------------   37%                  ] 37940 of 100000 complete in 298.4 sec
#  [--------------   37%                  ] 37999 of 100000 complete in 298.9 sec
#  [--------------   38%                  ] 38065 of 100000 complete in 299.4 sec
#  [--------------   38%                  ] 38130 of 100000 complete in 299.9 sec
#  [--------------   38%                  ] 38197 of 100000 complete in 300.4 sec
#  [--------------   38%                  ] 38263 of 100000 complete in 300.9 sec
#  [--------------   38%                  ] 38329 of 100000 complete in 301.4 sec
#  [--------------   38%                  ] 38397 of 100000 complete in 301.9 sec
#  [--------------   38%                  ] 38465 of 100000 complete in 302.4 sec
#  [--------------   38%                  ] 38531 of 100000 complete in 302.9 sec
#  [--------------   38%                  ] 38598 of 100000 complete in 303.4 sec
#  [--------------   38%                  ] 38663 of 100000 complete in 303.9 sec
#  [--------------   38%                  ] 38725 of 100000 complete in 304.4 sec
#  [--------------   38%                  ] 38793 of 100000 complete in 304.9 sec
#  [--------------   38%                  ] 38860 of 100000 complete in 305.4 sec
#  [--------------   38%                  ] 38922 of 100000 complete in 305.9 sec
#  [--------------   38%                  ] 38989 of 100000 complete in 306.4 sec
#  [--------------   39%                  ] 39056 of 100000 complete in 306.9 sec
# ...
#  [-----------------86%-------------     ] 86922 of 100000 complete in 672.2 sec
#  [-----------------86%-------------     ] 86988 of 100000 complete in 672.7 sec
#  [-----------------87%-------------     ] 87054 of 100000 complete in 673.2 sec
#  [-----------------87%-------------     ] 87121 of 100000 complete in 673.7 sec
#  [-----------------87%-------------     ] 87185 of 100000 complete in 674.2 sec
#  [-----------------87%-------------     ] 87250 of 100000 complete in 674.7 sec
#  [-----------------87%-------------     ] 87318 of 100000 complete in 675.2 sec
#  [-----------------87%-------------     ] 87385 of 100000 complete in 675.8 sec
#  [-----------------87%-------------     ] 87452 of 100000 complete in 676.3 sec
#  [-----------------87%-------------     ] 87518 of 100000 complete in 676.8 sec
#  [-----------------87%-------------     ] 87586 of 100000 complete in 677.3 sec
#  [-----------------87%-------------     ] 87655 of 100000 complete in 677.8 sec
#  [-----------------87%-------------     ] 87722 of 100000 complete in 678.3 sec
#  [-----------------87%-------------     ] 87788 of 100000 complete in 678.8 sec
#  [-----------------87%-------------     ] 87854 of 100000 complete in 679.3 sec
#  [-----------------87%-------------     ] 87920 of 100000 complete in 679.8 sec
#  [-----------------87%-------------     ] 87987 of 100000 complete in 680.3 sec
#  [-----------------88%-------------     ] 88053 of 100000 complete in 680.8 sec
#  [-----------------88%-------------     ] 88120 of 100000 complete in 681.3 sec
#  [-----------------88%-------------     ] 88186 of 100000 complete in 681.8 sec
#  [-----------------88%-------------     ] 88253 of 100000 complete in 682.3 sec
#  [-----------------88%-------------     ] 88319 of 100000 complete in 682.8 sec
#  [-----------------88%-------------     ] 88385 of 100000 complete in 683.3 sec
#  [-----------------88%-------------     ] 88453 of 100000 complete in 683.8 sec
#  [-----------------88%-------------     ] 88514 of 100000 complete in 684.3 sec
#  [-----------------88%-------------     ] 88578 of 100000 complete in 684.8 sec
#  [-----------------88%-------------     ] 88642 of 100000 complete in 685.3 sec
#  [-----------------88%-------------     ] 88709 of 100000 complete in 685.8 sec
#  [-----------------88%-------------     ] 88777 of 100000 complete in 686.3 sec
#  [-----------------88%-------------     ] 88842 of 100000 complete in 686.8 sec
#  [-----------------88%-------------     ] 88910 of 100000 complete in 687.3 sec
#  [-----------------88%-------------     ] 88978 of 100000 complete in 687.9 sec
#  [-----------------89%-------------     ] 89044 of 100000 complete in 688.4 sec
#  [-----------------89%-------------     ] 89110 of 100000 complete in 688.9 sec
#  [-----------------89%-------------     ] 89175 of 100000 complete in 689.4 sec
#  [-----------------89%-------------     ] 89242 of 100000 complete in 689.9 sec
#  [-----------------89%-------------     ] 89306 of 100000 complete in 690.4 sec
#  [-----------------89%-------------     ] 89372 of 100000 complete in 690.9 sec
#  [-----------------89%-------------     ] 89441 of 100000 complete in 691.4 sec
#  [-----------------89%--------------    ] 89508 of 100000 complete in 691.9 sec
#  [-----------------89%--------------    ] 89574 of 100000 complete in 692.4 sec
#  [-----------------89%--------------    ] 89640 of 100000 complete in 692.9 sec
#  [-----------------89%--------------    ] 89706 of 100000 complete in 693.4 sec
#  [-----------------89%--------------    ] 89773 of 100000 complete in 693.9 sec
#  [-----------------89%--------------    ] 89839 of 100000 complete in 694.4 sec
#  [-----------------89%--------------    ] 89907 of 100000 complete in 694.9 sec
#  [-----------------89%--------------    ] 89976 of 100000 complete in 695.4 sec
#  [-----------------90%--------------    ] 90040 of 100000 complete in 695.9 sec
#  [-----------------90%--------------    ] 90104 of 100000 complete in 696.4 sec
#  [-----------------90%--------------    ] 90171 of 100000 complete in 696.9 sec
#  [-----------------90%--------------    ] 90239 of 100000 complete in 697.4 sec
#  [-----------------90%--------------    ] 90307 of 100000 complete in 697.9 sec
#  [-----------------90%--------------    ] 90368 of 100000 complete in 698.4 sec
#  [-----------------90%--------------    ] 90436 of 100000 complete in 698.9 sec
#  [-----------------90%--------------    ] 90504 of 100000 complete in 699.4 sec
#  [-----------------90%--------------    ] 90571 of 100000 complete in 699.9 sec
#  [-----------------90%--------------    ] 90637 of 100000 complete in 700.4 sec
#  [-----------------90%--------------    ] 90702 of 100000 complete in 701.0 sec
#  [-----------------90%--------------    ] 90768 of 100000 complete in 701.5 sec
#  [-----------------90%--------------    ] 90836 of 100000 complete in 702.0 sec
#  [-----------------90%--------------    ] 90902 of 100000 complete in 702.5 sec
#  [-----------------90%--------------    ] 90970 of 100000 complete in 703.0 sec
#  [-----------------91%--------------    ] 91038 of 100000 complete in 703.5 sec
#  [-----------------91%--------------    ] 91101 of 100000 complete in 704.0 sec
#  [-----------------91%--------------    ] 91167 of 100000 complete in 704.5 sec
#  [-----------------91%--------------    ] 91234 of 100000 complete in 705.0 sec
#  [-----------------91%--------------    ] 91302 of 100000 complete in 705.5 sec
#  [-----------------91%--------------    ] 91370 of 100000 complete in 706.0 sec
#  [-----------------91%--------------    ] 91434 of 100000 complete in 706.5 sec
#  [-----------------91%--------------    ] 91501 of 100000 complete in 707.0 sec
#  [-----------------91%--------------    ] 91569 of 100000 complete in 707.5 sec
#  [-----------------91%--------------    ] 91636 of 100000 complete in 708.0 sec
#  [-----------------91%--------------    ] 91703 of 100000 complete in 708.5 sec
#  [-----------------91%--------------    ] 91770 of 100000 complete in 709.0 sec
#  [-----------------91%--------------    ] 91837 of 100000 complete in 709.5 sec
#  [-----------------91%--------------    ] 91905 of 100000 complete in 710.0 sec
#  [-----------------91%--------------    ] 91969 of 100000 complete in 710.5 sec
#  [-----------------92%--------------    ] 92037 of 100000 complete in 711.0 sec
#  [-----------------92%--------------    ] 92099 of 100000 complete in 711.5 sec
#  [-----------------92%---------------   ] 92163 of 100000 complete in 712.0 sec
#  [-----------------92%---------------   ] 92229 of 100000 complete in 712.6 sec
#  [-----------------92%---------------   ] 92297 of 100000 complete in 713.1 sec
#  [-----------------92%---------------   ] 92364 of 100000 complete in 713.6 sec
#  [-----------------92%---------------   ] 92431 of 100000 complete in 714.1 sec
#  [-----------------92%---------------   ] 92496 of 100000 complete in 714.6 sec
#  [-----------------92%---------------   ] 92562 of 100000 complete in 715.1 sec
#  [-----------------92%---------------   ] 92630 of 100000 complete in 715.6 sec
#  [-----------------92%---------------   ] 92699 of 100000 complete in 716.1 sec
#  [-----------------92%---------------   ] 92765 of 100000 complete in 716.6 sec
#  [-----------------92%---------------   ] 92826 of 100000 complete in 717.1 sec
#  [-----------------92%---------------   ] 92892 of 100000 complete in 717.6 sec
#  [-----------------92%---------------   ] 92958 of 100000 complete in 718.1 sec
#  [-----------------93%---------------   ] 93023 of 100000 complete in 718.6 sec
#  [-----------------93%---------------   ] 93090 of 100000 complete in 719.1 sec
#  [-----------------93%---------------   ] 93156 of 100000 complete in 719.6 sec
#  [-----------------93%---------------   ] 93224 of 100000 complete in 720.1 sec
#  [-----------------93%---------------   ] 93291 of 100000 complete in 720.6 sec
#  [-----------------93%---------------   ] 93359 of 100000 complete in 721.1 sec
#  [-----------------93%---------------   ] 93427 of 100000 complete in 721.6 sec
#  [-----------------93%---------------   ] 93495 of 100000 complete in 722.1 sec
#  [-----------------93%---------------   ] 93555 of 100000 complete in 722.6 sec
#  [-----------------93%---------------   ] 93622 of 100000 complete in 723.1 sec
#  [-----------------93%---------------   ] 93690 of 100000 complete in 723.6 sec
#  [-----------------93%---------------   ] 93757 of 100000 complete in 724.1 sec
#  [-----------------93%---------------   ] 93823 of 100000 complete in 724.6 sec
#  [-----------------93%---------------   ] 93889 of 100000 complete in 725.1 sec
#  [-----------------93%---------------   ] 93956 of 100000 complete in 725.6 sec
#  [-----------------94%---------------   ] 94024 of 100000 complete in 726.1 sec
#  [-----------------94%---------------   ] 94091 of 100000 complete in 726.6 sec
#  [-----------------94%---------------   ] 94157 of 100000 complete in 727.1 sec
#  [-----------------94%---------------   ] 94223 of 100000 complete in 727.7 sec
#  [-----------------94%---------------   ] 94289 of 100000 complete in 728.2 sec
#  [-----------------94%---------------   ] 94355 of 100000 complete in 728.7 sec
#  [-----------------94%---------------   ] 94423 of 100000 complete in 729.2 sec
#  [-----------------94%---------------   ] 94486 of 100000 complete in 729.7 sec
#  [-----------------94%---------------   ] 94553 of 100000 complete in 730.2 sec
#  [-----------------94%---------------   ] 94618 of 100000 complete in 730.7 sec
#  [-----------------94%---------------   ] 94684 of 100000 complete in 731.2 sec
#  [-----------------94%----------------  ] 94748 of 100000 complete in 731.7 sec
#  [-----------------94%----------------  ] 94815 of 100000 complete in 732.2 sec
#  [-----------------94%----------------  ] 94883 of 100000 complete in 732.7 sec
#  [-----------------94%----------------  ] 94946 of 100000 complete in 733.2 sec
#  [-----------------95%----------------  ] 95014 of 100000 complete in 733.7 sec
#  [-----------------95%----------------  ] 95082 of 100000 complete in 734.2 sec
#  [-----------------95%----------------  ] 95148 of 100000 complete in 734.7 sec
#  [-----------------95%----------------  ] 95216 of 100000 complete in 735.2 sec
#  [-----------------95%----------------  ] 95284 of 100000 complete in 735.7 sec
#  [-----------------95%----------------  ] 95345 of 100000 complete in 736.2 sec
#  [-----------------95%----------------  ] 95401 of 100000 complete in 736.7 sec
#  [-----------------95%----------------  ] 95465 of 100000 complete in 737.2 sec
#  [-----------------95%----------------  ] 95531 of 100000 complete in 737.7 sec
#  [-----------------95%----------------  ] 95599 of 100000 complete in 738.2 sec
#  [-----------------95%----------------  ] 95661 of 100000 complete in 738.7 sec
#  [-----------------95%----------------  ] 95728 of 100000 complete in 739.2 sec
#  [-----------------95%----------------  ] 95794 of 100000 complete in 739.7 sec
#  [-----------------95%----------------  ] 95862 of 100000 complete in 740.2 sec
#  [-----------------95%----------------  ] 95928 of 100000 complete in 740.7 sec
#  [-----------------95%----------------  ] 95994 of 100000 complete in 741.2 sec
#  [-----------------96%----------------  ] 96061 of 100000 complete in 741.7 sec
#  [-----------------96%----------------  ] 96128 of 100000 complete in 742.3 sec
#  [-----------------96%----------------  ] 96194 of 100000 complete in 742.8 sec
#  [-----------------96%----------------  ] 96262 of 100000 complete in 743.3 sec
#  [-----------------96%----------------  ] 96328 of 100000 complete in 743.8 sec
#  [-----------------96%----------------  ] 96392 of 100000 complete in 744.3 sec
#  [-----------------96%----------------  ] 96459 of 100000 complete in 744.8 sec
#  [-----------------96%----------------  ] 96527 of 100000 complete in 745.3 sec
#  [-----------------96%----------------  ] 96593 of 100000 complete in 745.8 sec
#  [-----------------96%----------------  ] 96660 of 100000 complete in 746.3 sec
#  [-----------------96%----------------  ] 96726 of 100000 complete in 746.8 sec
#  [-----------------96%----------------  ] 96790 of 100000 complete in 747.3 sec
#  [-----------------96%----------------  ] 96858 of 100000 complete in 747.8 sec
#  [-----------------96%----------------  ] 96926 of 100000 complete in 748.3 sec
#  [-----------------96%----------------  ] 96991 of 100000 complete in 748.8 sec
#  [-----------------97%----------------  ] 97055 of 100000 complete in 749.3 sec
#  [-----------------97%----------------  ] 97121 of 100000 complete in 749.8 sec
#  [-----------------97%----------------  ] 97188 of 100000 complete in 750.3 sec
#  [-----------------97%----------------  ] 97253 of 100000 complete in 750.8 sec
#  [-----------------97%----------------  ] 97320 of 100000 complete in 751.3 sec
#  [-----------------97%----------------- ] 97389 of 100000 complete in 751.8 sec
#  [-----------------97%----------------- ] 97457 of 100000 complete in 752.3 sec
#  [-----------------97%----------------- ] 97523 of 100000 complete in 752.8 sec
#  [-----------------97%----------------- ] 97591 of 100000 complete in 753.3 sec
#  [-----------------97%----------------- ] 97660 of 100000 complete in 753.8 sec
#  [-----------------97%----------------- ] 97728 of 100000 complete in 754.4 sec
#  [-----------------97%----------------- ] 97793 of 100000 complete in 754.9 sec
#  [-----------------97%----------------- ] 97861 of 100000 complete in 755.4 sec
#  [-----------------97%----------------- ] 97929 of 100000 complete in 755.9 sec
#  [-----------------97%----------------- ] 97995 of 100000 complete in 756.4 sec
#  [-----------------98%----------------- ] 98059 of 100000 complete in 756.9 sec
#  [-----------------98%----------------- ] 98126 of 100000 complete in 757.4 sec
#  [-----------------98%----------------- ] 98194 of 100000 complete in 757.9 sec
#  [-----------------98%----------------- ] 98256 of 100000 complete in 758.4 sec
#  [-----------------98%----------------- ] 98324 of 100000 complete in 758.9 sec
#  [-----------------98%----------------- ] 98390 of 100000 complete in 759.4 sec
#  [-----------------98%----------------- ] 98447 of 100000 complete in 759.9 sec
#  [-----------------98%----------------- ] 98506 of 100000 complete in 760.4 sec
#  [-----------------98%----------------- ] 98573 of 100000 complete in 760.9 sec
#  [-----------------98%----------------- ] 98640 of 100000 complete in 761.4 sec
#  [-----------------98%----------------- ] 98708 of 100000 complete in 761.9 sec
#  [-----------------98%----------------- ] 98774 of 100000 complete in 762.4 sec
#  [-----------------98%----------------- ] 98841 of 100000 complete in 762.9 sec
#  [-----------------98%----------------- ] 98907 of 100000 complete in 763.4 sec
#  [-----------------98%----------------- ] 98974 of 100000 complete in 763.9 sec
#  [-----------------99%----------------- ] 99041 of 100000 complete in 764.4 sec
#  [-----------------99%----------------- ] 99109 of 100000 complete in 764.9 sec
#  [-----------------99%----------------- ] 99173 of 100000 complete in 765.4 sec
#  [-----------------99%----------------- ] 99240 of 100000 complete in 765.9 sec
#  [-----------------99%----------------- ] 99307 of 100000 complete in 766.4 sec
#  [-----------------99%----------------- ] 99374 of 100000 complete in 767.0 sec
#  [-----------------99%----------------- ] 99442 of 100000 complete in 767.5 sec
#  [-----------------99%----------------- ] 99511 of 100000 complete in 768.0 sec
#  [-----------------99%----------------- ] 99577 of 100000 complete in 768.5 sec
#  [-----------------99%----------------- ] 99644 of 100000 complete in 769.0 sec
#  [-----------------99%----------------- ] 99710 of 100000 complete in 769.5 sec
#  [-----------------99%----------------- ] 99776 of 100000 complete in 770.0 sec
#  [-----------------99%----------------- ] 99841 of 100000 complete in 770.5 sec
#  [-----------------99%----------------- ] 99904 of 100000 complete in 771.0 sec
#  [-----------------99%----------------- ] 99971 of 100000 complete in 771.5 sec
#  [-----------------100%-----------------] 100000 of 100000 complete in 771.7 sec

# %%
order = np.argsort([b.stats()["mean"] for b in Mlang.betas[1:]])[::-1]
Matplot.summary_plot(np.array(Mlang.betas[1:])[order])

# %%
Matplot.plot(Mlang.beta_lang)
# Out:
# Plotting beta_lang
